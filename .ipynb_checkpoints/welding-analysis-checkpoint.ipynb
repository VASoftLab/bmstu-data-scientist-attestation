# %% [markdown]
# ## Анализ процесса электронно-лучевой сварки
# ### Выпускная квалификационная работа
# по курсу "Аналитик данных" Образовательный центр МГТУ им. Н.Э. Баумана - 2022
# <br>
# <br><b>Выполнил:</b> <i>Альчаков В.В. гр. AD11872/3<i>

# %% [markdown]
# ### Подключение необходимых библиотек

# %%
import pandas as pd
import numpy as np

# Установить точность вывода - 3 знака после запятой
np.set_printoptions(precision = 3, suppress = True)

# sklearn
from sklearn.preprocessing import PolynomialFeatures, StandardScaler
from sklearn.linear_model import LinearRegression
from sklearn.pipeline import make_pipeline
from sklearn.metrics import mean_absolute_error as mae

# scipy
from scipy import stats
from scipy.stats import norm

# Библиотеки для работы с графикой
import seaborn as sns
sns.set()

import matplotlib.pyplot as plt
import matplotlib.style
# %matplotlib inline

# tensorflow
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers

# Работа с ONNX моделями
import onnx
import tf2onnx
import onnxruntime as rt

# Отключение вывода предупреждений
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ### Геометрические параметры сварного шва
# ![alt text](img/welding.png "Title")
# <i><b>e</b> - Ширина шва</i><br>
# <i><b>q</b> - Выпуклость шва</i><br>
# <i><b>h</b> - Глубина провара</i><br>
# <i><b>t</b> - Толщина шва</i><br>
# <i><b>b</b> - Зазор</i><br>
# <i><b>S</b> - Толщина свариваемого металла</i><br>
#
# В качестве исходных данных были взяты результаты экспериментальных исследований, проводимых в целях улучшения технологического процесса электронно-лучевой сварки изделия, сборка которого состоит из элементов, состоящих из разнородного материала. Установка электронно-лучевой сварки, на которой проводились исследования, предназначена для сварки электронным лучом в глубоком вакууме деталей сборочных единиц из нержавеющих сталей, титановых, алюминиевых и специальных сплавов. Существующая установка электронно-лучевой сварки обеспечивает повторяемость режимов в рамках возможностей реализованной системы управления. Работы по сварке выполнялись на образцах-имитаторах, соответствующих технологическому изделию.

# %% [markdown]
# ### Загрузка исходного датасета
# <b>ВХОД:</b>
# <ol>
#     <li>IW - Ток сварочного тока</li>
#     <li>IF - Ток фокусировки электронного пучка</li>
#     <li>VW - Скорость сварки</li>
#     <li>FP - Расстояние от поверхности образцов</li>
# </ol>
# <br>
# <b>ВЫХОД:</b>
# <ol>
#     <li>Depth - Глубина шва</li>
#     <li>Width - Ширина шва</li>
# </ol>

# %%
raw_data = pd.read_csv('data/ebw_data.csv')
raw_data.shape
# Out:
# (72, 6)

# %% [markdown]
# ### Предварительная обработка и разведовательный анализ

# %% [markdown]
# ##### Просмотр первых строк датасета

# %%
raw_data.head()
# Out:
#    IW   IF   VW  FP  Depth  Width
# 0  47  139  4.5  80   1.60   2.54
# 1  47  139  4.5  80   1.62   2.50
# 2  47  139  4.5  80   1.68   2.60
# 3  47  139  4.5  80   1.58   2.52
# 4  45  140  4.5  80   1.76   2.48

# %% [markdown]
# ##### Проверка на наличие пропусков

# %%
raw_data.isnull().sum()
# Out:
# IW       0
# IF       0
# VW       0
# FP       0
# Depth    0
# Width    0
# dtype: int64

# %% [markdown]
# ##### Построение обучающей выборки
# Анализ датасета показывает, что комбинации значений столбцов IW, IF, VW, FP повторяются. Поэтому построим новый датасет, с уникальными комбинациями признаков и выходным параметром усредненным по каждой группе

# %%
train_data = raw_data.groupby(['IW', 'IF', 'VW', 'FP']).agg({'Depth': ['mean'], 'Width': ['mean']}).reset_index()
train_data.columns = ['IW', 'IF', 'VW', 'FP', 'Depth', 'Width']

# %%
# Модифицированный датасет для обучения
train_data
# Out:
#     IW   IF    VW   FP  Depth   Width
# 0   43  146   9.0   60  1.220  1.7650
# 1   43  150   9.0   50  1.080  1.8150
# 2   44  146   9.0   60  1.230  1.7950
# 3   45  140   4.5   80  1.690  2.5100
# 4   45  140   8.0   80  1.190  1.9700
# 5   45  141  10.0   80  1.010  1.8600
# 6   45  146   9.0   60  1.310  1.7600
# 7   46  141  10.0   80  1.140  1.8200
# 8   46  146  10.0   60  1.310  1.7700
# 9   47  134  10.0  110  0.945  1.9350
# 10  47  139   4.5   80  1.495  2.5150
# 11  47  140  10.0   80  1.160  1.7900
# 12  47  141  12.0   80  1.120  1.7275
# 13  48  131  10.0  125  0.845  2.0700
# 14  49  132   8.0  125  0.820  2.2600

# %% [markdown]
# ##### Описательная статистика

# %%
train_data.describe()
# Out:
#               IW          IF         VW          FP      Depth      Width
# count  15.000000   15.000000  15.000000   15.000000  15.000000  15.000000
# mean   45.800000  140.866667   8.866667   80.666667   1.171000   1.957500
# std     1.740279    5.462426   2.021904   23.057898   0.229543   0.265678
# min    43.000000  131.000000   4.500000   50.000000   0.820000   1.727500
# 25%    45.000000  139.500000   8.500000   60.000000   1.045000   1.780000
# 50%    46.000000  141.000000   9.000000   80.000000   1.160000   1.820000
# 75%    47.000000  146.000000  10.000000   80.000000   1.270000   2.020000
# max    49.000000  150.000000  12.000000  125.000000   1.690000   2.515000

# %% [markdown]
# ##### Расчет корреляционной матрицы
# В случае линейной регрессионной модели корреляционная матрица позволит выяснить, какие признаки в большей степени влияют на целевую переменную

# %%
# Корреляционная матрица
train_data.corr()
# Out:
#              IW        IF        VW        FP     Depth     Width
# IW     1.000000 -0.844566  0.073079  0.831286 -0.389267  0.359959
# IF    -0.844566  1.000000  0.066182 -0.983178  0.452146 -0.501293
# VW     0.073079  0.066182  1.000000  0.017364 -0.651087 -0.864309
# FP     0.831286 -0.983178  0.017364  1.000000 -0.569981  0.432293
# Depth -0.389267  0.452146 -0.651087 -0.569981  1.000000  0.355843
# Width  0.359959 -0.501293 -0.864309  0.432293  0.355843  1.000000

# %% [markdown]
# ##### Корреляционная матрица в виде тепловой карты

# %%
plt.figure(figsize = (5, 3), dpi = 100)
plt.style.use('classic')
sns.set_style('whitegrid')
sns.heatmap(train_data.corr(), annot = True)
plt.show()

# %%
sns.pairplot(train_data[['IW', 'IF', 'VW', 'FP', 'Depth', 'Width']], diag_kind = 'kde')

# %%
fig = plt.figure(figsize = (4, 3), dpi = 100)
sns.distplot(train_data['Depth'] , fit = norm);

# %%
fig = plt.figure(figsize = (4, 3), dpi = 100)
sns.distplot(train_data['Width'] , fit = norm);

# %%
fig = plt.figure(figsize = (7, 3), dpi = 100)
res = stats.probplot(train_data['Depth'], plot = plt)
plt.show()

# %%
fig = plt.figure(figsize = (7, 3), dpi = 100)
res = stats.probplot(train_data['Width'], plot = plt)
plt.show()

# %% [markdown]
# ##### Разбиваем выборку на массив признаков и вектор со значениями целевой переменной

# %%
# Признаки
X = train_data.drop(['Depth', 'Width'], axis = 1)
# Глубина шва
yD = train_data['Depth']
# Ширина шва
yW = train_data['Width']

# %%
# Матрица признаков
X.head()
# Out:
#    IW   IF   VW  FP
# 0  43  146  9.0  60
# 1  43  150  9.0  50
# 2  44  146  9.0  60
# 3  45  140  4.5  80
# 4  45  140  8.0  80

# %%
# Вектор целевая переменная - Глубина шва
yD.head()
# Out:
# 0    1.22
# 1    1.08
# 2    1.23
# 3    1.69
# 4    1.19
# Name: Depth, dtype: float64

# %%
# Вектор целевая переменная - Ширина шва
yW.head()
# Out:
# 0    1.765
# 1    1.815
# 2    1.795
# 3    2.510
# 4    1.970
# Name: Width, dtype: float64

# %%
print('Размерности данных (обучающая выборка)')
print(f'Матрица признаков {X.shape}')
print(f'Целевой вектор (глубина шва) {yD.shape}')
print(f'Целевой вектор (ширина шва) {yW.shape}')
# Out:
# Размерности данных (обучающая выборка)
# Матрица признаков (15, 4)
# Целевой вектор (глубина шва) (15,)
# Целевой вектор (ширина шва) (15,)

# %% [markdown]
# ##### Разбивка данных на выборки для обучения и тестирования

# %%
X_train = pd.DataFrame(train_data.iloc[:, 0:4]).values
yD_train = pd.DataFrame(train_data.iloc[:, 4:5]).values
yW_train = pd.DataFrame(train_data.iloc[:, 5:6]).values

X_test = pd.DataFrame(raw_data.iloc[:, 0:4]).values
yD_test = pd.DataFrame(raw_data.iloc[:, 4:5]).values
yW_test = pd.DataFrame(raw_data.iloc[:, 5:6]).values

# %%
# Переменные для хранения точности
test_results_width = {}
test_results_depth = {}

# %% [markdown]
# ##### Функция отрисовки результатов модели

# %%
def plot_model(x, y_test, y_predict, title_txt):
    plt.rcParams.update(plt.rcParamsDefault)
    plt.figure(figsize = (10, 4), dpi = 150)
    plt.plot(x, y_test, 'go-', linewidth = 2, markersize = 5)
    plt.plot(x, y_predict, '-r',  linewidth = 2, alpha = .75)
    plt.legend(['Измерения', 'Предсказания'])
    plt.title(title_txt)
    plt.grid(color = 'b', linestyle = '--', linewidth = 0.5, alpha = .75)
    plt.show()

# %%
pipe = make_pipeline(StandardScaler(), LinearRegression())
pipe.fit(X_train, yW_train)
yW_predict = pipe.predict(X_test)
xW_predict = range(yW_predict.shape[0])
test_results_width['LinearRegression'] = mae(yW_test, yW_predict)
plot_model(xW_predict, yW_test, yW_predict, f'Width: LinearRegression Model MAE: {mae(yW_test, yW_predict):0.3}')

# %%
pipe = make_pipeline(StandardScaler(), PolynomialFeatures(), LinearRegression())
pipe.fit(X_train, yW_train)
yW_predict = pipe.predict(X_test)
xW_predict = range(yW_predict.shape[0])
test_results_width['PolynomialFeatures'] = mae(yW_test, yW_predict)
plot_model(xW_predict, yW_test, yW_predict, f'Width: PolynomialFeatures Model MAE: {mae(yW_test, yW_predict):0.3}')

# %%
pipe = make_pipeline(StandardScaler(), LinearRegression())
pipe.fit(X_train, yD_train)
yD_predict = pipe.predict(X_test)
xD_predict = range(yD_predict.shape[0])
test_results_depth['LinearRegression'] = mae(yD_test, yD_predict)
plot_model(xD_predict, yD_test, yD_predict, f'Depth: LinearRegression Model MAE: {mae(yD_test, yD_predict):0.3}')

# %%
pipe = make_pipeline(StandardScaler(), PolynomialFeatures(), LinearRegression())
pipe.fit(X_train, yD_train)
yD_predict = pipe.predict(X_test)
xD_predict = range(yD_predict.shape[0])
test_results_depth['PolynomialFeatures'] = mae(yD_test, yD_predict)
plot_model(xD_predict, yD_test, yD_predict, f'Depth: PolynomialFeatures Model MAE: {mae(yD_test, yD_predict):0.3}')

# %% [markdown]
# ### Применение нейронной сети для анализа

# %%
train_features = pd.DataFrame(train_data.iloc[:, 0:4]).values
train_labels = pd.DataFrame(train_data.iloc[:, 4:6]).values
test_features = pd.DataFrame(raw_data.iloc[:, 0:4]).values
test_labels = pd.DataFrame(raw_data.iloc[:, 4:6]).values

# %%
normalizer = tf.keras.layers.Normalization(axis = -1)
normalizer.adapt(np.array(train_features))
print(normalizer.mean.numpy())
# Out:
# [[ 45.8   140.867   8.867  80.667]]

# %%
pd.DataFrame(train_data.iloc[:, 0:4]).describe().T
# Out:
#     count        mean        std    min    25%    50%    75%    max
# IW   15.0   45.800000   1.740279   43.0   45.0   46.0   47.0   49.0
# IF   15.0  140.866667   5.462426  131.0  139.5  141.0  146.0  150.0
# VW   15.0    8.866667   2.021904    4.5    8.5    9.0   10.0   12.0
# FP   15.0   80.666667  23.057898   50.0   60.0   80.0   80.0  125.0

# %%
seq_model = keras.Sequential([normalizer,
                              layers.Dense(64, activation = 'relu'),
                              layers.Dense(32, activation = 'relu'),
                              layers.Dense(2)
                             ])
seq_model.compile(loss = 'mean_absolute_error', optimizer = tf.keras.optimizers.Adam(0.001), metrics = ['accuracy'])
seq_model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  normalization (Normalizatio  (None, 4)                9
#  n)
#
#  dense (Dense)               (None, 64)                320
#
#  dense_1 (Dense)             (None, 32)                2080
#
#  dense_2 (Dense)             (None, 2)                 66
#
# =================================================================
# Total params: 2,475
# Trainable params: 2,466
# Non-trainable params: 9
# _________________________________________________________________

# %%
history = seq_model.fit(train_features, train_labels, epochs = 1000, verbose = 1, validation_split = 0.01)
# Out:
# Epoch 1/1000
# 1/1 [==============================] - 0s 440ms/step - loss: 1.6377 - accuracy: 0.6429 - val_loss: 1.4468 - val_accuracy: 0.0000e+00
# Epoch 2/1000
# 1/1 [==============================] - 0s 22ms/step - loss: 1.6057 - accuracy: 0.6429 - val_loss: 1.3830 - val_accuracy: 0.0000e+00
# Epoch 3/1000
# 1/1 [==============================] - 0s 21ms/step - loss: 1.5741 - accuracy: 0.5714 - val_loss: 1.3193 - val_accuracy: 0.0000e+00
# Epoch 4/1000
# 1/1 [==============================] - 0s 21ms/step - loss: 1.5431 - accuracy: 0.5714 - val_loss: 1.2559 - val_accuracy: 0.0000e+00
# Epoch 5/1000
# 1/1 [==============================] - 0s 22ms/step - loss: 1.5130 - accuracy: 0.5714 - val_loss: 1.1926 - val_accuracy: 0.0000e+00
# Epoch 6/1000
# 1/1 [==============================] - 0s 23ms/step - loss: 1.4837 - accuracy: 0.5714 - val_loss: 1.1297 - val_accuracy: 0.0000e+00
# Epoch 7/1000
# 1/1 [==============================] - 0s 22ms/step - loss: 1.4548 - accuracy: 0.5714 - val_loss: 1.0668 - val_accuracy: 0.0000e+00
# Epoch 8/1000
# 1/1 [==============================] - 0s 20ms/step - loss: 1.4263 - accuracy: 0.5714 - val_loss: 1.0038 - val_accuracy: 0.0000e+00
# Epoch 9/1000
# 1/1 [==============================] - 0s 22ms/step - loss: 1.4029 - accuracy: 0.5000 - val_loss: 0.9825 - val_accuracy: 0.0000e+00
# Epoch 10/1000
# 1/1 [==============================] - 0s 22ms/step - loss: 1.3803 - accuracy: 0.5000 - val_loss: 0.9951 - val_accuracy: 0.0000e+00
# Epoch 11/1000
# 1/1 [==============================] - 0s 23ms/step - loss: 1.3573 - accuracy: 0.4286 - val_loss: 1.0040 - val_accuracy: 0.0000e+00
# Epoch 12/1000
# 1/1 [==============================] - 0s 22ms/step - loss: 1.3346 - accuracy: 0.3571 - val_loss: 1.0084 - val_accuracy: 0.0000e+00
# Epoch 13/1000
# 1/1 [==============================] - 0s 20ms/step - loss: 1.3121 - accuracy: 0.2857 - val_loss: 1.0102 - val_accuracy: 0.0000e+00
# Epoch 14/1000
# 1/1 [==============================] - 0s 22ms/step - loss: 1.2894 - accuracy: 0.1429 - val_loss: 1.0081 - val_accuracy: 0.0000e+00
# Epoch 15/1000
# 1/1 [==============================] - 0s 22ms/step - loss: 1.2664 - accuracy: 0.0714 - val_loss: 1.0040 - val_accuracy: 0.0000e+00
# Epoch 16/1000
# 1/1 [==============================] - 0s 22ms/step - loss: 1.2434 - accuracy: 0.0000e+00 - val_loss: 0.9981 - val_accuracy: 0.0000e+00
# Epoch 17/1000
# 1/1 [==============================] - 0s 23ms/step - loss: 1.2204 - accuracy: 0.0000e+00 - val_loss: 0.9907 - val_accuracy: 0.0000e+00
# Epoch 18/1000
# 1/1 [==============================] - 0s 20ms/step - loss: 1.1975 - accuracy: 0.0000e+00 - val_loss: 0.9811 - val_accuracy: 0.0000e+00
# Epoch 19/1000
# 1/1 [==============================] - 0s 19ms/step - loss: 1.1747 - accuracy: 0.0000e+00 - val_loss: 0.9675 - val_accuracy: 0.0000e+00
# Epoch 20/1000
# 1/1 [==============================] - 0s 20ms/step - loss: 1.1529 - accuracy: 0.0000e+00 - val_loss: 0.9506 - val_accuracy: 0.0000e+00
# Epoch 21/1000
# 1/1 [==============================] - 0s 20ms/step - loss: 1.1305 - accuracy: 0.0000e+00 - val_loss: 0.9310 - val_accuracy: 0.0000e+00
# Epoch 22/1000
# 1/1 [==============================] - 0s 23ms/step - loss: 1.1074 - accuracy: 0.0000e+00 - val_loss: 0.9091 - val_accuracy: 0.0000e+00
# Epoch 23/1000
# 1/1 [==============================] - 0s 26ms/step - loss: 1.0836 - accuracy: 0.0000e+00 - val_loss: 0.8863 - val_accuracy: 0.0000e+00
# Epoch 24/1000
# 1/1 [==============================] - 0s 21ms/step - loss: 1.0591 - accuracy: 0.0000e+00 - val_loss: 0.8645 - val_accuracy: 0.0000e+00
# Epoch 25/1000
# 1/1 [==============================] - 0s 21ms/step - loss: 1.0339 - accuracy: 0.0000e+00 - val_loss: 0.8436 - val_accuracy: 0.0000e+00
# Epoch 26/1000
# 1/1 [==============================] - 0s 21ms/step - loss: 1.0105 - accuracy: 0.0000e+00 - val_loss: 0.8216 - val_accuracy: 0.0000e+00
# Epoch 27/1000
# 1/1 [==============================] - 0s 22ms/step - loss: 0.9887 - accuracy: 0.0000e+00 - val_loss: 0.7985 - val_accuracy: 0.0000e+00
# Epoch 28/1000
# 1/1 [==============================] - 0s 22ms/step - loss: 0.9662 - accuracy: 0.0000e+00 - val_loss: 0.7748 - val_accuracy: 0.0000e+00
# Epoch 29/1000
# 1/1 [==============================] - 0s 20ms/step - loss: 0.9433 - accuracy: 0.0000e+00 - val_loss: 0.7497 - val_accuracy: 0.0000e+00
# Epoch 30/1000
# 1/1 [==============================] - 0s 21ms/step - loss: 0.9200 - accuracy: 0.0000e+00 - val_loss: 0.7237 - val_accuracy: 0.0000e+00
# Epoch 31/1000
# 1/1 [==============================] - 0s 23ms/step - loss: 0.8965 - accuracy: 0.0000e+00 - val_loss: 0.6971 - val_accuracy: 1.0000
# Epoch 32/1000
# 1/1 [==============================] - 0s 21ms/step - loss: 0.8735 - accuracy: 0.0714 - val_loss: 0.6694 - val_accuracy: 1.0000
# Epoch 33/1000
# 1/1 [==============================] - 0s 22ms/step - loss: 0.8509 - accuracy: 0.1429 - val_loss: 0.6407 - val_accuracy: 1.0000
# Epoch 34/1000
# 1/1 [==============================] - 0s 22ms/step - loss: 0.8306 - accuracy: 0.1429 - val_loss: 0.6127 - val_accuracy: 1.0000
# Epoch 35/1000
# 1/1 [==============================] - 0s 21ms/step - loss: 0.8102 - accuracy: 0.1429 - val_loss: 0.5856 - val_accuracy: 1.0000
# Epoch 36/1000
# 1/1 [==============================] - 0s 24ms/step - loss: 0.7892 - accuracy: 0.1429 - val_loss: 0.5594 - val_accuracy: 1.0000
# Epoch 37/1000
# 1/1 [==============================] - 0s 22ms/step - loss: 0.7673 - accuracy: 0.1429 - val_loss: 0.5351 - val_accuracy: 1.0000
# Epoch 38/1000
# 1/1 [==============================] - 0s 22ms/step - loss: 0.7446 - accuracy: 0.1429 - val_loss: 0.5137 - val_accuracy: 1.0000
# Epoch 39/1000
# 1/1 [==============================] - 0s 22ms/step - loss: 0.7222 - accuracy: 0.1429 - val_loss: 0.4916 - val_accuracy: 1.0000
# Epoch 40/1000
# 1/1 [==============================] - 0s 21ms/step - loss: 0.7030 - accuracy: 0.1429 - val_loss: 0.4643 - val_accuracy: 1.0000
# Epoch 41/1000
# 1/1 [==============================] - 0s 20ms/step - loss: 0.6830 - accuracy: 0.1429 - val_loss: 0.4329 - val_accuracy: 1.0000
# Epoch 42/1000
# 1/1 [==============================] - 0s 20ms/step - loss: 0.6652 - accuracy: 0.1429 - val_loss: 0.3961 - val_accuracy: 1.0000
# Epoch 43/1000
# 1/1 [==============================] - 0s 20ms/step - loss: 0.6468 - accuracy: 0.1429 - val_loss: 0.3590 - val_accuracy: 1.0000
# Epoch 44/1000
# 1/1 [==============================] - 0s 20ms/step - loss: 0.6319 - accuracy: 0.1429 - val_loss: 0.3580 - val_accuracy: 1.0000
# Epoch 45/1000
# 1/1 [==============================] - 0s 20ms/step - loss: 0.6161 - accuracy: 0.1429 - val_loss: 0.3802 - val_accuracy: 1.0000
# Epoch 46/1000
# 1/1 [==============================] - 0s 20ms/step - loss: 0.5998 - accuracy: 0.1429 - val_loss: 0.3992 - val_accuracy: 1.0000
# Epoch 47/1000
# 1/1 [==============================] - 0s 20ms/step - loss: 0.5829 - accuracy: 0.1429 - val_loss: 0.4154 - val_accuracy: 1.0000
# Epoch 48/1000
# 1/1 [==============================] - 0s 20ms/step - loss: 0.5655 - accuracy: 0.1429 - val_loss: 0.4290 - val_accuracy: 1.0000
# Epoch 49/1000
# 1/1 [==============================] - 0s 20ms/step - loss: 0.5475 - accuracy: 0.1429 - val_loss: 0.4404 - val_accuracy: 1.0000
# Epoch 50/1000
# 1/1 [==============================] - 0s 21ms/step - loss: 0.5288 - accuracy: 0.1429 - val_loss: 0.4499 - val_accuracy: 1.0000
# Epoch 51/1000
# 1/1 [==============================] - 0s 20ms/step - loss: 0.5092 - accuracy: 0.2143 - val_loss: 0.4576 - val_accuracy: 1.0000
# Epoch 52/1000
# 1/1 [==============================] - 0s 20ms/step - loss: 0.4897 - accuracy: 0.2143 - val_loss: 0.4638 - val_accuracy: 1.0000
# Epoch 53/1000
# 1/1 [==============================] - 0s 20ms/step - loss: 0.4697 - accuracy: 0.3571 - val_loss: 0.4675 - val_accuracy: 1.0000
# Epoch 54/1000
# 1/1 [==============================] - 0s 20ms/step - loss: 0.4488 - accuracy: 0.5000 - val_loss: 0.4697 - val_accuracy: 1.0000
# Epoch 55/1000
# 1/1 [==============================] - 0s 20ms/step - loss: 0.4337 - accuracy: 0.5714 - val_loss: 0.4734 - val_accuracy: 1.0000
# Epoch 56/1000
# 1/1 [==============================] - 0s 20ms/step - loss: 0.4193 - accuracy: 0.6429 - val_loss: 0.4782 - val_accuracy: 1.0000
# Epoch 57/1000
# 1/1 [==============================] - 0s 24ms/step - loss: 0.4048 - accuracy: 0.7857 - val_loss: 0.4839 - val_accuracy: 1.0000
# Epoch 58/1000
# 1/1 [==============================] - 0s 23ms/step - loss: 0.3900 - accuracy: 0.8571 - val_loss: 0.4906 - val_accuracy: 1.0000
# Epoch 59/1000
# 1/1 [==============================] - 0s 26ms/step - loss: 0.3764 - accuracy: 0.8571 - val_loss: 0.4935 - val_accuracy: 1.0000
# Epoch 60/1000
# 1/1 [==============================] - 0s 22ms/step - loss: 0.3646 - accuracy: 0.9286 - val_loss: 0.4935 - val_accuracy: 1.0000
# Epoch 61/1000
# 1/1 [==============================] - 0s 22ms/step - loss: 0.3543 - accuracy: 1.0000 - val_loss: 0.4909 - val_accuracy: 1.0000
# Epoch 62/1000
# 1/1 [==============================] - 0s 22ms/step - loss: 0.3437 - accuracy: 1.0000 - val_loss: 0.4860 - val_accuracy: 1.0000
# Epoch 63/1000
# 1/1 [==============================] - 0s 21ms/step - loss: 0.3331 - accuracy: 1.0000 - val_loss: 0.4781 - val_accuracy: 1.0000
# Epoch 64/1000
# 1/1 [==============================] - 0s 20ms/step - loss: 0.3248 - accuracy: 1.0000 - val_loss: 0.4684 - val_accuracy: 1.0000
# Epoch 65/1000
# 1/1 [==============================] - 0s 21ms/step - loss: 0.3160 - accuracy: 1.0000 - val_loss: 0.4573 - val_accuracy: 1.0000
# Epoch 66/1000
# 1/1 [==============================] - 0s 20ms/step - loss: 0.3064 - accuracy: 1.0000 - val_loss: 0.4450 - val_accuracy: 1.0000
# Epoch 67/1000
# 1/1 [==============================] - 0s 21ms/step - loss: 0.2989 - accuracy: 1.0000 - val_loss: 0.4314 - val_accuracy: 1.0000
# Epoch 68/1000
# 1/1 [==============================] - 0s 21ms/step - loss: 0.2942 - accuracy: 1.0000 - val_loss: 0.4176 - val_accuracy: 1.0000
# Epoch 69/1000
# 1/1 [==============================] - 0s 23ms/step - loss: 0.2895 - accuracy: 1.0000 - val_loss: 0.4088 - val_accuracy: 1.0000
# Epoch 70/1000
# 1/1 [==============================] - 0s 21ms/step - loss: 0.2874 - accuracy: 1.0000 - val_loss: 0.4075 - val_accuracy: 1.0000
# Epoch 71/1000
# 1/1 [==============================] - 0s 20ms/step - loss: 0.2859 - accuracy: 1.0000 - val_loss: 0.4090 - val_accuracy: 1.0000
# Epoch 72/1000
# 1/1 [==============================] - 0s 20ms/step - loss: 0.2847 - accuracy: 1.0000 - val_loss: 0.4068 - val_accuracy: 1.0000
# Epoch 73/1000
# 1/1 [==============================] - 0s 21ms/step - loss: 0.2839 - accuracy: 1.0000 - val_loss: 0.3990 - val_accuracy: 1.0000
# Epoch 74/1000
# 1/1 [==============================] - 0s 20ms/step - loss: 0.2818 - accuracy: 1.0000 - val_loss: 0.3867 - val_accuracy: 1.0000
# Epoch 75/1000
# 1/1 [==============================] - 0s 20ms/step - loss: 0.2774 - accuracy: 1.0000 - val_loss: 0.3707 - val_accuracy: 1.0000
# Epoch 76/1000
# 1/1 [==============================] - 0s 20ms/step - loss: 0.2708 - accuracy: 1.0000 - val_loss: 0.3515 - val_accuracy: 1.0000
# Epoch 77/1000
# 1/1 [==============================] - 0s 20ms/step - loss: 0.2637 - accuracy: 1.0000 - val_loss: 0.3292 - val_accuracy: 1.0000
# Epoch 78/1000
# 1/1 [==============================] - 0s 20ms/step - loss: 0.2558 - accuracy: 1.0000 - val_loss: 0.3061 - val_accuracy: 1.0000
# Epoch 79/1000
# 1/1 [==============================] - 0s 20ms/step - loss: 0.2480 - accuracy: 1.0000 - val_loss: 0.2836 - val_accuracy: 1.0000
# Epoch 80/1000
# 1/1 [==============================] - 0s 21ms/step - loss: 0.2432 - accuracy: 1.0000 - val_loss: 0.2626 - val_accuracy: 1.0000
# Epoch 81/1000
# 1/1 [==============================] - 0s 20ms/step - loss: 0.2426 - accuracy: 1.0000 - val_loss: 0.2487 - val_accuracy: 1.0000
# Epoch 82/1000
# 1/1 [==============================] - 0s 20ms/step - loss: 0.2417 - accuracy: 0.9286 - val_loss: 0.2408 - val_accuracy: 1.0000
# Epoch 83/1000
# 1/1 [==============================] - 0s 19ms/step - loss: 0.2389 - accuracy: 0.9286 - val_loss: 0.2376 - val_accuracy: 1.0000
# Epoch 84/1000
# 1/1 [==============================] - 0s 20ms/step - loss: 0.2361 - accuracy: 0.9286 - val_loss: 0.2378 - val_accuracy: 1.0000
# Epoch 85/1000
# 1/1 [==============================] - 0s 20ms/step - loss: 0.2330 - accuracy: 0.9286 - val_loss: 0.2362 - val_accuracy: 1.0000
# Epoch 86/1000
# 1/1 [==============================] - 0s 20ms/step - loss: 0.2298 - accuracy: 0.9286 - val_loss: 0.2335 - val_accuracy: 1.0000
# Epoch 87/1000
# 1/1 [==============================] - 0s 20ms/step - loss: 0.2263 - accuracy: 0.9286 - val_loss: 0.2294 - val_accuracy: 1.0000
# Epoch 88/1000
# 1/1 [==============================] - 0s 20ms/step - loss: 0.2226 - accuracy: 0.9286 - val_loss: 0.2238 - val_accuracy: 1.0000
# Epoch 89/1000
# 1/1 [==============================] - 0s 21ms/step - loss: 0.2200 - accuracy: 0.9286 - val_loss: 0.2170 - val_accuracy: 1.0000
# Epoch 90/1000
# 1/1 [==============================] - 0s 21ms/step - loss: 0.2179 - accuracy: 0.9286 - val_loss: 0.2073 - val_accuracy: 1.0000
# Epoch 91/1000
# 1/1 [==============================] - 0s 20ms/step - loss: 0.2164 - accuracy: 0.9286 - val_loss: 0.1950 - val_accuracy: 1.0000
# Epoch 92/1000
# 1/1 [==============================] - 0s 20ms/step - loss: 0.2143 - accuracy: 0.9286 - val_loss: 0.1882 - val_accuracy: 1.0000
# Epoch 93/1000
# 1/1 [==============================] - 0s 20ms/step - loss: 0.2121 - accuracy: 0.9286 - val_loss: 0.1867 - val_accuracy: 1.0000
# Epoch 94/1000
# 1/1 [==============================] - 0s 21ms/step - loss: 0.2097 - accuracy: 0.9286 - val_loss: 0.1825 - val_accuracy: 1.0000
# Epoch 95/1000
# 1/1 [==============================] - 0s 20ms/step - loss: 0.2067 - accuracy: 0.9286 - val_loss: 0.1757 - val_accuracy: 1.0000
# Epoch 96/1000
# 1/1 [==============================] - 0s 20ms/step - loss: 0.2036 - accuracy: 1.0000 - val_loss: 0.1665 - val_accuracy: 1.0000
# Epoch 97/1000
# 1/1 [==============================] - 0s 20ms/step - loss: 0.2003 - accuracy: 1.0000 - val_loss: 0.1551 - val_accuracy: 1.0000
# Epoch 98/1000
# 1/1 [==============================] - 0s 21ms/step - loss: 0.1975 - accuracy: 1.0000 - val_loss: 0.1437 - val_accuracy: 1.0000
# Epoch 99/1000
# 1/1 [==============================] - 0s 20ms/step - loss: 0.1954 - accuracy: 1.0000 - val_loss: 0.1376 - val_accuracy: 1.0000
# Epoch 100/1000
# 1/1 [==============================] - 0s 20ms/step - loss: 0.1934 - accuracy: 1.0000 - val_loss: 0.1313 - val_accuracy: 1.0000
# Epoch 101/1000
# 1/1 [==============================] - 0s 21ms/step - loss: 0.1916 - accuracy: 1.0000 - val_loss: 0.1251 - val_accuracy: 1.0000
# Epoch 102/1000
# 1/1 [==============================] - 0s 22ms/step - loss: 0.1884 - accuracy: 1.0000 - val_loss: 0.1189 - val_accuracy: 1.0000
# Epoch 103/1000
# 1/1 [==============================] - 0s 26ms/step - loss: 0.1861 - accuracy: 1.0000 - val_loss: 0.1103 - val_accuracy: 1.0000
# Epoch 104/1000
# 1/1 [==============================] - 0s 26ms/step - loss: 0.1849 - accuracy: 1.0000 - val_loss: 0.1068 - val_accuracy: 1.0000
# Epoch 105/1000
# 1/1 [==============================] - 0s 21ms/step - loss: 0.1814 - accuracy: 1.0000 - val_loss: 0.1079 - val_accuracy: 1.0000
# Epoch 106/1000
# 1/1 [==============================] - 0s 23ms/step - loss: 0.1793 - accuracy: 1.0000 - val_loss: 0.1054 - val_accuracy: 1.0000
# Epoch 107/1000
# 1/1 [==============================] - 0s 21ms/step - loss: 0.1779 - accuracy: 1.0000 - val_loss: 0.1023 - val_accuracy: 1.0000
# Epoch 108/1000
# 1/1 [==============================] - 0s 22ms/step - loss: 0.1761 - accuracy: 1.0000 - val_loss: 0.1015 - val_accuracy: 1.0000
# Epoch 109/1000
# 1/1 [==============================] - 0s 20ms/step - loss: 0.1738 - accuracy: 1.0000 - val_loss: 0.1030 - val_accuracy: 1.0000
# Epoch 110/1000
# 1/1 [==============================] - 0s 36ms/step - loss: 0.1719 - accuracy: 1.0000 - val_loss: 0.1006 - val_accuracy: 1.0000
# Epoch 111/1000
# 1/1 [==============================] - 0s 20ms/step - loss: 0.1701 - accuracy: 1.0000 - val_loss: 0.0950 - val_accuracy: 1.0000
# Epoch 112/1000
# 1/1 [==============================] - 0s 20ms/step - loss: 0.1689 - accuracy: 1.0000 - val_loss: 0.0869 - val_accuracy: 1.0000
# Epoch 113/1000
# 1/1 [==============================] - 0s 20ms/step - loss: 0.1674 - accuracy: 1.0000 - val_loss: 0.0789 - val_accuracy: 1.0000
# Epoch 114/1000
# 1/1 [==============================] - 0s 21ms/step - loss: 0.1655 - accuracy: 1.0000 - val_loss: 0.0683 - val_accuracy: 1.0000
# Epoch 115/1000
# 1/1 [==============================] - 0s 20ms/step - loss: 0.1634 - accuracy: 1.0000 - val_loss: 0.0597 - val_accuracy: 1.0000
# Epoch 116/1000
# 1/1 [==============================] - 0s 21ms/step - loss: 0.1616 - accuracy: 1.0000 - val_loss: 0.0548 - val_accuracy: 1.0000
# Epoch 117/1000
# 1/1 [==============================] - 0s 21ms/step - loss: 0.1603 - accuracy: 1.0000 - val_loss: 0.0570 - val_accuracy: 1.0000
# Epoch 118/1000
# 1/1 [==============================] - 0s 20ms/step - loss: 0.1590 - accuracy: 1.0000 - val_loss: 0.0644 - val_accuracy: 1.0000
# Epoch 119/1000
# 1/1 [==============================] - 0s 19ms/step - loss: 0.1559 - accuracy: 1.0000 - val_loss: 0.0647 - val_accuracy: 1.0000
# Epoch 120/1000
# 1/1 [==============================] - 0s 21ms/step - loss: 0.1542 - accuracy: 1.0000 - val_loss: 0.0601 - val_accuracy: 1.0000
# Epoch 121/1000
# 1/1 [==============================] - 0s 21ms/step - loss: 0.1535 - accuracy: 1.0000 - val_loss: 0.0562 - val_accuracy: 1.0000
# Epoch 122/1000
# 1/1 [==============================] - 0s 21ms/step - loss: 0.1524 - accuracy: 1.0000 - val_loss: 0.0548 - val_accuracy: 1.0000
# Epoch 123/1000
# 1/1 [==============================] - 0s 21ms/step - loss: 0.1495 - accuracy: 1.0000 - val_loss: 0.0597 - val_accuracy: 1.0000
# Epoch 124/1000
# 1/1 [==============================] - 0s 21ms/step - loss: 0.1467 - accuracy: 1.0000 - val_loss: 0.0594 - val_accuracy: 1.0000
# Epoch 125/1000
# 1/1 [==============================] - 0s 20ms/step - loss: 0.1452 - accuracy: 1.0000 - val_loss: 0.0551 - val_accuracy: 1.0000
# Epoch 126/1000
# 1/1 [==============================] - 0s 21ms/step - loss: 0.1437 - accuracy: 1.0000 - val_loss: 0.0466 - val_accuracy: 1.0000
# Epoch 127/1000
# 1/1 [==============================] - 0s 21ms/step - loss: 0.1415 - accuracy: 1.0000 - val_loss: 0.0382 - val_accuracy: 1.0000
# Epoch 128/1000
# 1/1 [==============================] - 0s 21ms/step - loss: 0.1392 - accuracy: 1.0000 - val_loss: 0.0411 - val_accuracy: 1.0000
# Epoch 129/1000
# 1/1 [==============================] - 0s 20ms/step - loss: 0.1367 - accuracy: 1.0000 - val_loss: 0.0499 - val_accuracy: 1.0000
# Epoch 130/1000
# 1/1 [==============================] - 0s 20ms/step - loss: 0.1362 - accuracy: 1.0000 - val_loss: 0.0487 - val_accuracy: 1.0000
# Epoch 131/1000
# 1/1 [==============================] - 0s 20ms/step - loss: 0.1345 - accuracy: 1.0000 - val_loss: 0.0361 - val_accuracy: 1.0000
# Epoch 132/1000
# 1/1 [==============================] - 0s 21ms/step - loss: 0.1318 - accuracy: 1.0000 - val_loss: 0.0229 - val_accuracy: 1.0000
# Epoch 133/1000
# 1/1 [==============================] - 0s 21ms/step - loss: 0.1308 - accuracy: 1.0000 - val_loss: 0.0153 - val_accuracy: 1.0000
# Epoch 134/1000
# 1/1 [==============================] - 0s 21ms/step - loss: 0.1288 - accuracy: 1.0000 - val_loss: 0.0106 - val_accuracy: 1.0000
# Epoch 135/1000
# 1/1 [==============================] - 0s 21ms/step - loss: 0.1264 - accuracy: 1.0000 - val_loss: 0.0086 - val_accuracy: 1.0000
# Epoch 136/1000
# 1/1 [==============================] - 0s 20ms/step - loss: 0.1254 - accuracy: 1.0000 - val_loss: 0.0083 - val_accuracy: 1.0000
# Epoch 137/1000
# 1/1 [==============================] - 0s 21ms/step - loss: 0.1236 - accuracy: 1.0000 - val_loss: 0.0087 - val_accuracy: 1.0000
# Epoch 138/1000
# 1/1 [==============================] - 0s 20ms/step - loss: 0.1213 - accuracy: 1.0000 - val_loss: 0.0076 - val_accuracy: 1.0000
# Epoch 139/1000
# 1/1 [==============================] - 0s 21ms/step - loss: 0.1193 - accuracy: 1.0000 - val_loss: 0.0117 - val_accuracy: 1.0000
# Epoch 140/1000
# 1/1 [==============================] - 0s 21ms/step - loss: 0.1171 - accuracy: 1.0000 - val_loss: 0.0164 - val_accuracy: 1.0000
# Epoch 141/1000
# 1/1 [==============================] - 0s 20ms/step - loss: 0.1159 - accuracy: 1.0000 - val_loss: 0.0182 - val_accuracy: 1.0000
# Epoch 142/1000
# 1/1 [==============================] - 0s 20ms/step - loss: 0.1140 - accuracy: 1.0000 - val_loss: 0.0177 - val_accuracy: 1.0000
# Epoch 143/1000
# 1/1 [==============================] - 0s 21ms/step - loss: 0.1132 - accuracy: 1.0000 - val_loss: 0.0210 - val_accuracy: 1.0000
# Epoch 144/1000
# 1/1 [==============================] - 0s 21ms/step - loss: 0.1109 - accuracy: 1.0000 - val_loss: 0.0305 - val_accuracy: 1.0000
# Epoch 145/1000
# 1/1 [==============================] - 0s 21ms/step - loss: 0.1103 - accuracy: 1.0000 - val_loss: 0.0366 - val_accuracy: 1.0000
# Epoch 146/1000
# 1/1 [==============================] - 0s 20ms/step - loss: 0.1081 - accuracy: 1.0000 - val_loss: 0.0412 - val_accuracy: 1.0000
# Epoch 147/1000
# 1/1 [==============================] - 0s 20ms/step - loss: 0.1070 - accuracy: 1.0000 - val_loss: 0.0465 - val_accuracy: 1.0000
# Epoch 148/1000
# 1/1 [==============================] - 0s 21ms/step - loss: 0.1049 - accuracy: 1.0000 - val_loss: 0.0522 - val_accuracy: 1.0000
# Epoch 149/1000
# 1/1 [==============================] - 0s 21ms/step - loss: 0.1046 - accuracy: 1.0000 - val_loss: 0.0567 - val_accuracy: 1.0000
# Epoch 150/1000
# 1/1 [==============================] - 0s 21ms/step - loss: 0.1031 - accuracy: 1.0000 - val_loss: 0.0617 - val_accuracy: 1.0000
# Epoch 151/1000
# 1/1 [==============================] - 0s 27ms/step - loss: 0.1023 - accuracy: 1.0000 - val_loss: 0.0625 - val_accuracy: 1.0000
# Epoch 152/1000
# 1/1 [==============================] - 0s 21ms/step - loss: 0.1002 - accuracy: 1.0000 - val_loss: 0.0618 - val_accuracy: 1.0000
# Epoch 153/1000
# 1/1 [==============================] - 0s 20ms/step - loss: 0.0992 - accuracy: 1.0000 - val_loss: 0.0646 - val_accuracy: 1.0000
# Epoch 154/1000
# 1/1 [==============================] - 0s 21ms/step - loss: 0.0979 - accuracy: 1.0000 - val_loss: 0.0713 - val_accuracy: 1.0000
# Epoch 155/1000
# 1/1 [==============================] - 0s 20ms/step - loss: 0.0970 - accuracy: 1.0000 - val_loss: 0.0758 - val_accuracy: 1.0000
# Epoch 156/1000
# 1/1 [==============================] - 0s 20ms/step - loss: 0.0952 - accuracy: 1.0000 - val_loss: 0.0824 - val_accuracy: 1.0000
# Epoch 157/1000
# 1/1 [==============================] - 0s 20ms/step - loss: 0.0933 - accuracy: 1.0000 - val_loss: 0.0872 - val_accuracy: 1.0000
# Epoch 158/1000
# 1/1 [==============================] - 0s 20ms/step - loss: 0.0928 - accuracy: 1.0000 - val_loss: 0.0905 - val_accuracy: 1.0000
# Epoch 159/1000
# 1/1 [==============================] - 0s 20ms/step - loss: 0.0921 - accuracy: 1.0000 - val_loss: 0.0930 - val_accuracy: 1.0000
# Epoch 160/1000
# 1/1 [==============================] - 0s 20ms/step - loss: 0.0901 - accuracy: 1.0000 - val_loss: 0.0953 - val_accuracy: 1.0000
# Epoch 161/1000
# 1/1 [==============================] - 0s 20ms/step - loss: 0.0888 - accuracy: 1.0000 - val_loss: 0.0960 - val_accuracy: 1.0000
# Epoch 162/1000
# 1/1 [==============================] - 0s 21ms/step - loss: 0.0879 - accuracy: 1.0000 - val_loss: 0.0952 - val_accuracy: 1.0000
# Epoch 163/1000
# 1/1 [==============================] - 0s 19ms/step - loss: 0.0862 - accuracy: 1.0000 - val_loss: 0.0996 - val_accuracy: 1.0000
# Epoch 164/1000
# 1/1 [==============================] - 0s 20ms/step - loss: 0.0846 - accuracy: 1.0000 - val_loss: 0.1073 - val_accuracy: 1.0000
# Epoch 165/1000
# 1/1 [==============================] - 0s 20ms/step - loss: 0.0836 - accuracy: 1.0000 - val_loss: 0.1164 - val_accuracy: 1.0000
# Epoch 166/1000
# 1/1 [==============================] - 0s 21ms/step - loss: 0.0823 - accuracy: 1.0000 - val_loss: 0.1195 - val_accuracy: 1.0000
# Epoch 167/1000
# 1/1 [==============================] - 0s 21ms/step - loss: 0.0813 - accuracy: 1.0000 - val_loss: 0.1179 - val_accuracy: 1.0000
# Epoch 168/1000
# 1/1 [==============================] - 0s 19ms/step - loss: 0.0802 - accuracy: 1.0000 - val_loss: 0.1192 - val_accuracy: 1.0000
# Epoch 169/1000
# 1/1 [==============================] - 0s 21ms/step - loss: 0.0780 - accuracy: 1.0000 - val_loss: 0.1199 - val_accuracy: 1.0000
# Epoch 170/1000
# 1/1 [==============================] - 0s 21ms/step - loss: 0.0774 - accuracy: 1.0000 - val_loss: 0.1284 - val_accuracy: 1.0000
# Epoch 171/1000
# 1/1 [==============================] - 0s 21ms/step - loss: 0.0764 - accuracy: 1.0000 - val_loss: 0.1337 - val_accuracy: 1.0000
# Epoch 172/1000
# 1/1 [==============================] - 0s 21ms/step - loss: 0.0763 - accuracy: 1.0000 - val_loss: 0.1307 - val_accuracy: 1.0000
# Epoch 173/1000
# 1/1 [==============================] - 0s 20ms/step - loss: 0.0748 - accuracy: 1.0000 - val_loss: 0.1329 - val_accuracy: 1.0000
# Epoch 174/1000
# 1/1 [==============================] - 0s 20ms/step - loss: 0.0732 - accuracy: 1.0000 - val_loss: 0.1454 - val_accuracy: 1.0000
# Epoch 175/1000
# 1/1 [==============================] - 0s 20ms/step - loss: 0.0738 - accuracy: 1.0000 - val_loss: 0.1414 - val_accuracy: 1.0000
# Epoch 176/1000
# 1/1 [==============================] - 0s 19ms/step - loss: 0.0725 - accuracy: 1.0000 - val_loss: 0.1306 - val_accuracy: 1.0000
# Epoch 177/1000
# 1/1 [==============================] - 0s 20ms/step - loss: 0.0731 - accuracy: 1.0000 - val_loss: 0.1361 - val_accuracy: 1.0000
# Epoch 178/1000
# 1/1 [==============================] - 0s 20ms/step - loss: 0.0696 - accuracy: 1.0000 - val_loss: 0.1447 - val_accuracy: 1.0000
# Epoch 179/1000
# 1/1 [==============================] - 0s 19ms/step - loss: 0.0704 - accuracy: 1.0000 - val_loss: 0.1451 - val_accuracy: 1.0000
# Epoch 180/1000
# 1/1 [==============================] - 0s 20ms/step - loss: 0.0678 - accuracy: 1.0000 - val_loss: 0.1475 - val_accuracy: 1.0000
# Epoch 181/1000
# 1/1 [==============================] - 0s 20ms/step - loss: 0.0669 - accuracy: 1.0000 - val_loss: 0.1462 - val_accuracy: 1.0000
# Epoch 182/1000
# 1/1 [==============================] - 0s 20ms/step - loss: 0.0665 - accuracy: 1.0000 - val_loss: 0.1530 - val_accuracy: 1.0000
# Epoch 183/1000
# 1/1 [==============================] - 0s 20ms/step - loss: 0.0656 - accuracy: 1.0000 - val_loss: 0.1485 - val_accuracy: 1.0000
# Epoch 184/1000
# 1/1 [==============================] - 0s 19ms/step - loss: 0.0645 - accuracy: 1.0000 - val_loss: 0.1334 - val_accuracy: 1.0000
# Epoch 185/1000
# 1/1 [==============================] - 0s 19ms/step - loss: 0.0650 - accuracy: 1.0000 - val_loss: 0.1317 - val_accuracy: 1.0000
# Epoch 186/1000
# 1/1 [==============================] - 0s 20ms/step - loss: 0.0645 - accuracy: 1.0000 - val_loss: 0.1444 - val_accuracy: 1.0000
# Epoch 187/1000
# 1/1 [==============================] - 0s 20ms/step - loss: 0.0617 - accuracy: 1.0000 - val_loss: 0.1616 - val_accuracy: 1.0000
# Epoch 188/1000
# 1/1 [==============================] - 0s 20ms/step - loss: 0.0622 - accuracy: 1.0000 - val_loss: 0.1636 - val_accuracy: 1.0000
# Epoch 189/1000
# 1/1 [==============================] - 0s 20ms/step - loss: 0.0613 - accuracy: 1.0000 - val_loss: 0.1615 - val_accuracy: 1.0000
# Epoch 190/1000
# 1/1 [==============================] - 0s 20ms/step - loss: 0.0610 - accuracy: 1.0000 - val_loss: 0.1566 - val_accuracy: 1.0000
# Epoch 191/1000
# 1/1 [==============================] - 0s 20ms/step - loss: 0.0589 - accuracy: 1.0000 - val_loss: 0.1588 - val_accuracy: 1.0000
# Epoch 192/1000
# 1/1 [==============================] - 0s 20ms/step - loss: 0.0582 - accuracy: 1.0000 - val_loss: 0.1516 - val_accuracy: 1.0000
# Epoch 193/1000
# 1/1 [==============================] - 0s 20ms/step - loss: 0.0579 - accuracy: 1.0000 - val_loss: 0.1497 - val_accuracy: 1.0000
# Epoch 194/1000
# 1/1 [==============================] - 0s 20ms/step - loss: 0.0557 - accuracy: 1.0000 - val_loss: 0.1557 - val_accuracy: 1.0000
# Epoch 195/1000
# 1/1 [==============================] - 0s 20ms/step - loss: 0.0548 - accuracy: 1.0000 - val_loss: 0.1513 - val_accuracy: 1.0000
# Epoch 196/1000
# 1/1 [==============================] - 0s 20ms/step - loss: 0.0549 - accuracy: 1.0000 - val_loss: 0.1476 - val_accuracy: 1.0000
# Epoch 197/1000
# 1/1 [==============================] - 0s 20ms/step - loss: 0.0544 - accuracy: 1.0000 - val_loss: 0.1530 - val_accuracy: 1.0000
# Epoch 198/1000
# 1/1 [==============================] - 0s 20ms/step - loss: 0.0525 - accuracy: 1.0000 - val_loss: 0.1591 - val_accuracy: 1.0000
# Epoch 199/1000
# 1/1 [==============================] - 0s 19ms/step - loss: 0.0529 - accuracy: 1.0000 - val_loss: 0.1515 - val_accuracy: 1.0000
# Epoch 200/1000
# 1/1 [==============================] - 0s 20ms/step - loss: 0.0514 - accuracy: 1.0000 - val_loss: 0.1551 - val_accuracy: 1.0000
# Epoch 201/1000
# 1/1 [==============================] - 0s 20ms/step - loss: 0.0493 - accuracy: 1.0000 - val_loss: 0.1636 - val_accuracy: 1.0000
# Epoch 202/1000
# 1/1 [==============================] - 0s 19ms/step - loss: 0.0489 - accuracy: 1.0000 - val_loss: 0.1702 - val_accuracy: 1.0000
# Epoch 203/1000
# 1/1 [==============================] - 0s 20ms/step - loss: 0.0480 - accuracy: 1.0000 - val_loss: 0.1679 - val_accuracy: 1.0000
# Epoch 204/1000
# 1/1 [==============================] - 0s 19ms/step - loss: 0.0465 - accuracy: 1.0000 - val_loss: 0.1577 - val_accuracy: 1.0000
# Epoch 205/1000
# 1/1 [==============================] - 0s 19ms/step - loss: 0.0462 - accuracy: 1.0000 - val_loss: 0.1496 - val_accuracy: 1.0000
# Epoch 206/1000
# 1/1 [==============================] - 0s 19ms/step - loss: 0.0462 - accuracy: 1.0000 - val_loss: 0.1569 - val_accuracy: 1.0000
# Epoch 207/1000
# 1/1 [==============================] - 0s 19ms/step - loss: 0.0449 - accuracy: 1.0000 - val_loss: 0.1648 - val_accuracy: 1.0000
# Epoch 208/1000
# 1/1 [==============================] - 0s 21ms/step - loss: 0.0432 - accuracy: 1.0000 - val_loss: 0.1752 - val_accuracy: 1.0000
# Epoch 209/1000
# 1/1 [==============================] - 0s 20ms/step - loss: 0.0435 - accuracy: 1.0000 - val_loss: 0.1724 - val_accuracy: 1.0000
# Epoch 210/1000
# 1/1 [==============================] - 0s 20ms/step - loss: 0.0430 - accuracy: 1.0000 - val_loss: 0.1638 - val_accuracy: 1.0000
# Epoch 211/1000
# 1/1 [==============================] - 0s 20ms/step - loss: 0.0420 - accuracy: 1.0000 - val_loss: 0.1530 - val_accuracy: 1.0000
# Epoch 212/1000
# 1/1 [==============================] - 0s 20ms/step - loss: 0.0417 - accuracy: 1.0000 - val_loss: 0.1525 - val_accuracy: 1.0000
# Epoch 213/1000
# 1/1 [==============================] - 0s 20ms/step - loss: 0.0408 - accuracy: 1.0000 - val_loss: 0.1589 - val_accuracy: 1.0000
# Epoch 214/1000
# 1/1 [==============================] - 0s 20ms/step - loss: 0.0392 - accuracy: 1.0000 - val_loss: 0.1588 - val_accuracy: 1.0000
# Epoch 215/1000
# 1/1 [==============================] - 0s 20ms/step - loss: 0.0389 - accuracy: 1.0000 - val_loss: 0.1549 - val_accuracy: 1.0000
# Epoch 216/1000
# 1/1 [==============================] - 0s 21ms/step - loss: 0.0378 - accuracy: 1.0000 - val_loss: 0.1538 - val_accuracy: 1.0000
# Epoch 217/1000
# 1/1 [==============================] - 0s 20ms/step - loss: 0.0372 - accuracy: 1.0000 - val_loss: 0.1494 - val_accuracy: 1.0000
# Epoch 218/1000
# 1/1 [==============================] - 0s 20ms/step - loss: 0.0361 - accuracy: 1.0000 - val_loss: 0.1462 - val_accuracy: 1.0000
# Epoch 219/1000
# 1/1 [==============================] - 0s 20ms/step - loss: 0.0368 - accuracy: 1.0000 - val_loss: 0.1523 - val_accuracy: 1.0000
# Epoch 220/1000
# 1/1 [==============================] - 0s 20ms/step - loss: 0.0357 - accuracy: 1.0000 - val_loss: 0.1599 - val_accuracy: 1.0000
# Epoch 221/1000
# 1/1 [==============================] - 0s 20ms/step - loss: 0.0353 - accuracy: 1.0000 - val_loss: 0.1602 - val_accuracy: 1.0000
# Epoch 222/1000
# 1/1 [==============================] - 0s 20ms/step - loss: 0.0348 - accuracy: 1.0000 - val_loss: 0.1507 - val_accuracy: 1.0000
# Epoch 223/1000
# 1/1 [==============================] - 0s 20ms/step - loss: 0.0345 - accuracy: 1.0000 - val_loss: 0.1416 - val_accuracy: 1.0000
# Epoch 224/1000
# 1/1 [==============================] - 0s 20ms/step - loss: 0.0328 - accuracy: 1.0000 - val_loss: 0.1413 - val_accuracy: 1.0000
# Epoch 225/1000
# 1/1 [==============================] - 0s 20ms/step - loss: 0.0339 - accuracy: 1.0000 - val_loss: 0.1392 - val_accuracy: 1.0000
# Epoch 226/1000
# 1/1 [==============================] - 0s 20ms/step - loss: 0.0327 - accuracy: 1.0000 - val_loss: 0.1438 - val_accuracy: 1.0000
# Epoch 227/1000
# 1/1 [==============================] - 0s 21ms/step - loss: 0.0318 - accuracy: 1.0000 - val_loss: 0.1578 - val_accuracy: 1.0000
# Epoch 228/1000
# 1/1 [==============================] - 0s 20ms/step - loss: 0.0308 - accuracy: 1.0000 - val_loss: 0.1631 - val_accuracy: 1.0000
# Epoch 229/1000
# 1/1 [==============================] - 0s 20ms/step - loss: 0.0322 - accuracy: 1.0000 - val_loss: 0.1594 - val_accuracy: 1.0000
# Epoch 230/1000
# 1/1 [==============================] - 0s 20ms/step - loss: 0.0296 - accuracy: 1.0000 - val_loss: 0.1539 - val_accuracy: 1.0000
# Epoch 231/1000
# 1/1 [==============================] - 0s 20ms/step - loss: 0.0292 - accuracy: 1.0000 - val_loss: 0.1474 - val_accuracy: 1.0000
# Epoch 232/1000
# 1/1 [==============================] - 0s 19ms/step - loss: 0.0294 - accuracy: 1.0000 - val_loss: 0.1442 - val_accuracy: 1.0000
# Epoch 233/1000
# 1/1 [==============================] - 0s 19ms/step - loss: 0.0288 - accuracy: 1.0000 - val_loss: 0.1450 - val_accuracy: 1.0000
# Epoch 234/1000
# 1/1 [==============================] - 0s 20ms/step - loss: 0.0276 - accuracy: 1.0000 - val_loss: 0.1472 - val_accuracy: 1.0000
# Epoch 235/1000
# 1/1 [==============================] - 0s 19ms/step - loss: 0.0275 - accuracy: 1.0000 - val_loss: 0.1428 - val_accuracy: 1.0000
# Epoch 236/1000
# 1/1 [==============================] - 0s 20ms/step - loss: 0.0265 - accuracy: 1.0000 - val_loss: 0.1358 - val_accuracy: 1.0000
# Epoch 237/1000
# 1/1 [==============================] - 0s 20ms/step - loss: 0.0262 - accuracy: 1.0000 - val_loss: 0.1242 - val_accuracy: 1.0000
# Epoch 238/1000
# 1/1 [==============================] - 0s 20ms/step - loss: 0.0270 - accuracy: 1.0000 - val_loss: 0.1187 - val_accuracy: 1.0000
# Epoch 239/1000
# 1/1 [==============================] - 0s 21ms/step - loss: 0.0267 - accuracy: 1.0000 - val_loss: 0.1272 - val_accuracy: 1.0000
# Epoch 240/1000
# 1/1 [==============================] - 0s 29ms/step - loss: 0.0251 - accuracy: 1.0000 - val_loss: 0.1416 - val_accuracy: 1.0000
# Epoch 241/1000
# 1/1 [==============================] - 0s 22ms/step - loss: 0.0258 - accuracy: 1.0000 - val_loss: 0.1507 - val_accuracy: 1.0000
# Epoch 242/1000
# 1/1 [==============================] - 0s 22ms/step - loss: 0.0265 - accuracy: 1.0000 - val_loss: 0.1477 - val_accuracy: 1.0000
# Epoch 243/1000
# 1/1 [==============================] - 0s 20ms/step - loss: 0.0253 - accuracy: 1.0000 - val_loss: 0.1403 - val_accuracy: 1.0000
# Epoch 244/1000
# 1/1 [==============================] - 0s 20ms/step - loss: 0.0260 - accuracy: 1.0000 - val_loss: 0.1319 - val_accuracy: 1.0000
# Epoch 245/1000
# 1/1 [==============================] - 0s 21ms/step - loss: 0.0259 - accuracy: 1.0000 - val_loss: 0.1255 - val_accuracy: 1.0000
# Epoch 246/1000
# 1/1 [==============================] - 0s 21ms/step - loss: 0.0255 - accuracy: 1.0000 - val_loss: 0.1181 - val_accuracy: 1.0000
# Epoch 247/1000
# 1/1 [==============================] - 0s 20ms/step - loss: 0.0252 - accuracy: 1.0000 - val_loss: 0.1162 - val_accuracy: 1.0000
# Epoch 248/1000
# 1/1 [==============================] - 0s 21ms/step - loss: 0.0233 - accuracy: 1.0000 - val_loss: 0.1191 - val_accuracy: 1.0000
# Epoch 249/1000
# 1/1 [==============================] - 0s 20ms/step - loss: 0.0243 - accuracy: 1.0000 - val_loss: 0.1219 - val_accuracy: 1.0000
# Epoch 250/1000
# 1/1 [==============================] - 0s 20ms/step - loss: 0.0242 - accuracy: 1.0000 - val_loss: 0.1295 - val_accuracy: 1.0000
# Epoch 251/1000
# 1/1 [==============================] - 0s 21ms/step - loss: 0.0244 - accuracy: 1.0000 - val_loss: 0.1221 - val_accuracy: 1.0000
# Epoch 252/1000
# 1/1 [==============================] - 0s 20ms/step - loss: 0.0246 - accuracy: 1.0000 - val_loss: 0.1169 - val_accuracy: 1.0000
# Epoch 253/1000
# 1/1 [==============================] - 0s 22ms/step - loss: 0.0241 - accuracy: 1.0000 - val_loss: 0.1199 - val_accuracy: 1.0000
# Epoch 254/1000
# 1/1 [==============================] - 0s 20ms/step - loss: 0.0242 - accuracy: 1.0000 - val_loss: 0.1300 - val_accuracy: 1.0000
# Epoch 255/1000
# 1/1 [==============================] - 0s 20ms/step - loss: 0.0237 - accuracy: 1.0000 - val_loss: 0.1345 - val_accuracy: 1.0000
# Epoch 256/1000
# 1/1 [==============================] - 0s 20ms/step - loss: 0.0245 - accuracy: 1.0000 - val_loss: 0.1303 - val_accuracy: 1.0000
# Epoch 257/1000
# 1/1 [==============================] - 0s 19ms/step - loss: 0.0228 - accuracy: 1.0000 - val_loss: 0.1202 - val_accuracy: 1.0000
# Epoch 258/1000
# 1/1 [==============================] - 0s 20ms/step - loss: 0.0229 - accuracy: 1.0000 - val_loss: 0.1169 - val_accuracy: 1.0000
# Epoch 259/1000
# 1/1 [==============================] - 0s 20ms/step - loss: 0.0226 - accuracy: 1.0000 - val_loss: 0.1133 - val_accuracy: 1.0000
# Epoch 260/1000
# 1/1 [==============================] - 0s 20ms/step - loss: 0.0227 - accuracy: 1.0000 - val_loss: 0.1076 - val_accuracy: 1.0000
# Epoch 261/1000
# 1/1 [==============================] - 0s 20ms/step - loss: 0.0223 - accuracy: 1.0000 - val_loss: 0.1073 - val_accuracy: 1.0000
# Epoch 262/1000
# 1/1 [==============================] - 0s 20ms/step - loss: 0.0206 - accuracy: 1.0000 - val_loss: 0.1064 - val_accuracy: 1.0000
# Epoch 263/1000
# 1/1 [==============================] - 0s 20ms/step - loss: 0.0202 - accuracy: 1.0000 - val_loss: 0.1023 - val_accuracy: 1.0000
# Epoch 264/1000
# 1/1 [==============================] - 0s 20ms/step - loss: 0.0209 - accuracy: 1.0000 - val_loss: 0.1076 - val_accuracy: 1.0000
# Epoch 265/1000
# 1/1 [==============================] - 0s 19ms/step - loss: 0.0204 - accuracy: 1.0000 - val_loss: 0.1070 - val_accuracy: 1.0000
# Epoch 266/1000
# 1/1 [==============================] - 0s 19ms/step - loss: 0.0212 - accuracy: 1.0000 - val_loss: 0.1005 - val_accuracy: 1.0000
# Epoch 267/1000
# 1/1 [==============================] - 0s 20ms/step - loss: 0.0208 - accuracy: 1.0000 - val_loss: 0.0984 - val_accuracy: 1.0000
# Epoch 268/1000
# 1/1 [==============================] - 0s 20ms/step - loss: 0.0204 - accuracy: 1.0000 - val_loss: 0.1076 - val_accuracy: 1.0000
# Epoch 269/1000
# 1/1 [==============================] - 0s 20ms/step - loss: 0.0204 - accuracy: 1.0000 - val_loss: 0.1062 - val_accuracy: 1.0000
# Epoch 270/1000
# 1/1 [==============================] - 0s 20ms/step - loss: 0.0194 - accuracy: 1.0000 - val_loss: 0.1056 - val_accuracy: 1.0000
# Epoch 271/1000
# 1/1 [==============================] - 0s 25ms/step - loss: 0.0189 - accuracy: 1.0000 - val_loss: 0.1012 - val_accuracy: 1.0000
# Epoch 272/1000
# 1/1 [==============================] - 0s 20ms/step - loss: 0.0196 - accuracy: 1.0000 - val_loss: 0.1002 - val_accuracy: 1.0000
# Epoch 273/1000
# 1/1 [==============================] - 0s 20ms/step - loss: 0.0200 - accuracy: 1.0000 - val_loss: 0.1037 - val_accuracy: 1.0000
# Epoch 274/1000
# 1/1 [==============================] - 0s 20ms/step - loss: 0.0213 - accuracy: 1.0000 - val_loss: 0.1004 - val_accuracy: 1.0000
# Epoch 275/1000
# 1/1 [==============================] - 0s 20ms/step - loss: 0.0200 - accuracy: 1.0000 - val_loss: 0.0934 - val_accuracy: 1.0000
# Epoch 276/1000
# 1/1 [==============================] - 0s 20ms/step - loss: 0.0201 - accuracy: 1.0000 - val_loss: 0.0976 - val_accuracy: 1.0000
# Epoch 277/1000
# 1/1 [==============================] - 0s 20ms/step - loss: 0.0180 - accuracy: 1.0000 - val_loss: 0.1059 - val_accuracy: 1.0000
# Epoch 278/1000
# 1/1 [==============================] - 0s 20ms/step - loss: 0.0179 - accuracy: 1.0000 - val_loss: 0.1007 - val_accuracy: 1.0000
# Epoch 279/1000
# 1/1 [==============================] - 0s 20ms/step - loss: 0.0182 - accuracy: 1.0000 - val_loss: 0.0959 - val_accuracy: 1.0000
# Epoch 280/1000
# 1/1 [==============================] - 0s 20ms/step - loss: 0.0198 - accuracy: 1.0000 - val_loss: 0.1014 - val_accuracy: 1.0000
# Epoch 281/1000
# 1/1 [==============================] - 0s 20ms/step - loss: 0.0196 - accuracy: 1.0000 - val_loss: 0.1133 - val_accuracy: 1.0000
# Epoch 282/1000
# 1/1 [==============================] - 0s 20ms/step - loss: 0.0188 - accuracy: 1.0000 - val_loss: 0.1110 - val_accuracy: 1.0000
# Epoch 283/1000
# 1/1 [==============================] - 0s 20ms/step - loss: 0.0188 - accuracy: 1.0000 - val_loss: 0.0951 - val_accuracy: 1.0000
# Epoch 284/1000
# 1/1 [==============================] - 0s 20ms/step - loss: 0.0167 - accuracy: 1.0000 - val_loss: 0.0932 - val_accuracy: 1.0000
# Epoch 285/1000
# 1/1 [==============================] - 0s 20ms/step - loss: 0.0181 - accuracy: 1.0000 - val_loss: 0.0977 - val_accuracy: 1.0000
# Epoch 286/1000
# 1/1 [==============================] - 0s 21ms/step - loss: 0.0177 - accuracy: 1.0000 - val_loss: 0.1059 - val_accuracy: 1.0000
# Epoch 287/1000
# 1/1 [==============================] - 0s 21ms/step - loss: 0.0173 - accuracy: 1.0000 - val_loss: 0.1100 - val_accuracy: 1.0000
# Epoch 288/1000
# 1/1 [==============================] - 0s 20ms/step - loss: 0.0178 - accuracy: 1.0000 - val_loss: 0.0994 - val_accuracy: 1.0000
# Epoch 289/1000
# 1/1 [==============================] - 0s 20ms/step - loss: 0.0163 - accuracy: 1.0000 - val_loss: 0.0950 - val_accuracy: 1.0000
# Epoch 290/1000
# 1/1 [==============================] - 0s 20ms/step - loss: 0.0168 - accuracy: 1.0000 - val_loss: 0.0924 - val_accuracy: 1.0000
# Epoch 291/1000
# 1/1 [==============================] - 0s 19ms/step - loss: 0.0178 - accuracy: 1.0000 - val_loss: 0.0986 - val_accuracy: 1.0000
# Epoch 292/1000
# 1/1 [==============================] - 0s 20ms/step - loss: 0.0154 - accuracy: 1.0000 - val_loss: 0.0990 - val_accuracy: 1.0000
# Epoch 293/1000
# 1/1 [==============================] - 0s 19ms/step - loss: 0.0181 - accuracy: 1.0000 - val_loss: 0.1052 - val_accuracy: 1.0000
# Epoch 294/1000
# 1/1 [==============================] - 0s 20ms/step - loss: 0.0193 - accuracy: 1.0000 - val_loss: 0.1049 - val_accuracy: 1.0000
# Epoch 295/1000
# 1/1 [==============================] - 0s 20ms/step - loss: 0.0185 - accuracy: 1.0000 - val_loss: 0.1030 - val_accuracy: 1.0000
# Epoch 296/1000
# 1/1 [==============================] - 0s 20ms/step - loss: 0.0179 - accuracy: 1.0000 - val_loss: 0.0989 - val_accuracy: 1.0000
# Epoch 297/1000
# 1/1 [==============================] - 0s 19ms/step - loss: 0.0178 - accuracy: 1.0000 - val_loss: 0.0950 - val_accuracy: 1.0000
# Epoch 298/1000
# 1/1 [==============================] - 0s 20ms/step - loss: 0.0190 - accuracy: 1.0000 - val_loss: 0.0891 - val_accuracy: 1.0000
# Epoch 299/1000
# 1/1 [==============================] - 0s 21ms/step - loss: 0.0168 - accuracy: 1.0000 - val_loss: 0.0849 - val_accuracy: 1.0000
# Epoch 300/1000
# 1/1 [==============================] - 0s 19ms/step - loss: 0.0156 - accuracy: 1.0000 - val_loss: 0.0955 - val_accuracy: 1.0000
# Epoch 301/1000
# 1/1 [==============================] - 0s 19ms/step - loss: 0.0152 - accuracy: 1.0000 - val_loss: 0.0912 - val_accuracy: 1.0000
# Epoch 302/1000
# 1/1 [==============================] - 0s 20ms/step - loss: 0.0147 - accuracy: 1.0000 - val_loss: 0.0874 - val_accuracy: 1.0000
# Epoch 303/1000
# 1/1 [==============================] - 0s 20ms/step - loss: 0.0142 - accuracy: 1.0000 - val_loss: 0.0907 - val_accuracy: 1.0000
# Epoch 304/1000
# 1/1 [==============================] - 0s 20ms/step - loss: 0.0141 - accuracy: 1.0000 - val_loss: 0.0954 - val_accuracy: 1.0000
# Epoch 305/1000
# 1/1 [==============================] - 0s 19ms/step - loss: 0.0136 - accuracy: 1.0000 - val_loss: 0.0967 - val_accuracy: 1.0000
# Epoch 306/1000
# 1/1 [==============================] - 0s 20ms/step - loss: 0.0139 - accuracy: 1.0000 - val_loss: 0.0993 - val_accuracy: 1.0000
# Epoch 307/1000
# 1/1 [==============================] - 0s 20ms/step - loss: 0.0150 - accuracy: 1.0000 - val_loss: 0.0953 - val_accuracy: 1.0000
# Epoch 308/1000
# 1/1 [==============================] - 0s 20ms/step - loss: 0.0142 - accuracy: 1.0000 - val_loss: 0.0848 - val_accuracy: 1.0000
# Epoch 309/1000
# 1/1 [==============================] - 0s 20ms/step - loss: 0.0135 - accuracy: 1.0000 - val_loss: 0.0801 - val_accuracy: 1.0000
# Epoch 310/1000
# 1/1 [==============================] - 0s 20ms/step - loss: 0.0142 - accuracy: 1.0000 - val_loss: 0.0833 - val_accuracy: 1.0000
# Epoch 311/1000
# 1/1 [==============================] - 0s 20ms/step - loss: 0.0128 - accuracy: 1.0000 - val_loss: 0.0915 - val_accuracy: 1.0000
# Epoch 312/1000
# 1/1 [==============================] - 0s 19ms/step - loss: 0.0130 - accuracy: 1.0000 - val_loss: 0.0957 - val_accuracy: 1.0000
# Epoch 313/1000
# 1/1 [==============================] - 0s 19ms/step - loss: 0.0119 - accuracy: 1.0000 - val_loss: 0.0947 - val_accuracy: 1.0000
# Epoch 314/1000
# 1/1 [==============================] - 0s 20ms/step - loss: 0.0133 - accuracy: 1.0000 - val_loss: 0.0931 - val_accuracy: 1.0000
# Epoch 315/1000
# 1/1 [==============================] - 0s 20ms/step - loss: 0.0131 - accuracy: 1.0000 - val_loss: 0.0951 - val_accuracy: 1.0000
# Epoch 316/1000
# 1/1 [==============================] - 0s 20ms/step - loss: 0.0119 - accuracy: 1.0000 - val_loss: 0.0928 - val_accuracy: 1.0000
# Epoch 317/1000
# 1/1 [==============================] - 0s 19ms/step - loss: 0.0133 - accuracy: 1.0000 - val_loss: 0.0982 - val_accuracy: 1.0000
# Epoch 318/1000
# 1/1 [==============================] - 0s 19ms/step - loss: 0.0153 - accuracy: 1.0000 - val_loss: 0.0886 - val_accuracy: 1.0000
# Epoch 319/1000
# 1/1 [==============================] - 0s 20ms/step - loss: 0.0135 - accuracy: 1.0000 - val_loss: 0.0873 - val_accuracy: 1.0000
# Epoch 320/1000
# 1/1 [==============================] - 0s 20ms/step - loss: 0.0126 - accuracy: 1.0000 - val_loss: 0.0913 - val_accuracy: 1.0000
# Epoch 321/1000
# 1/1 [==============================] - 0s 19ms/step - loss: 0.0136 - accuracy: 1.0000 - val_loss: 0.0958 - val_accuracy: 1.0000
# Epoch 322/1000
# 1/1 [==============================] - 0s 20ms/step - loss: 0.0124 - accuracy: 1.0000 - val_loss: 0.0955 - val_accuracy: 1.0000
# Epoch 323/1000
# 1/1 [==============================] - 0s 19ms/step - loss: 0.0143 - accuracy: 1.0000 - val_loss: 0.0938 - val_accuracy: 1.0000
# Epoch 324/1000
# 1/1 [==============================] - 0s 19ms/step - loss: 0.0127 - accuracy: 1.0000 - val_loss: 0.0906 - val_accuracy: 1.0000
# Epoch 325/1000
# 1/1 [==============================] - 0s 19ms/step - loss: 0.0130 - accuracy: 1.0000 - val_loss: 0.0873 - val_accuracy: 1.0000
# Epoch 326/1000
# 1/1 [==============================] - 0s 20ms/step - loss: 0.0135 - accuracy: 1.0000 - val_loss: 0.0881 - val_accuracy: 1.0000
# Epoch 327/1000
# 1/1 [==============================] - 0s 20ms/step - loss: 0.0110 - accuracy: 1.0000 - val_loss: 0.0874 - val_accuracy: 1.0000
# Epoch 328/1000
# 1/1 [==============================] - 0s 19ms/step - loss: 0.0137 - accuracy: 1.0000 - val_loss: 0.0871 - val_accuracy: 1.0000
# Epoch 329/1000
# 1/1 [==============================] - 0s 19ms/step - loss: 0.0128 - accuracy: 1.0000 - val_loss: 0.0852 - val_accuracy: 1.0000
# Epoch 330/1000
# 1/1 [==============================] - 0s 21ms/step - loss: 0.0119 - accuracy: 1.0000 - val_loss: 0.0889 - val_accuracy: 1.0000
# Epoch 331/1000
# 1/1 [==============================] - 0s 20ms/step - loss: 0.0120 - accuracy: 1.0000 - val_loss: 0.0934 - val_accuracy: 1.0000
# Epoch 332/1000
# 1/1 [==============================] - 0s 19ms/step - loss: 0.0113 - accuracy: 1.0000 - val_loss: 0.0945 - val_accuracy: 1.0000
# Epoch 333/1000
# 1/1 [==============================] - 0s 20ms/step - loss: 0.0133 - accuracy: 1.0000 - val_loss: 0.0949 - val_accuracy: 1.0000
# Epoch 334/1000
# 1/1 [==============================] - 0s 20ms/step - loss: 0.0114 - accuracy: 1.0000 - val_loss: 0.0902 - val_accuracy: 1.0000
# Epoch 335/1000
# 1/1 [==============================] - 0s 20ms/step - loss: 0.0124 - accuracy: 1.0000 - val_loss: 0.0879 - val_accuracy: 1.0000
# Epoch 336/1000
# ...
# Epoch 890/1000
# 1/1 [==============================] - 0s 21ms/step - loss: 0.0062 - accuracy: 1.0000 - val_loss: 0.0850 - val_accuracy: 1.0000
# Epoch 891/1000
# 1/1 [==============================] - 0s 21ms/step - loss: 0.0035 - accuracy: 1.0000 - val_loss: 0.0865 - val_accuracy: 1.0000
# Epoch 892/1000
# 1/1 [==============================] - 0s 21ms/step - loss: 0.0052 - accuracy: 1.0000 - val_loss: 0.0901 - val_accuracy: 1.0000
# Epoch 893/1000
# 1/1 [==============================] - 0s 20ms/step - loss: 0.0041 - accuracy: 1.0000 - val_loss: 0.0953 - val_accuracy: 1.0000
# Epoch 894/1000
# 1/1 [==============================] - 0s 21ms/step - loss: 0.0044 - accuracy: 1.0000 - val_loss: 0.0971 - val_accuracy: 1.0000
# Epoch 895/1000
# 1/1 [==============================] - 0s 20ms/step - loss: 0.0060 - accuracy: 1.0000 - val_loss: 0.0947 - val_accuracy: 1.0000
# Epoch 896/1000
# 1/1 [==============================] - 0s 20ms/step - loss: 0.0045 - accuracy: 1.0000 - val_loss: 0.0886 - val_accuracy: 1.0000
# Epoch 897/1000
# 1/1 [==============================] - 0s 20ms/step - loss: 0.0057 - accuracy: 1.0000 - val_loss: 0.0856 - val_accuracy: 1.0000
# Epoch 898/1000
# 1/1 [==============================] - 0s 20ms/step - loss: 0.0061 - accuracy: 1.0000 - val_loss: 0.0891 - val_accuracy: 1.0000
# Epoch 899/1000
# 1/1 [==============================] - 0s 20ms/step - loss: 0.0046 - accuracy: 1.0000 - val_loss: 0.0899 - val_accuracy: 1.0000
# Epoch 900/1000
# 1/1 [==============================] - 0s 23ms/step - loss: 0.0057 - accuracy: 1.0000 - val_loss: 0.0902 - val_accuracy: 1.0000
# Epoch 901/1000
# 1/1 [==============================] - 0s 20ms/step - loss: 0.0043 - accuracy: 1.0000 - val_loss: 0.0891 - val_accuracy: 1.0000
# Epoch 902/1000
# 1/1 [==============================] - 0s 20ms/step - loss: 0.0034 - accuracy: 1.0000 - val_loss: 0.0867 - val_accuracy: 1.0000
# Epoch 903/1000
# 1/1 [==============================] - 0s 19ms/step - loss: 0.0049 - accuracy: 1.0000 - val_loss: 0.0862 - val_accuracy: 1.0000
# Epoch 904/1000
# 1/1 [==============================] - 0s 20ms/step - loss: 0.0048 - accuracy: 1.0000 - val_loss: 0.0870 - val_accuracy: 1.0000
# Epoch 905/1000
# 1/1 [==============================] - 0s 20ms/step - loss: 0.0036 - accuracy: 1.0000 - val_loss: 0.0922 - val_accuracy: 1.0000
# Epoch 906/1000
# 1/1 [==============================] - 0s 19ms/step - loss: 0.0047 - accuracy: 1.0000 - val_loss: 0.0958 - val_accuracy: 1.0000
# Epoch 907/1000
# 1/1 [==============================] - 0s 21ms/step - loss: 0.0038 - accuracy: 1.0000 - val_loss: 0.0941 - val_accuracy: 1.0000
# Epoch 908/1000
# 1/1 [==============================] - 0s 20ms/step - loss: 0.0047 - accuracy: 1.0000 - val_loss: 0.0889 - val_accuracy: 1.0000
# Epoch 909/1000
# 1/1 [==============================] - 0s 21ms/step - loss: 0.0043 - accuracy: 1.0000 - val_loss: 0.0860 - val_accuracy: 1.0000
# Epoch 910/1000
# 1/1 [==============================] - 0s 20ms/step - loss: 0.0040 - accuracy: 1.0000 - val_loss: 0.0881 - val_accuracy: 1.0000
# Epoch 911/1000
# 1/1 [==============================] - 0s 20ms/step - loss: 0.0057 - accuracy: 1.0000 - val_loss: 0.0888 - val_accuracy: 1.0000
# Epoch 912/1000
# 1/1 [==============================] - 0s 20ms/step - loss: 0.0049 - accuracy: 1.0000 - val_loss: 0.0874 - val_accuracy: 1.0000
# Epoch 913/1000
# 1/1 [==============================] - 0s 19ms/step - loss: 0.0045 - accuracy: 1.0000 - val_loss: 0.0860 - val_accuracy: 1.0000
# Epoch 914/1000
# 1/1 [==============================] - 0s 19ms/step - loss: 0.0060 - accuracy: 1.0000 - val_loss: 0.0860 - val_accuracy: 1.0000
# Epoch 915/1000
# 1/1 [==============================] - 0s 20ms/step - loss: 0.0046 - accuracy: 1.0000 - val_loss: 0.0911 - val_accuracy: 1.0000
# Epoch 916/1000
# 1/1 [==============================] - 0s 19ms/step - loss: 0.0046 - accuracy: 1.0000 - val_loss: 0.0955 - val_accuracy: 1.0000
# Epoch 917/1000
# 1/1 [==============================] - 0s 20ms/step - loss: 0.0073 - accuracy: 1.0000 - val_loss: 0.0941 - val_accuracy: 1.0000
# Epoch 918/1000
# 1/1 [==============================] - 0s 21ms/step - loss: 0.0067 - accuracy: 1.0000 - val_loss: 0.0883 - val_accuracy: 1.0000
# Epoch 919/1000
# 1/1 [==============================] - 0s 21ms/step - loss: 0.0046 - accuracy: 1.0000 - val_loss: 0.0861 - val_accuracy: 1.0000
# Epoch 920/1000
# 1/1 [==============================] - 0s 20ms/step - loss: 0.0079 - accuracy: 1.0000 - val_loss: 0.0889 - val_accuracy: 1.0000
# Epoch 921/1000
# 1/1 [==============================] - 0s 20ms/step - loss: 0.0072 - accuracy: 1.0000 - val_loss: 0.0934 - val_accuracy: 1.0000
# Epoch 922/1000
# 1/1 [==============================] - 0s 21ms/step - loss: 0.0042 - accuracy: 1.0000 - val_loss: 0.0948 - val_accuracy: 1.0000
# Epoch 923/1000
# 1/1 [==============================] - 0s 20ms/step - loss: 0.0054 - accuracy: 1.0000 - val_loss: 0.0903 - val_accuracy: 1.0000
# Epoch 924/1000
# 1/1 [==============================] - 0s 21ms/step - loss: 0.0036 - accuracy: 1.0000 - val_loss: 0.0858 - val_accuracy: 1.0000
# Epoch 925/1000
# 1/1 [==============================] - 0s 20ms/step - loss: 0.0037 - accuracy: 1.0000 - val_loss: 0.0856 - val_accuracy: 1.0000
# Epoch 926/1000
# 1/1 [==============================] - 0s 20ms/step - loss: 0.0031 - accuracy: 1.0000 - val_loss: 0.0897 - val_accuracy: 1.0000
# Epoch 927/1000
# 1/1 [==============================] - 0s 20ms/step - loss: 0.0026 - accuracy: 1.0000 - val_loss: 0.0935 - val_accuracy: 1.0000
# Epoch 928/1000
# 1/1 [==============================] - 0s 20ms/step - loss: 0.0042 - accuracy: 1.0000 - val_loss: 0.0932 - val_accuracy: 1.0000
# Epoch 929/1000
# 1/1 [==============================] - 0s 20ms/step - loss: 0.0045 - accuracy: 1.0000 - val_loss: 0.0883 - val_accuracy: 1.0000
# Epoch 930/1000
# 1/1 [==============================] - 0s 21ms/step - loss: 0.0039 - accuracy: 1.0000 - val_loss: 0.0860 - val_accuracy: 1.0000
# Epoch 931/1000
# 1/1 [==============================] - 0s 20ms/step - loss: 0.0038 - accuracy: 1.0000 - val_loss: 0.0833 - val_accuracy: 1.0000
# Epoch 932/1000
# 1/1 [==============================] - 0s 21ms/step - loss: 0.0039 - accuracy: 1.0000 - val_loss: 0.0829 - val_accuracy: 1.0000
# Epoch 933/1000
# 1/1 [==============================] - 0s 21ms/step - loss: 0.0036 - accuracy: 1.0000 - val_loss: 0.0846 - val_accuracy: 1.0000
# Epoch 934/1000
# 1/1 [==============================] - 0s 20ms/step - loss: 0.0041 - accuracy: 1.0000 - val_loss: 0.0885 - val_accuracy: 1.0000
# Epoch 935/1000
# 1/1 [==============================] - 0s 20ms/step - loss: 0.0037 - accuracy: 1.0000 - val_loss: 0.0885 - val_accuracy: 1.0000
# Epoch 936/1000
# 1/1 [==============================] - 0s 20ms/step - loss: 0.0037 - accuracy: 1.0000 - val_loss: 0.0886 - val_accuracy: 1.0000
# Epoch 937/1000
# 1/1 [==============================] - 0s 21ms/step - loss: 0.0034 - accuracy: 1.0000 - val_loss: 0.0875 - val_accuracy: 1.0000
# Epoch 938/1000
# 1/1 [==============================] - 0s 20ms/step - loss: 0.0037 - accuracy: 1.0000 - val_loss: 0.0866 - val_accuracy: 1.0000
# Epoch 939/1000
# 1/1 [==============================] - 0s 20ms/step - loss: 0.0035 - accuracy: 1.0000 - val_loss: 0.0874 - val_accuracy: 1.0000
# Epoch 940/1000
# 1/1 [==============================] - 0s 19ms/step - loss: 0.0034 - accuracy: 1.0000 - val_loss: 0.0904 - val_accuracy: 1.0000
# Epoch 941/1000
# 1/1 [==============================] - 0s 20ms/step - loss: 0.0036 - accuracy: 1.0000 - val_loss: 0.0938 - val_accuracy: 1.0000
# Epoch 942/1000
# 1/1 [==============================] - 0s 20ms/step - loss: 0.0053 - accuracy: 1.0000 - val_loss: 0.0913 - val_accuracy: 1.0000
# Epoch 943/1000
# 1/1 [==============================] - 0s 20ms/step - loss: 0.0037 - accuracy: 1.0000 - val_loss: 0.0865 - val_accuracy: 1.0000
# Epoch 944/1000
# 1/1 [==============================] - 0s 19ms/step - loss: 0.0053 - accuracy: 1.0000 - val_loss: 0.0846 - val_accuracy: 1.0000
# Epoch 945/1000
# 1/1 [==============================] - 0s 19ms/step - loss: 0.0053 - accuracy: 1.0000 - val_loss: 0.0870 - val_accuracy: 1.0000
# Epoch 946/1000
# 1/1 [==============================] - 0s 20ms/step - loss: 0.0034 - accuracy: 1.0000 - val_loss: 0.0903 - val_accuracy: 1.0000
# Epoch 947/1000
# 1/1 [==============================] - 0s 20ms/step - loss: 0.0046 - accuracy: 1.0000 - val_loss: 0.0927 - val_accuracy: 1.0000
# Epoch 948/1000
# 1/1 [==============================] - 0s 19ms/step - loss: 0.0047 - accuracy: 1.0000 - val_loss: 0.0920 - val_accuracy: 1.0000
# Epoch 949/1000
# 1/1 [==============================] - 0s 19ms/step - loss: 0.0046 - accuracy: 1.0000 - val_loss: 0.0880 - val_accuracy: 1.0000
# Epoch 950/1000
# 1/1 [==============================] - 0s 21ms/step - loss: 0.0044 - accuracy: 1.0000 - val_loss: 0.0849 - val_accuracy: 1.0000
# Epoch 951/1000
# 1/1 [==============================] - 0s 20ms/step - loss: 0.0042 - accuracy: 1.0000 - val_loss: 0.0876 - val_accuracy: 1.0000
# Epoch 952/1000
# 1/1 [==============================] - 0s 20ms/step - loss: 0.0061 - accuracy: 1.0000 - val_loss: 0.0879 - val_accuracy: 1.0000
# Epoch 953/1000
# 1/1 [==============================] - 0s 24ms/step - loss: 0.0050 - accuracy: 1.0000 - val_loss: 0.0868 - val_accuracy: 1.0000
# Epoch 954/1000
# 1/1 [==============================] - 0s 21ms/step - loss: 0.0049 - accuracy: 1.0000 - val_loss: 0.0858 - val_accuracy: 1.0000
# Epoch 955/1000
# 1/1 [==============================] - 0s 19ms/step - loss: 0.0057 - accuracy: 1.0000 - val_loss: 0.0878 - val_accuracy: 1.0000
# Epoch 956/1000
# 1/1 [==============================] - 0s 20ms/step - loss: 0.0060 - accuracy: 1.0000 - val_loss: 0.0884 - val_accuracy: 1.0000
# Epoch 957/1000
# 1/1 [==============================] - 0s 19ms/step - loss: 0.0045 - accuracy: 1.0000 - val_loss: 0.0891 - val_accuracy: 1.0000
# Epoch 958/1000
# 1/1 [==============================] - 0s 19ms/step - loss: 0.0063 - accuracy: 1.0000 - val_loss: 0.0867 - val_accuracy: 1.0000
# Epoch 959/1000
# 1/1 [==============================] - 0s 19ms/step - loss: 0.0060 - accuracy: 1.0000 - val_loss: 0.0857 - val_accuracy: 1.0000
# Epoch 960/1000
# 1/1 [==============================] - 0s 20ms/step - loss: 0.0044 - accuracy: 1.0000 - val_loss: 0.0880 - val_accuracy: 1.0000
# Epoch 961/1000
# 1/1 [==============================] - 0s 20ms/step - loss: 0.0059 - accuracy: 1.0000 - val_loss: 0.0897 - val_accuracy: 1.0000
# Epoch 962/1000
# 1/1 [==============================] - 0s 20ms/step - loss: 0.0049 - accuracy: 1.0000 - val_loss: 0.0911 - val_accuracy: 1.0000
# Epoch 963/1000
# 1/1 [==============================] - 0s 20ms/step - loss: 0.0051 - accuracy: 1.0000 - val_loss: 0.0939 - val_accuracy: 1.0000
# Epoch 964/1000
# 1/1 [==============================] - 0s 21ms/step - loss: 0.0050 - accuracy: 1.0000 - val_loss: 0.0948 - val_accuracy: 1.0000
# Epoch 965/1000
# 1/1 [==============================] - 0s 22ms/step - loss: 0.0051 - accuracy: 1.0000 - val_loss: 0.0918 - val_accuracy: 1.0000
# Epoch 966/1000
# 1/1 [==============================] - 0s 23ms/step - loss: 0.0051 - accuracy: 1.0000 - val_loss: 0.0867 - val_accuracy: 1.0000
# Epoch 967/1000
# 1/1 [==============================] - 0s 22ms/step - loss: 0.0052 - accuracy: 1.0000 - val_loss: 0.0819 - val_accuracy: 1.0000
# Epoch 968/1000
# 1/1 [==============================] - 0s 21ms/step - loss: 0.0052 - accuracy: 1.0000 - val_loss: 0.0813 - val_accuracy: 1.0000
# Epoch 969/1000
# 1/1 [==============================] - 0s 20ms/step - loss: 0.0052 - accuracy: 1.0000 - val_loss: 0.0852 - val_accuracy: 1.0000
# Epoch 970/1000
# 1/1 [==============================] - 0s 20ms/step - loss: 0.0041 - accuracy: 1.0000 - val_loss: 0.0917 - val_accuracy: 1.0000
# Epoch 971/1000
# 1/1 [==============================] - 0s 22ms/step - loss: 0.0066 - accuracy: 1.0000 - val_loss: 0.0987 - val_accuracy: 1.0000
# Epoch 972/1000
# 1/1 [==============================] - 0s 20ms/step - loss: 0.0081 - accuracy: 1.0000 - val_loss: 0.1007 - val_accuracy: 1.0000
# Epoch 973/1000
# 1/1 [==============================] - 0s 21ms/step - loss: 0.0072 - accuracy: 1.0000 - val_loss: 0.0986 - val_accuracy: 1.0000
# Epoch 974/1000
# 1/1 [==============================] - 0s 23ms/step - loss: 0.0069 - accuracy: 1.0000 - val_loss: 0.0942 - val_accuracy: 1.0000
# Epoch 975/1000
# 1/1 [==============================] - 0s 19ms/step - loss: 0.0061 - accuracy: 1.0000 - val_loss: 0.0876 - val_accuracy: 1.0000
# Epoch 976/1000
# 1/1 [==============================] - 0s 20ms/step - loss: 0.0050 - accuracy: 1.0000 - val_loss: 0.0817 - val_accuracy: 1.0000
# Epoch 977/1000
# 1/1 [==============================] - 0s 20ms/step - loss: 0.0068 - accuracy: 1.0000 - val_loss: 0.0779 - val_accuracy: 1.0000
# Epoch 978/1000
# 1/1 [==============================] - 0s 20ms/step - loss: 0.0077 - accuracy: 1.0000 - val_loss: 0.0762 - val_accuracy: 1.0000
# Epoch 979/1000
# 1/1 [==============================] - 0s 21ms/step - loss: 0.0067 - accuracy: 1.0000 - val_loss: 0.0740 - val_accuracy: 1.0000
# Epoch 980/1000
# 1/1 [==============================] - 0s 23ms/step - loss: 0.0079 - accuracy: 1.0000 - val_loss: 0.0766 - val_accuracy: 1.0000
# Epoch 981/1000
# 1/1 [==============================] - 0s 24ms/step - loss: 0.0074 - accuracy: 1.0000 - val_loss: 0.0840 - val_accuracy: 1.0000
# Epoch 982/1000
# 1/1 [==============================] - 0s 22ms/step - loss: 0.0063 - accuracy: 1.0000 - val_loss: 0.0906 - val_accuracy: 1.0000
# Epoch 983/1000
# 1/1 [==============================] - 0s 21ms/step - loss: 0.0053 - accuracy: 1.0000 - val_loss: 0.0938 - val_accuracy: 1.0000
# Epoch 984/1000
# 1/1 [==============================] - 0s 20ms/step - loss: 0.0045 - accuracy: 1.0000 - val_loss: 0.0957 - val_accuracy: 1.0000
# Epoch 985/1000
# 1/1 [==============================] - 0s 21ms/step - loss: 0.0047 - accuracy: 1.0000 - val_loss: 0.0941 - val_accuracy: 1.0000
# Epoch 986/1000
# 1/1 [==============================] - 0s 21ms/step - loss: 0.0045 - accuracy: 1.0000 - val_loss: 0.0946 - val_accuracy: 1.0000
# Epoch 987/1000
# 1/1 [==============================] - 0s 20ms/step - loss: 0.0054 - accuracy: 1.0000 - val_loss: 0.0922 - val_accuracy: 1.0000
# Epoch 988/1000
# 1/1 [==============================] - 0s 20ms/step - loss: 0.0058 - accuracy: 1.0000 - val_loss: 0.0889 - val_accuracy: 1.0000
# Epoch 989/1000
# 1/1 [==============================] - 0s 20ms/step - loss: 0.0056 - accuracy: 1.0000 - val_loss: 0.0860 - val_accuracy: 1.0000
# Epoch 990/1000
# 1/1 [==============================] - 0s 20ms/step - loss: 0.0046 - accuracy: 1.0000 - val_loss: 0.0845 - val_accuracy: 1.0000
# Epoch 991/1000
# 1/1 [==============================] - 0s 21ms/step - loss: 0.0056 - accuracy: 1.0000 - val_loss: 0.0883 - val_accuracy: 1.0000
# Epoch 992/1000
# 1/1 [==============================] - 0s 21ms/step - loss: 0.0039 - accuracy: 1.0000 - val_loss: 0.0947 - val_accuracy: 1.0000
# Epoch 993/1000
# 1/1 [==============================] - 0s 20ms/step - loss: 0.0044 - accuracy: 1.0000 - val_loss: 0.0987 - val_accuracy: 1.0000
# Epoch 994/1000
# 1/1 [==============================] - 0s 20ms/step - loss: 0.0062 - accuracy: 1.0000 - val_loss: 0.0975 - val_accuracy: 1.0000
# Epoch 995/1000
# 1/1 [==============================] - 0s 20ms/step - loss: 0.0051 - accuracy: 1.0000 - val_loss: 0.0921 - val_accuracy: 1.0000
# Epoch 996/1000
# 1/1 [==============================] - 0s 20ms/step - loss: 0.0030 - accuracy: 1.0000 - val_loss: 0.0870 - val_accuracy: 1.0000
# Epoch 997/1000
# 1/1 [==============================] - 0s 20ms/step - loss: 0.0057 - accuracy: 1.0000 - val_loss: 0.0843 - val_accuracy: 1.0000
# Epoch 998/1000
# 1/1 [==============================] - 0s 20ms/step - loss: 0.0065 - accuracy: 1.0000 - val_loss: 0.0831 - val_accuracy: 1.0000
# Epoch 999/1000
# 1/1 [==============================] - 0s 20ms/step - loss: 0.0053 - accuracy: 1.0000 - val_loss: 0.0859 - val_accuracy: 1.0000
# Epoch 1000/1000
# 1/1 [==============================] - 0s 20ms/step - loss: 0.0042 - accuracy: 1.0000 - val_loss: 0.0883 - val_accuracy: 1.0000

# %%
model_score = seq_model.evaluate(test_features, test_labels, verbose = 0)
print(model_score)
# Out:
# [0.04094023257493973, 1.0]

# %%
test_predictions = seq_model.predict(test_features)
#print(test_predictions)
# Out:
# 3/3 [==============================] - 0s 1ms/step

# %%
# Анализ Depth
x_predict = range(test_predictions.shape[0])
y_predict = test_predictions[:,:1]
y_test = test_labels[:,:1]
test_results_depth['NN'] = mae(y_test, y_predict)
plot_model(x_predict, y_test, y_predict, f'Depth: NN Model MAE: {mae(y_test, y_predict):0.3}')

# %%
# Анализ Width
x_predict = range(test_predictions.shape[0])
y_predict = test_predictions[:,1:2]
y_test = test_labels[:,1:2]
test_results_width['NN'] = mae(y_test, y_predict)
plot_model(x_predict, y_test, y_predict, f'Width: NN Model MAE: {mae(y_test, y_predict):0.3}')

# %%
test_predictions = seq_model.predict(test_features[:1], verbose = 0)
print(f'Параметры: {test_features[:1]}')
print(f'Прогноз: {test_predictions}')
print(f'Истинное значение: {test_labels[:1]}')
# Out:
# Параметры: [[ 47.  139.    4.5  80. ]]
# Прогноз: [[1.489 2.51 ]]
# Истинное значение: [[1.6  2.54]]

# %%
print("WIDTH")
test_results_width
# Out:
# WIDTH
# {'LinearRegression': 0.05442429651267374,
#  'PolynomialFeatures': 0.030625000000000013,
#  'NN': 0.0367903436554803}

# %%
print("DEPTH")
test_results_depth
# Out:
# DEPTH
# {'LinearRegression': 0.0745975747744926,
#  'PolynomialFeatures': 0.04277777777777795,
#  'NN': 0.04509012295140161}

# %% [markdown]
# #### Сохранение модели

# %%
seq_model.save('model\welding-model')
# Сохранение в формате ONNX
tf2onnx.convert.from_keras(seq_model, output_path = 'model\welding-model.onnx')
# Out:
# INFO:tensorflow:Assets written to: welding-model\assets
# (ir_version: 7
#  producer_name: "tf2onnx"
#  producer_version: "1.13.0 2c1db5"
#  graph {
#    node {
#      input: "normalization_input"
#      input: "sequential/normalization/sub/y:0"
#      output: "sequential/normalization/sub:0"
#      name: "sequential/normalization/sub"
#      op_type: "Sub"
#    }
#    node {
#      input: "sequential/normalization/sub:0"
#      input: "ConstantFolding/sequential/normalization/truediv_recip:0"
#      output: "sequential/normalization/truediv:0"
#      name: "sequential/normalization/truediv"
#      op_type: "Mul"
#    }
#    node {
#      input: "sequential/normalization/truediv:0"
#      input: "sequential/dense/MatMul/ReadVariableOp:0"
#      output: "sequential/dense/MatMul:0"
#      name: "sequential/dense/MatMul"
#      op_type: "MatMul"
#    }
#    node {
#      input: "sequential/dense/MatMul:0"
#      input: "sequential/dense/BiasAdd/ReadVariableOp:0"
#      output: "sequential/dense/BiasAdd:0"
#      name: "sequential/dense/BiasAdd"
#      op_type: "Add"
#    }
#    node {
#      input: "sequential/dense/BiasAdd:0"
#      output: "sequential/dense/Relu:0"
#      name: "sequential/dense/Relu"
#      op_type: "Relu"
#    }
#    node {
#      input: "sequential/dense/Relu:0"
#      input: "sequential/dense_1/MatMul/ReadVariableOp:0"
#      output: "sequential/dense_1/MatMul:0"
#      name: "sequential/dense_1/MatMul"
#      op_type: "MatMul"
#    }
#    node {
#      input: "sequential/dense_1/MatMul:0"
#      input: "sequential/dense_1/BiasAdd/ReadVariableOp:0"
#      output: "sequential/dense_1/BiasAdd:0"
#      name: "sequential/dense_1/BiasAdd"
#      op_type: "Add"
#    }
#    node {
#      input: "sequential/dense_1/BiasAdd:0"
#      output: "sequential/dense_1/Relu:0"
#      name: "sequential/dense_1/Relu"
#      op_type: "Relu"
#    }
#    node {
#      input: "sequential/dense_1/Relu:0"
#      input: "sequential/dense_2/MatMul/ReadVariableOp:0"
#      output: "sequential/dense_2/MatMul:0"
#      name: "sequential/dense_2/MatMul"
#      op_type: "MatMul"
#    }
#    node {
#      input: "sequential/dense_2/MatMul:0"
#      input: "sequential/dense_2/BiasAdd/ReadVariableOp:0"
#      output: "dense_2"
#      name: "sequential/dense_2/BiasAdd"
#      op_type: "Add"
#    }
#    name: "tf2onnx"
#    initializer {
#      dims: 1
#      dims: 4
#      data_type: 1
#      name: "sequential/normalization/sub/y:0"
#      raw_data: "337B\336\335\014C\336\335\rAUU\241B"
#    }
#    initializer {
#      dims: 32
#      dims: 2
#      data_type: 1
#      name: "sequential/dense_2/MatMul/ReadVariableOp:0"
#      raw_data: "\253\000\307\276\363\264C\276@\347\224\276\363\250\371\275\360\275\302\276\377\374\247>NA\242>z\r\260=#\362`>s\237\337\273t>\313>\331\356k\275\303\320A=s?G>\233\241\273>LO\004\2760_\217>5h\341>\022\311\225\276\260\367\026\275\030\360\223>\271x\205\274\021!\206>=\241\204<\n\375\260\2754.a<,7\263\276}\322\223>\215\256b>\017O\343>mr\323=\265\242\324>\313{\262\276`\037M<\360\244P\276q\177r>\177\320\002?%\023\201=\323\206\000>\014N\233=9\305\204;\027\256#\276 \205\274\275\226\254x\276\362<\255\276\226<\215\276\325\347\303\276A\035\240\276\305\301\312\276\001\205\344\275\372\"\270>\327i\305>\274)\036>\362C\265> n\303<>a\023\276t\334\302>26\223=\246j/\2765\3337>W\223=>\324\326\356<\227_\265\276M}\227>"
#    }
#    initializer {
#      dims: 2
#      data_type: 1
#      name: "sequential/dense_2/BiasAdd/ReadVariableOp:0"
#      raw_data: "\252\356\212=\244\277\335="
#    }
#    initializer {
#      dims: 64
#      dims: 32
#      data_type: 1
#      name: "sequential/dense_1/MatMul/ReadVariableOp:0"
#      raw_data: "8\374S\276%\267Q>\002|l\2735O\342<\351\240p>7\262b<\020VA>\014oA\276\233-I\275E\254\034\276\372\374g=\2238\210>\010\027\010\276\3448\245\275\370\271\241\275\014\3573=\200#e\2753\027.\2766\310\224>\220f\027\276\351\022\2608\220\251\025\276\256\273\003\276\236\263\";,\200\237\275\303_9\276\360t\223>\334iQ\276Cy\354=\371t\031>16\037\276\032z\022>\321\212\211<\r\333\305=\340\032\321<fS4\276\252\302\235=\325\300\000\275\346\235g>\300\326v\276\005r_>_\301\210\276O\274\212\276\236\007\261\275\344\306\260\274\343\364\313\275\310$:>\213X\010\276\210\254\267=T\262\357=\251|1\275\264\204\205>E\243/>\001\235\033>\003\2535\2761\250b> j7=AHe\275&\376u>\2002I\274j\355\305\275\245\224\034\276\245jP>?$\367=y\002W<w\354\021>\202u\"\276\230\222\201>*\300\014>U\232>>\000\363\251>\230y\356=^\036/>\020\362\334=~X\216=a\226\334=\315=6>\311\325\r>^\341-\275\311\217\023\276\300\026\020\276\220\035\302=R`\300=\260w\024\276\315\300=\276=\210y\276\013ad\276\227\325\323\275\020\342\200\276N\307\271<\263\206\025\275\340\277\331\274\211\225\212>\nIe\276\006\244N=\n\3044=\034a\217\275a\335M>7g\356=+\211-<\n\236H\276\237\230\\>\244\362$\276@z\330<^\332\274=\352\325\360\275\300?\037\276\323*\204>\017\247\251;\024MO=\247\3301\276\307\264v>\304\323\034\276\303\332\">G\331\035=\327\357\004>9\276\215\276\000\276\312\2758\271\230<1\251P\276\203d&>\345\235\016\276\272\023\354\275p\340R=j\340\354\275\240\217\r>\000\230\202\275SH\231=\320z\312=n\375\022>@\267t>\274aJ=d\014[\275\033\363\031>\002\013\364\274\340xy=\316*\221\276|o\345=`\251(>;\025\016>R\374`\276\0341\212=\024\014\236<Ll\220\276\274\305\">]\273\243=\275\337 \276).o=\344Y>\276\352N6>\231\276\225<\026:_>\362\326n\276\304\275\030\276g\254u<\234\214E\276\267\272\224=\004\371\276\275D\365\213\274\200\333o\275\347\234r<\227\375M\276X\316\233=\312\010\t\276\317\031N>T\240p=\020\n\221>`cs=\201{\253>\275\216\014>:\'\352<\305\277\226\275\000ID<\031r\230>,S\236>\223\237Q>h\005\200=\340\237\251<(}\002>\265\223\303\275\244k\203\276\"\377\315\275\344\330\203=\024Sb=w\3776> B\321=A\345R>0\315m\275q\3276\276V\302\032>U0)<\351\334\007>\306\212\337=\035\266o=\200\373l>\337\227q>$\340n\276\020\377N\275s\351)\276 \366^\275\333\325\r=\341U=\276\325\271j\275\247\362\274\275\000*\241;MT\225\276[t\307;gfN>\034\3033\276\272\270C>\345 (>\270\372\224\275U7\303\275\\H\002>\244\023-\276\226\022\017=\316\023.\276\345\032X\276j\351\014\276\004\\|\276\005\350u=\247\341\357=/\034E\276\336\252\263<c\0277>\374\343<\274)\354\020>\"D\245\275\362\225\217=@\311$\274rp_>\210bI\276/ZM\276\331N\312=%\343e>\323\305\032\276\272y\344\275\263\251\325\275\316_\355\275\300\254i>\010\217\263\275D\023=>\201s\274=\031\243A>e\3127>\225)\275=d\217_>\314\362\300\275\32245\276\375\354f>\257s\314= m5\276\025\255\362\274\326\316L>\335k\250\2750\253\357<\274\215=\273i\254R=\227\352\030\276\036\367W>\230\310\214=Y\252\001>\000\370\256=\254d$>r1!\276\246\022\210=k\355=>`\034\350\275\000.\247\274\023\254\033=\241W/\276\026q&\276\234dd>\311\037\024>I\350\345\275\351H2>=\377\013=\030\036\014>)\371i\276\317\212g=\212\230\222\275h\336\355=v6\016>\240\354 =\3634\310=\351CW\276\256[]\276\016\316\304\275Y\223\327<)8\301\274\367\237\037>\277d\023=\000!\004\276\032\277\027>r\330>>\314@I>\257I\261=\237;c=y\247b\276\342>6>\211#1\276\336+\225\275\2546\217\275,\254d\275\300Z:>\210EO\274\310\331\036\276a\0218\274\307\010\377=\330\253k\276\335r$\275\246\017\274\2754M\003>\300c\232\275\256\225\014> w\375<\'Q\021>\005\373\230=.=&>\275\344\205>!/\254\275\034}\014\276\360\234\017=\010\230\300\275\311\237\342=W\r.>K;\330\274\300!\343=\021s\274\275Yn\013>\317G7\276\337\3216\276}\355\005\276s\242\310\275h\327{>V\342\t>\200\340\233\273\036\360\005>_$\261\275\316\214\350\275\211\362@\276\271xY\275\236\221h\276\374\351X\276\'\004\030>\nb\013>s9\315\275\330%\374\275\202|x>\201}Q>C?Q\275\304\327\245=\355\214\302\275\033\274\265\274B\323T>a\025S\276\306;m>\366Z\346=\245\316\274\275@\276:\275\265>\027\275]\301\035>\363\227\301=\365\203\017>\310\214{\276\274\262\341=\264\330\034 ...
#    }
#    initializer {
#      dims: 32
#      data_type: 1
#      name: "sequential/dense_1/BiasAdd/ReadVariableOp:0"
#      raw_data: "n\343\036\275\342\"}\275b[\000\274G\210\317=\363\241\311=\314\303k=\343\206\365=\000\000\000\000R\213\360=\002e\016\275\205\216\014=\214\324\244=\255gm\274+\363\215=,\211,>\345!\350=\000\000\000\000\335n\357=0C\373=T=\253=^2\024\275\210\201y\274*\024\340\274\274%m\275\311\222\376\274[\242\310=\217\373!>\000\000\000\000)H\273=\340\347+=\003\374\246=\357\304\253="
#    }
#    initializer {
#      dims: 4
#      dims: 64
#      data_type: 1
#      name: "sequential/dense/MatMul/ReadVariableOp:0"
#      raw_data: "c\257\217>\221\244\024\273\034\264D\276\341\215\230\276\001\365\031=\335\221\002>\226\275\314=\306\017r\276_\007U\275\262E\275\275\021G\255\276\231\232\220\275Q\336\013\275\260\263\253\276\340na\276G\002\251\275\370\036\234\276Gb\211=\266^\227\276\227\317\242>-wX\275\300q\016\275E\225W<e\356\024\275E\350O>\006\321.>\345\005\357\275\214\363v>\203m\035>\264SW=H\024\234\276\265K\010>h\271q=3\321\345<\321\215\032\275\022\031^\276}\010n>\235\352n;\307S\327\275~:\352\274Y\006(\275\\\301*\276\250\016i=\030P\236=]\265I\276\'\022z\276\350N\204>\226Ip>W\231\031\274\215\034B\276\353\227;\275\341\3006=y\234\000>\001\347\"<sw\026>E\271q\275\200\270\310\275\254\017\306=\276<h=S\356\027\2764_\235\276\354\274*>\177\256?>d%\037\275\362\311i>\323\230J\275\210\247,\276sw\n\276\360\262\344<D!D<\000\352+\276S\231\203\276\372\212\367=Bq\262=c\342L\276\320\005/\276\300}\223\276\256iu\276\221\373\027\276\265\366\235\274Y\352\205\276c\003\001\275\320\303e\276C\017;>\366t\206>\n\300\"\276:\214->s\2332\276\273s(>7\312\005\276\310\236\230\276j;\033\276v\2045\276x\366\254\275\202\3302>K@H>Xf\220<\222\374 \276\021[\325\275A\\,\276\307[6>E\354\204>v\3424\276\334a{\275\r\221\271=q\257\306=W\245?>N\023R<\331p\031\276\261\350\001>+Dz>Q\215`>l\311v\276\235\235\242\276\231\311M=\276\374\326;\"\t\024\276\320\267Z\276\177\330\225\275nA\224>`\304)\276\210Lz=X\365\340\275\246\204+\276\2579#\276\2415+>w\201`>?\331H>\337\324Z>\2652\332=\2101c\2725*y\276`\002\024=\332\330<<\006%M\276\024\257\n\276\020\001o>^\365,=\304\353\254=\222\010O\276p>\341\275Q8\250=R\230\037\276\302}\334= \222\307=\270;#<\313$\234=\273\360q\276R\n\203\276\336\253i>\267t]>m\327~\276P\"\017>\207\262\250\276.\210b>&\313\\\276;V(>U7->yT\010\276\360\n\212>Y\354u>DLW=hEc=?\262Q\276o\235\265\275O\3639\275^\233\017>4@\247\275\332\0258\276\254\211\314\275\301\362\177\276\363a\225\276\376\315\242\276\034\031+;:\223\201\276K(\200\276B\206\224\275\003\224\222=\217\017<>\310Fm\276\001$\345\275\002C\037>\330\020\017\276O\240\223\275\007\360d>\354\215m=\337u\215\275\306D]>\3654\352\275\265\3150\276[\350\257=\216\246\272\275\\\r\262\276\000\245\232<$B,\276o\345\337\275o\336F>\016\362\317\275\226\027\274=\215\342+\276\242\207\263\274VC\364:\205\356<>\002r\003\276\303L$>1\223\002\276\014\037\005\2766T\030>\372\006\204=c\313T>+0\020>\372\341`\276\305\263\\>\321\350\367<\027\372)\276\014h\273\275\'\363\177\276\3371\n<\3608\216=\202\200\264=\\\375\246\276K]\n\275[U<\276\022\262\007>M\367\325\275`K\201=\177J\261\275\376\024\351\274 F:>#\000 \274t\240l>\rT\021=x\257{\276\317p\227\276\307p\371\275\273\234\"\276h`\212>\204c\244\275[\230\352=\312\334\300=~\375/\276xhY\276\321@G\276i\311\326<\330\313\304\275\027\022\324\274\341|`>\024\0369\276\302`\036\275\226\366\220\274\027\274t\276$D\337\275\331lA>s\240\266=P0\037=\365\020T\276"
#    }
#    initializer {
#      dims: 64
#      data_type: 1
#      name: "sequential/dense/BiasAdd/ReadVariableOp:0"
#      raw_data: "g\353\">@\006\365=\342{\371=\374D\t>pN\204\274\344\204I>\317I\260=\364n\034\274\344Qs\275R\326\'>\216\020;>T&l\2747\247\273\273\0327\311\274\265m\330\273\177\306\345=\327\267\237\274YQ\254=\240\030\'>1\223R>J(n\274\2538\235<.\360\033=B\321\036=\324\261\367=\252\320\241=\277\363\020>\315\264V=\007YB>\004\213\332\275e\321\302=\021I\021>\320>\004>\364\344\376\274\243\\\034>+9Q=\371:\243=\312\036\230=u\260G>\3276T>\226>\250=\234O#>\210\220\367==$\316=\334\340\250\274\246\177\034<5!p;\266g=>,11>\353\2378>ZB\376\275\247\002\343=\246\240[\275\271\335\001>}P\025>\252\333\263\275K\372\215\275p\030\277<\024\377\273==\327_;\356\262\371=5z\354;\3408\022>\036\027\373="
#    }
#    initializer {
#      dims: 1
#      dims: 4
#      data_type: 1
#      name: "ConstantFolding/sequential/normalization/truediv_recip:0"
#      raw_data: "\021D\030?\311\nB>\250\016\003?\351\3377="
#    }
#    doc_string: "converted from sequential"
#    input {
#      name: "normalization_input"
#      type {
#        tensor_type {
#          elem_type: 1
#          shape {
#            dim {
#              dim_param: "unk__6"
#            }
#            dim {
#              dim_param: "unk__7"
#            }
#          }
#        }
#      }
#    }
#    output {
#      name: "dense_2"
#      type {
#        tensor_type {
#          elem_type: 1
#          shape {
#            dim {
#              dim_param: "unk__8"
#            }
#            dim {
#              dim_value: 2
#            }
#          }
#        }
#      }
#    }
#  }
#  opset_import {
#    domain: ""
#    version: 13
#  }
#  opset_import {
#    domain: "ai.onnx.ml"
#    version: 2
#  },
#  None)

# %% [markdown]
# #### Загрузка сохраненной модели и тестовый запуск

# %%
# Создание переменной сессии для работы с моделью (загрузка модели)
session = rt.InferenceSession('model\welding-model.onnx')
# Создание вектора для параметров
X = np.array([[47.0, 139.0, 4.5, 80.0]], dtype = np.float32)
inputDetails = session.get_inputs()
# Получение прогозна
y = session.run(None, {inputDetails[0].name: X})
print(y)
# Out:
# [array([[1.489, 2.51 ]], dtype=float32)]

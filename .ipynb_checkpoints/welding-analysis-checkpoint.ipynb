# %% [markdown]
# ## Анализ процесса электронно-лучевой сварки
# ### Выпускная квалификационная работа
# по курсу "Аналитик данных" Образовательный центр МГТУ им. Н.Э. Баумана - 2022
# <br>
# <br><b>Выполнил:</b> <i>Альчаков В.В. гр. AD11872/3<i>

# %% [markdown]
# ### Подключение необходимых библиотек

# %%
import pandas as pd
import numpy as np

# Установить точность вывода - 3 знака после запятой
np.set_printoptions(precision = 3, suppress = True)

# sklearn
from sklearn.preprocessing import PolynomialFeatures, StandardScaler
from sklearn.svm import SVR
from sklearn.linear_model import LinearRegression
from sklearn.pipeline import make_pipeline
from sklearn.metrics import mean_absolute_error as mae

# scipy
from scipy import stats
from scipy.stats import norm

# Библиотеки для работы с графикой
import seaborn as sns
sns.set()

import matplotlib.pyplot as plt
import matplotlib.style
# %matplotlib inline

# tensorflow
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers

# Работа с ONNX моделями
import onnx
import tf2onnx
import onnxruntime as rt

# Отключение вывода предупреждений
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ### Геометрические параметры сварного шва
# ![alt text](img/welding.png "Title")
# <i><b>e</b> - Ширина шва</i><br>
# <i><b>q</b> - Выпуклость шва</i><br>
# <i><b>h</b> - Глубина провара</i><br>
# <i><b>t</b> - Толщина шва</i><br>
# <i><b>b</b> - Зазор</i><br>
# <i><b>S</b> - Толщина свариваемого металла</i><br>
#
# В качестве исходных данных были взяты результаты экспериментальных исследований, проводимых в целях улучшения технологического процесса электронно-лучевой сварки изделия, сборка которого состоит из элементов, состоящих из разнородного материала. Установка электронно-лучевой сварки, на которой проводились исследования, предназначена для сварки электронным лучом в глубоком вакууме деталей сборочных единиц из нержавеющих сталей, титановых, алюминиевых и специальных сплавов. Существующая установка электронно-лучевой сварки обеспечивает повторяемость режимов в рамках возможностей реализованной системы управления. Работы по сварке выполнялись на образцах-имитаторах, соответствующих технологическому изделию.

# %% [markdown]
# ### Загрузка исходного датасета
# <b>ВХОД:</b>
# <ol>
#     <li>IW - Ток сварочного тока</li>
#     <li>IF - Ток фокусировки электронного пучка</li>
#     <li>VW - Скорость сварки</li>
#     <li>FP - Расстояние от поверхности образцов</li>
# </ol>
# <br>
# <b>ВЫХОД:</b>
# <ol>
#     <li>Depth - Глубина шва</li>
#     <li>Width - Ширина шва</li>
# </ol>

# %%
raw_data = pd.read_csv('data/ebw_data.csv')
raw_data.shape
# Out:
# (72, 6)

# %% [markdown]
# ### Предварительная обработка и разведовательный анализ

# %% [markdown]
# ##### Просмотр первых строк датасета

# %%
raw_data.head()
# Out:
#    IW   IF   VW  FP  Depth  Width
# 0  47  139  4.5  80   1.60   2.54
# 1  47  139  4.5  80   1.62   2.50
# 2  47  139  4.5  80   1.68   2.60
# 3  47  139  4.5  80   1.58   2.52
# 4  45  140  4.5  80   1.76   2.48

# %% [markdown]
# ##### Проверка на наличие пропусков

# %%
raw_data.isnull().sum()
# Out:
# IW       0
# IF       0
# VW       0
# FP       0
# Depth    0
# Width    0
# dtype: int64

# %% [markdown]
# ##### Построение обучающей выборки
# Анализ датасета показывает, что комбинации значений столбцов IW, IF, VW, FP повторяются. Поэтому построим новый датасет, с уникальными комбинациями признаков и выходным параметром усредненным по каждой группе

# %%
train_data = raw_data.groupby(['IW', 'IF', 'VW', 'FP']).agg({'Depth': ['mean'], 'Width': ['mean']}).reset_index()
train_data.columns = ['IW', 'IF', 'VW', 'FP', 'Depth', 'Width']

# %%
# Модифицированный датасет для обучения
train_data
# Out:
#     IW   IF    VW   FP  Depth   Width
# 0   43  146   9.0   60  1.220  1.7650
# 1   43  150   9.0   50  1.080  1.8150
# 2   44  146   9.0   60  1.230  1.7950
# 3   45  140   4.5   80  1.690  2.5100
# 4   45  140   8.0   80  1.190  1.9700
# 5   45  141  10.0   80  1.010  1.8600
# 6   45  146   9.0   60  1.310  1.7600
# 7   46  141  10.0   80  1.140  1.8200
# 8   46  146  10.0   60  1.310  1.7700
# 9   47  134  10.0  110  0.945  1.9350
# 10  47  139   4.5   80  1.495  2.5150
# 11  47  140  10.0   80  1.160  1.7900
# 12  47  141  12.0   80  1.120  1.7275
# 13  48  131  10.0  125  0.845  2.0700
# 14  49  132   8.0  125  0.820  2.2600

# %% [markdown]
# ##### Описательная статистика

# %%
train_data.describe()
# Out:
#               IW          IF         VW          FP      Depth      Width
# count  15.000000   15.000000  15.000000   15.000000  15.000000  15.000000
# mean   45.800000  140.866667   8.866667   80.666667   1.171000   1.957500
# std     1.740279    5.462426   2.021904   23.057898   0.229543   0.265678
# min    43.000000  131.000000   4.500000   50.000000   0.820000   1.727500
# 25%    45.000000  139.500000   8.500000   60.000000   1.045000   1.780000
# 50%    46.000000  141.000000   9.000000   80.000000   1.160000   1.820000
# 75%    47.000000  146.000000  10.000000   80.000000   1.270000   2.020000
# max    49.000000  150.000000  12.000000  125.000000   1.690000   2.515000

# %% [markdown]
# ##### Расчет корреляционной матрицы
# В случае линейной регрессионной модели корреляционная матрица позволит выяснить, какие признаки в большей степени влияют на целевую переменную

# %%
# Корреляционная матрица
train_data.corr()
# Out:
#              IW        IF        VW        FP     Depth     Width
# IW     1.000000 -0.844566  0.073079  0.831286 -0.389267  0.359959
# IF    -0.844566  1.000000  0.066182 -0.983178  0.452146 -0.501293
# VW     0.073079  0.066182  1.000000  0.017364 -0.651087 -0.864309
# FP     0.831286 -0.983178  0.017364  1.000000 -0.569981  0.432293
# Depth -0.389267  0.452146 -0.651087 -0.569981  1.000000  0.355843
# Width  0.359959 -0.501293 -0.864309  0.432293  0.355843  1.000000

# %% [markdown]
# ##### Корреляционная матрица в виде тепловой карты

# %%
plt.figure(figsize = (5, 3), dpi = 100)
plt.style.use('classic')
sns.set_style('whitegrid')
sns.heatmap(train_data.corr(), annot = True)
plt.show()

# %%
sns.pairplot(train_data[['IW', 'IF', 'VW', 'FP', 'Depth', 'Width']], diag_kind = 'kde')

# %%
fig = plt.figure(figsize = (4, 3), dpi = 100)
sns.distplot(train_data['Depth'] , fit = norm);

# %%
fig = plt.figure(figsize = (4, 3), dpi = 100)
sns.distplot(train_data['Width'] , fit = norm);

# %%
fig = plt.figure(figsize = (4, 3), dpi = 100)
res = stats.probplot(train_data['Depth'], plot = plt)
plt.grid(color = 'b', linestyle = '--', linewidth = 0.5, alpha = .75)
plt.show()

# %%
fig = plt.figure(figsize = (4, 3), dpi = 100)
res = stats.probplot(train_data['Width'], plot = plt)
plt.grid(color = 'b', linestyle = '--', linewidth = 0.5, alpha = .75)
plt.show()

# %% [markdown]
# ##### Разбиваем выборку на массив признаков и вектор со значениями целевой переменной

# %%
# Признаки
X = train_data.drop(['Depth', 'Width'], axis = 1)
# Глубина шва
yD = train_data['Depth']
# Ширина шва
yW = train_data['Width']

# %%
# Матрица признаков
X.head()
# Out:
#    IW   IF   VW  FP
# 0  43  146  9.0  60
# 1  43  150  9.0  50
# 2  44  146  9.0  60
# 3  45  140  4.5  80
# 4  45  140  8.0  80

# %%
# Вектор целевая переменная - Глубина шва
yD.head()
# Out:
# 0    1.22
# 1    1.08
# 2    1.23
# 3    1.69
# 4    1.19
# Name: Depth, dtype: float64

# %%
# Вектор целевая переменная - Ширина шва
yW.head()
# Out:
# 0    1.765
# 1    1.815
# 2    1.795
# 3    2.510
# 4    1.970
# Name: Width, dtype: float64

# %%
print('Размерности данных (обучающая выборка)')
print(f'Матрица признаков {X.shape}')
print(f'Целевой вектор (глубина шва) {yD.shape}')
print(f'Целевой вектор (ширина шва) {yW.shape}')
# Out:
# Размерности данных (обучающая выборка)
# Матрица признаков (15, 4)
# Целевой вектор (глубина шва) (15,)
# Целевой вектор (ширина шва) (15,)

# %% [markdown]
# ##### Разбивка данных на выборки для обучения и тестирования

# %%
X_train = pd.DataFrame(train_data.iloc[:, 0:4]).values
yD_train = pd.DataFrame(train_data.iloc[:, 4:5]).values
yW_train = pd.DataFrame(train_data.iloc[:, 5:6]).values

X_test = pd.DataFrame(raw_data.iloc[:, 0:4]).values
yD_test = pd.DataFrame(raw_data.iloc[:, 4:5]).values
yW_test = pd.DataFrame(raw_data.iloc[:, 5:6]).values

# %%
# Переменные для хранения точности
test_results_width = {}
test_results_depth = {}

# %% [markdown]
# ##### Функция отрисовки результатов модели

# %%
def plt_model(x, y_test, y_predict, title_txt):
    plt.rcParams.update(plt.rcParamsDefault)
    plt.figure(figsize = (10, 4), dpi = 150)
    plt.plot(x, y_test, 'go-', linewidth = 2, markersize = 5)
    plt.plot(x, y_predict, '-r',  linewidth = 2, alpha = .75)
    plt.legend(['Измерения', 'Предсказания'])
    plt.title(title_txt)
    plt.grid(color = 'b', linestyle = '--', linewidth = 0.5, alpha = .75)
    plt.show()

# %% [markdown]
# ##### Функция обучения модели

# %%
def fit_model(pipe, x_train, y_train, x_test, y_test):
    pipe.fit(x_train, y_train)
    y_predict = pipe.predict(x_test)
    x_index = range(y_predict.shape[0])
    mae_value = mae(y_test, y_predict)
    return y_predict, x_index, mae_value

# %% [markdown]
# ##### Функция сборки и прогона модели

# %%
def run_model(pipe, x_train, y_train, x_test, y_test, model_type, model_name):
    y_predict, x_index, mae_value = fit_model(pipe, x_train, y_train, x_test, y_test)
    plt_model(x_index, y_test, y_predict, f'{model_type}: {model_name} Model MAE: {mae(y_test, y_predict):0.3}')
    return mae_value

# %% [markdown]
# ### Применение метода линейной регрессии для анализа

# %%
pipe = make_pipeline(StandardScaler(), LinearRegression())
test_results_width['LinearRegression'] = run_model(pipe, X_train, yW_train, X_test, yW_test, 'Width', 'LinearRegression')

# %%
pipe = make_pipeline(StandardScaler(), PolynomialFeatures(), LinearRegression())
test_results_width['PolynomialFeatures'] = run_model(pipe, X_train, yW_train, X_test, yW_test, 'Width', 'PolynomialFeatures')

# %%
pipe = make_pipeline(StandardScaler(), LinearRegression())
test_results_depth['LinearRegression'] = run_model(pipe, X_train, yD_train, X_test, yD_test, 'Depth', 'LinearRegression')

# %%
pipe = make_pipeline(StandardScaler(), PolynomialFeatures(), LinearRegression())
test_results_depth['PolynomialFeatures'] = run_model(pipe, X_train, yD_train, X_test, yD_test, 'Depth', 'PolynomialFeatures')

# %% [markdown]
# ### Применение метода опорных векторов для анализа

# %%
pipe = make_pipeline(StandardScaler(), SVR(C = 1.0, epsilon = 0.01))
test_results_width['SupportVectorRegression'] = run_model(pipe, X_train, yW_train, X_test, yW_test, 'Width', 'SupportVectorRegression')

# %%
pipe = make_pipeline(StandardScaler(), SVR(C = 1.0, epsilon = 0.01))
test_results_depth['SupportVectorRegression'] = run_model(pipe, X_train, yD_train, X_test, yD_test, 'Depth', 'SupportVectorRegression')

# %% [markdown]
# ### Применение нейронной сети для анализа

# %%
train_features = pd.DataFrame(train_data.iloc[:, 0:4]).values
train_labels = pd.DataFrame(train_data.iloc[:, 4:6]).values
test_features = pd.DataFrame(raw_data.iloc[:, 0:4]).values
test_labels = pd.DataFrame(raw_data.iloc[:, 4:6]).values

# %%
normalizer = tf.keras.layers.Normalization(axis = -1)
normalizer.adapt(np.array(train_features))
print(normalizer.mean.numpy())
# Out:
# [[ 45.8   140.867   8.867  80.667]]

# %%
pd.DataFrame(train_data.iloc[:, 0:4]).describe().T
# Out:
#     count        mean        std    min    25%    50%    75%    max
# IW   15.0   45.800000   1.740279   43.0   45.0   46.0   47.0   49.0
# IF   15.0  140.866667   5.462426  131.0  139.5  141.0  146.0  150.0
# VW   15.0    8.866667   2.021904    4.5    8.5    9.0   10.0   12.0
# FP   15.0   80.666667  23.057898   50.0   60.0   80.0   80.0  125.0

# %%
seq_model = keras.Sequential([normalizer,
                              layers.Dense(64, activation = 'relu'),
                              layers.Dense(32, activation = 'relu'),
                              layers.Dense(2)
                             ])
seq_model.compile(loss = 'mean_absolute_error', optimizer = tf.keras.optimizers.Adam(0.001), metrics = ['accuracy'])
seq_model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  normalization (Normalizatio  (None, 4)                9
#  n)
#
#  dense (Dense)               (None, 64)                320
#
#  dense_1 (Dense)             (None, 32)                2080
#
#  dense_2 (Dense)             (None, 2)                 66
#
# =================================================================
# Total params: 2,475
# Trainable params: 2,466
# Non-trainable params: 9
# _________________________________________________________________

# %%
history = seq_model.fit(train_features, train_labels, epochs = 1000, verbose = 1, validation_split = 0.01)
# Out:
# Epoch 1/1000
# 1/1 [==============================] - 0s 434ms/step - loss: 1.5995 - accuracy: 0.7143 - val_loss: 1.7161 - val_accuracy: 1.0000
# Epoch 2/1000
# 1/1 [==============================] - 0s 21ms/step - loss: 1.5718 - accuracy: 0.7143 - val_loss: 1.6918 - val_accuracy: 1.0000
# Epoch 3/1000
# 1/1 [==============================] - 0s 22ms/step - loss: 1.5442 - accuracy: 0.7857 - val_loss: 1.6589 - val_accuracy: 1.0000
# Epoch 4/1000
# 1/1 [==============================] - 0s 23ms/step - loss: 1.5167 - accuracy: 0.8571 - val_loss: 1.6263 - val_accuracy: 1.0000
# Epoch 5/1000
# 1/1 [==============================] - 0s 22ms/step - loss: 1.4890 - accuracy: 0.9286 - val_loss: 1.5942 - val_accuracy: 1.0000
# Epoch 6/1000
# 1/1 [==============================] - 0s 21ms/step - loss: 1.4610 - accuracy: 0.9286 - val_loss: 1.5622 - val_accuracy: 1.0000
# Epoch 7/1000
# 1/1 [==============================] - 0s 21ms/step - loss: 1.4323 - accuracy: 0.9286 - val_loss: 1.5305 - val_accuracy: 1.0000
# Epoch 8/1000
# 1/1 [==============================] - 0s 22ms/step - loss: 1.4032 - accuracy: 1.0000 - val_loss: 1.4989 - val_accuracy: 1.0000
# Epoch 9/1000
# 1/1 [==============================] - 0s 23ms/step - loss: 1.3737 - accuracy: 1.0000 - val_loss: 1.4671 - val_accuracy: 1.0000
# Epoch 10/1000
# 1/1 [==============================] - 0s 23ms/step - loss: 1.3440 - accuracy: 1.0000 - val_loss: 1.4348 - val_accuracy: 1.0000
# Epoch 11/1000
# 1/1 [==============================] - 0s 23ms/step - loss: 1.3139 - accuracy: 1.0000 - val_loss: 1.4024 - val_accuracy: 1.0000
# Epoch 12/1000
# 1/1 [==============================] - 0s 22ms/step - loss: 1.2834 - accuracy: 1.0000 - val_loss: 1.3699 - val_accuracy: 1.0000
# Epoch 13/1000
# 1/1 [==============================] - 0s 22ms/step - loss: 1.2523 - accuracy: 1.0000 - val_loss: 1.3373 - val_accuracy: 1.0000
# Epoch 14/1000
# 1/1 [==============================] - 0s 22ms/step - loss: 1.2211 - accuracy: 1.0000 - val_loss: 1.3046 - val_accuracy: 1.0000
# Epoch 15/1000
# 1/1 [==============================] - 0s 22ms/step - loss: 1.1893 - accuracy: 1.0000 - val_loss: 1.2718 - val_accuracy: 1.0000
# Epoch 16/1000
# 1/1 [==============================] - 0s 20ms/step - loss: 1.1567 - accuracy: 1.0000 - val_loss: 1.2388 - val_accuracy: 1.0000
# Epoch 17/1000
# 1/1 [==============================] - 0s 22ms/step - loss: 1.1234 - accuracy: 1.0000 - val_loss: 1.2057 - val_accuracy: 1.0000
# Epoch 18/1000
# 1/1 [==============================] - 0s 21ms/step - loss: 1.0931 - accuracy: 1.0000 - val_loss: 1.1724 - val_accuracy: 1.0000
# Epoch 19/1000
# 1/1 [==============================] - 0s 21ms/step - loss: 1.0645 - accuracy: 1.0000 - val_loss: 1.1389 - val_accuracy: 1.0000
# Epoch 20/1000
# 1/1 [==============================] - 0s 21ms/step - loss: 1.0353 - accuracy: 1.0000 - val_loss: 1.1052 - val_accuracy: 1.0000
# Epoch 21/1000
# 1/1 [==============================] - 0s 22ms/step - loss: 1.0056 - accuracy: 1.0000 - val_loss: 1.0712 - val_accuracy: 1.0000
# Epoch 22/1000
# 1/1 [==============================] - 0s 22ms/step - loss: 0.9751 - accuracy: 1.0000 - val_loss: 1.0369 - val_accuracy: 1.0000
# Epoch 23/1000
# 1/1 [==============================] - 0s 21ms/step - loss: 0.9444 - accuracy: 1.0000 - val_loss: 1.0022 - val_accuracy: 1.0000
# Epoch 24/1000
# 1/1 [==============================] - 0s 22ms/step - loss: 0.9147 - accuracy: 1.0000 - val_loss: 0.9672 - val_accuracy: 1.0000
# Epoch 25/1000
# 1/1 [==============================] - 0s 22ms/step - loss: 0.8870 - accuracy: 1.0000 - val_loss: 0.9318 - val_accuracy: 1.0000
# Epoch 26/1000
# 1/1 [==============================] - 0s 22ms/step - loss: 0.8633 - accuracy: 1.0000 - val_loss: 0.8959 - val_accuracy: 1.0000
# Epoch 27/1000
# 1/1 [==============================] - 0s 22ms/step - loss: 0.8408 - accuracy: 1.0000 - val_loss: 0.8593 - val_accuracy: 1.0000
# Epoch 28/1000
# 1/1 [==============================] - 0s 22ms/step - loss: 0.8181 - accuracy: 1.0000 - val_loss: 0.8223 - val_accuracy: 1.0000
# Epoch 29/1000
# 1/1 [==============================] - 0s 21ms/step - loss: 0.7946 - accuracy: 1.0000 - val_loss: 0.7847 - val_accuracy: 1.0000
# Epoch 30/1000
# 1/1 [==============================] - 0s 22ms/step - loss: 0.7707 - accuracy: 1.0000 - val_loss: 0.7467 - val_accuracy: 1.0000
# Epoch 31/1000
# 1/1 [==============================] - 0s 21ms/step - loss: 0.7467 - accuracy: 1.0000 - val_loss: 0.7107 - val_accuracy: 1.0000
# Epoch 32/1000
# 1/1 [==============================] - 0s 22ms/step - loss: 0.7257 - accuracy: 1.0000 - val_loss: 0.6738 - val_accuracy: 1.0000
# Epoch 33/1000
# 1/1 [==============================] - 0s 22ms/step - loss: 0.7061 - accuracy: 1.0000 - val_loss: 0.6342 - val_accuracy: 1.0000
# Epoch 34/1000
# 1/1 [==============================] - 0s 20ms/step - loss: 0.6869 - accuracy: 1.0000 - val_loss: 0.5930 - val_accuracy: 1.0000
# Epoch 35/1000
# 1/1 [==============================] - 0s 22ms/step - loss: 0.6673 - accuracy: 1.0000 - val_loss: 0.5497 - val_accuracy: 1.0000
# Epoch 36/1000
# 1/1 [==============================] - 0s 22ms/step - loss: 0.6484 - accuracy: 1.0000 - val_loss: 0.5033 - val_accuracy: 1.0000
# Epoch 37/1000
# 1/1 [==============================] - 0s 22ms/step - loss: 0.6301 - accuracy: 1.0000 - val_loss: 0.4557 - val_accuracy: 1.0000
# Epoch 38/1000
# 1/1 [==============================] - 0s 21ms/step - loss: 0.6109 - accuracy: 1.0000 - val_loss: 0.4068 - val_accuracy: 1.0000
# Epoch 39/1000
# 1/1 [==============================] - 0s 20ms/step - loss: 0.5914 - accuracy: 1.0000 - val_loss: 0.3573 - val_accuracy: 1.0000
# Epoch 40/1000
# 1/1 [==============================] - 0s 22ms/step - loss: 0.5725 - accuracy: 1.0000 - val_loss: 0.3071 - val_accuracy: 1.0000
# Epoch 41/1000
# 1/1 [==============================] - 0s 21ms/step - loss: 0.5516 - accuracy: 1.0000 - val_loss: 0.2555 - val_accuracy: 1.0000
# Epoch 42/1000
# 1/1 [==============================] - 0s 22ms/step - loss: 0.5290 - accuracy: 1.0000 - val_loss: 0.2024 - val_accuracy: 1.0000
# Epoch 43/1000
# 1/1 [==============================] - 0s 22ms/step - loss: 0.5084 - accuracy: 1.0000 - val_loss: 0.1476 - val_accuracy: 1.0000
# Epoch 44/1000
# 1/1 [==============================] - 0s 21ms/step - loss: 0.4880 - accuracy: 1.0000 - val_loss: 0.1143 - val_accuracy: 1.0000
# Epoch 45/1000
# 1/1 [==============================] - 0s 24ms/step - loss: 0.4708 - accuracy: 1.0000 - val_loss: 0.1089 - val_accuracy: 1.0000
# Epoch 46/1000
# 1/1 [==============================] - 0s 24ms/step - loss: 0.4612 - accuracy: 1.0000 - val_loss: 0.1040 - val_accuracy: 1.0000
# Epoch 47/1000
# 1/1 [==============================] - 0s 21ms/step - loss: 0.4514 - accuracy: 1.0000 - val_loss: 0.0998 - val_accuracy: 1.0000
# Epoch 48/1000
# 1/1 [==============================] - 0s 21ms/step - loss: 0.4412 - accuracy: 1.0000 - val_loss: 0.0987 - val_accuracy: 1.0000
# Epoch 49/1000
# 1/1 [==============================] - 0s 22ms/step - loss: 0.4328 - accuracy: 1.0000 - val_loss: 0.1394 - val_accuracy: 1.0000
# Epoch 50/1000
# 1/1 [==============================] - 0s 21ms/step - loss: 0.4251 - accuracy: 1.0000 - val_loss: 0.1775 - val_accuracy: 1.0000
# Epoch 51/1000
# 1/1 [==============================] - 0s 20ms/step - loss: 0.4169 - accuracy: 1.0000 - val_loss: 0.2132 - val_accuracy: 1.0000
# Epoch 52/1000
# 1/1 [==============================] - 0s 21ms/step - loss: 0.4081 - accuracy: 1.0000 - val_loss: 0.2491 - val_accuracy: 1.0000
# Epoch 53/1000
# 1/1 [==============================] - 0s 21ms/step - loss: 0.3989 - accuracy: 1.0000 - val_loss: 0.2842 - val_accuracy: 1.0000
# Epoch 54/1000
# 1/1 [==============================] - 0s 20ms/step - loss: 0.3894 - accuracy: 1.0000 - val_loss: 0.3172 - val_accuracy: 1.0000
# Epoch 55/1000
# 1/1 [==============================] - 0s 20ms/step - loss: 0.3823 - accuracy: 1.0000 - val_loss: 0.3432 - val_accuracy: 1.0000
# Epoch 56/1000
# 1/1 [==============================] - 0s 20ms/step - loss: 0.3746 - accuracy: 1.0000 - val_loss: 0.3619 - val_accuracy: 1.0000
# Epoch 57/1000
# 1/1 [==============================] - 0s 20ms/step - loss: 0.3663 - accuracy: 1.0000 - val_loss: 0.3741 - val_accuracy: 1.0000
# Epoch 58/1000
# 1/1 [==============================] - 0s 20ms/step - loss: 0.3587 - accuracy: 1.0000 - val_loss: 0.3795 - val_accuracy: 1.0000
# Epoch 59/1000
# 1/1 [==============================] - 0s 21ms/step - loss: 0.3510 - accuracy: 1.0000 - val_loss: 0.3788 - val_accuracy: 1.0000
# Epoch 60/1000
# 1/1 [==============================] - 0s 20ms/step - loss: 0.3427 - accuracy: 1.0000 - val_loss: 0.3730 - val_accuracy: 1.0000
# Epoch 61/1000
# 1/1 [==============================] - 0s 20ms/step - loss: 0.3347 - accuracy: 1.0000 - val_loss: 0.3619 - val_accuracy: 1.0000
# Epoch 62/1000
# 1/1 [==============================] - 0s 20ms/step - loss: 0.3259 - accuracy: 1.0000 - val_loss: 0.3463 - val_accuracy: 1.0000
# Epoch 63/1000
# 1/1 [==============================] - 0s 20ms/step - loss: 0.3197 - accuracy: 1.0000 - val_loss: 0.3284 - val_accuracy: 1.0000
# Epoch 64/1000
# 1/1 [==============================] - 0s 20ms/step - loss: 0.3140 - accuracy: 1.0000 - val_loss: 0.3113 - val_accuracy: 1.0000
# Epoch 65/1000
# 1/1 [==============================] - 0s 20ms/step - loss: 0.3092 - accuracy: 1.0000 - val_loss: 0.2950 - val_accuracy: 1.0000
# Epoch 66/1000
# 1/1 [==============================] - 0s 20ms/step - loss: 0.3041 - accuracy: 1.0000 - val_loss: 0.2798 - val_accuracy: 1.0000
# Epoch 67/1000
# 1/1 [==============================] - 0s 20ms/step - loss: 0.3004 - accuracy: 1.0000 - val_loss: 0.2638 - val_accuracy: 1.0000
# Epoch 68/1000
# 1/1 [==============================] - 0s 21ms/step - loss: 0.2966 - accuracy: 1.0000 - val_loss: 0.2472 - val_accuracy: 1.0000
# Epoch 69/1000
# 1/1 [==============================] - 0s 20ms/step - loss: 0.2935 - accuracy: 1.0000 - val_loss: 0.2309 - val_accuracy: 1.0000
# Epoch 70/1000
# 1/1 [==============================] - 0s 20ms/step - loss: 0.2909 - accuracy: 1.0000 - val_loss: 0.2156 - val_accuracy: 1.0000
# Epoch 71/1000
# 1/1 [==============================] - 0s 20ms/step - loss: 0.2881 - accuracy: 1.0000 - val_loss: 0.2014 - val_accuracy: 1.0000
# Epoch 72/1000
# 1/1 [==============================] - 0s 20ms/step - loss: 0.2846 - accuracy: 1.0000 - val_loss: 0.1870 - val_accuracy: 1.0000
# Epoch 73/1000
# 1/1 [==============================] - 0s 21ms/step - loss: 0.2814 - accuracy: 1.0000 - val_loss: 0.1725 - val_accuracy: 1.0000
# Epoch 74/1000
# 1/1 [==============================] - 0s 21ms/step - loss: 0.2776 - accuracy: 1.0000 - val_loss: 0.1579 - val_accuracy: 1.0000
# Epoch 75/1000
# 1/1 [==============================] - 0s 20ms/step - loss: 0.2731 - accuracy: 1.0000 - val_loss: 0.1433 - val_accuracy: 1.0000
# Epoch 76/1000
# 1/1 [==============================] - 0s 20ms/step - loss: 0.2689 - accuracy: 1.0000 - val_loss: 0.1281 - val_accuracy: 1.0000
# Epoch 77/1000
# 1/1 [==============================] - 0s 20ms/step - loss: 0.2644 - accuracy: 1.0000 - val_loss: 0.1123 - val_accuracy: 1.0000
# Epoch 78/1000
# 1/1 [==============================] - 0s 21ms/step - loss: 0.2614 - accuracy: 1.0000 - val_loss: 0.0976 - val_accuracy: 1.0000
# Epoch 79/1000
# 1/1 [==============================] - 0s 20ms/step - loss: 0.2597 - accuracy: 1.0000 - val_loss: 0.0891 - val_accuracy: 1.0000
# Epoch 80/1000
# 1/1 [==============================] - 0s 20ms/step - loss: 0.2578 - accuracy: 1.0000 - val_loss: 0.0942 - val_accuracy: 1.0000
# Epoch 81/1000
# 1/1 [==============================] - 0s 20ms/step - loss: 0.2555 - accuracy: 1.0000 - val_loss: 0.0983 - val_accuracy: 1.0000
# Epoch 82/1000
# 1/1 [==============================] - 0s 20ms/step - loss: 0.2530 - accuracy: 1.0000 - val_loss: 0.1016 - val_accuracy: 1.0000
# Epoch 83/1000
# 1/1 [==============================] - 0s 20ms/step - loss: 0.2503 - accuracy: 1.0000 - val_loss: 0.1041 - val_accuracy: 1.0000
# Epoch 84/1000
# 1/1 [==============================] - 0s 20ms/step - loss: 0.2473 - accuracy: 1.0000 - val_loss: 0.1059 - val_accuracy: 1.0000
# Epoch 85/1000
# 1/1 [==============================] - 0s 21ms/step - loss: 0.2446 - accuracy: 1.0000 - val_loss: 0.1074 - val_accuracy: 1.0000
# Epoch 86/1000
# 1/1 [==============================] - 0s 20ms/step - loss: 0.2418 - accuracy: 1.0000 - val_loss: 0.1087 - val_accuracy: 1.0000
# Epoch 87/1000
# 1/1 [==============================] - 0s 20ms/step - loss: 0.2390 - accuracy: 1.0000 - val_loss: 0.1088 - val_accuracy: 1.0000
# Epoch 88/1000
# 1/1 [==============================] - 0s 20ms/step - loss: 0.2358 - accuracy: 1.0000 - val_loss: 0.1088 - val_accuracy: 1.0000
# Epoch 89/1000
# 1/1 [==============================] - 0s 21ms/step - loss: 0.2326 - accuracy: 1.0000 - val_loss: 0.1087 - val_accuracy: 1.0000
# Epoch 90/1000
# 1/1 [==============================] - 0s 20ms/step - loss: 0.2296 - accuracy: 1.0000 - val_loss: 0.1082 - val_accuracy: 1.0000
# Epoch 91/1000
# 1/1 [==============================] - 0s 21ms/step - loss: 0.2266 - accuracy: 1.0000 - val_loss: 0.1066 - val_accuracy: 1.0000
# Epoch 92/1000
# 1/1 [==============================] - 0s 22ms/step - loss: 0.2239 - accuracy: 1.0000 - val_loss: 0.1043 - val_accuracy: 1.0000
# Epoch 93/1000
# 1/1 [==============================] - 0s 20ms/step - loss: 0.2211 - accuracy: 1.0000 - val_loss: 0.1014 - val_accuracy: 1.0000
# Epoch 94/1000
# 1/1 [==============================] - 0s 20ms/step - loss: 0.2180 - accuracy: 1.0000 - val_loss: 0.0981 - val_accuracy: 1.0000
# Epoch 95/1000
# 1/1 [==============================] - 0s 20ms/step - loss: 0.2149 - accuracy: 1.0000 - val_loss: 0.0943 - val_accuracy: 1.0000
# Epoch 96/1000
# 1/1 [==============================] - 0s 21ms/step - loss: 0.2117 - accuracy: 1.0000 - val_loss: 0.0920 - val_accuracy: 1.0000
# Epoch 97/1000
# 1/1 [==============================] - 0s 21ms/step - loss: 0.2088 - accuracy: 1.0000 - val_loss: 0.0907 - val_accuracy: 1.0000
# Epoch 98/1000
# 1/1 [==============================] - 0s 21ms/step - loss: 0.2059 - accuracy: 1.0000 - val_loss: 0.0905 - val_accuracy: 1.0000
# Epoch 99/1000
# 1/1 [==============================] - 0s 20ms/step - loss: 0.2033 - accuracy: 1.0000 - val_loss: 0.0890 - val_accuracy: 1.0000
# Epoch 100/1000
# 1/1 [==============================] - 0s 21ms/step - loss: 0.2006 - accuracy: 1.0000 - val_loss: 0.0875 - val_accuracy: 1.0000
# Epoch 101/1000
# 1/1 [==============================] - 0s 20ms/step - loss: 0.1980 - accuracy: 1.0000 - val_loss: 0.0856 - val_accuracy: 1.0000
# Epoch 102/1000
# 1/1 [==============================] - 0s 20ms/step - loss: 0.1949 - accuracy: 1.0000 - val_loss: 0.0832 - val_accuracy: 1.0000
# Epoch 103/1000
# 1/1 [==============================] - 0s 20ms/step - loss: 0.1922 - accuracy: 1.0000 - val_loss: 0.0802 - val_accuracy: 1.0000
# Epoch 104/1000
# 1/1 [==============================] - 0s 20ms/step - loss: 0.1896 - accuracy: 1.0000 - val_loss: 0.0844 - val_accuracy: 1.0000
# Epoch 105/1000
# 1/1 [==============================] - 0s 19ms/step - loss: 0.1866 - accuracy: 1.0000 - val_loss: 0.0905 - val_accuracy: 1.0000
# Epoch 106/1000
# 1/1 [==============================] - 0s 20ms/step - loss: 0.1850 - accuracy: 1.0000 - val_loss: 0.0934 - val_accuracy: 1.0000
# Epoch 107/1000
# 1/1 [==============================] - 0s 21ms/step - loss: 0.1825 - accuracy: 1.0000 - val_loss: 0.0933 - val_accuracy: 1.0000
# Epoch 108/1000
# 1/1 [==============================] - 0s 20ms/step - loss: 0.1789 - accuracy: 1.0000 - val_loss: 0.0922 - val_accuracy: 1.0000
# Epoch 109/1000
# 1/1 [==============================] - 0s 20ms/step - loss: 0.1766 - accuracy: 1.0000 - val_loss: 0.0931 - val_accuracy: 1.0000
# Epoch 110/1000
# 1/1 [==============================] - 0s 20ms/step - loss: 0.1749 - accuracy: 1.0000 - val_loss: 0.0947 - val_accuracy: 1.0000
# Epoch 111/1000
# 1/1 [==============================] - 0s 21ms/step - loss: 0.1727 - accuracy: 1.0000 - val_loss: 0.0979 - val_accuracy: 1.0000
# Epoch 112/1000
# 1/1 [==============================] - 0s 21ms/step - loss: 0.1700 - accuracy: 1.0000 - val_loss: 0.1012 - val_accuracy: 1.0000
# Epoch 113/1000
# 1/1 [==============================] - 0s 23ms/step - loss: 0.1667 - accuracy: 1.0000 - val_loss: 0.1052 - val_accuracy: 1.0000
# Epoch 114/1000
# 1/1 [==============================] - 0s 21ms/step - loss: 0.1634 - accuracy: 1.0000 - val_loss: 0.1083 - val_accuracy: 1.0000
# Epoch 115/1000
# 1/1 [==============================] - 0s 21ms/step - loss: 0.1608 - accuracy: 1.0000 - val_loss: 0.1105 - val_accuracy: 1.0000
# Epoch 116/1000
# 1/1 [==============================] - 0s 22ms/step - loss: 0.1579 - accuracy: 1.0000 - val_loss: 0.1120 - val_accuracy: 1.0000
# Epoch 117/1000
# 1/1 [==============================] - 0s 21ms/step - loss: 0.1553 - accuracy: 1.0000 - val_loss: 0.1171 - val_accuracy: 1.0000
# Epoch 118/1000
# 1/1 [==============================] - 0s 21ms/step - loss: 0.1520 - accuracy: 1.0000 - val_loss: 0.1242 - val_accuracy: 1.0000
# Epoch 119/1000
# 1/1 [==============================] - 0s 20ms/step - loss: 0.1494 - accuracy: 1.0000 - val_loss: 0.1286 - val_accuracy: 1.0000
# Epoch 120/1000
# 1/1 [==============================] - 0s 20ms/step - loss: 0.1462 - accuracy: 1.0000 - val_loss: 0.1330 - val_accuracy: 1.0000
# Epoch 121/1000
# 1/1 [==============================] - 0s 21ms/step - loss: 0.1439 - accuracy: 1.0000 - val_loss: 0.1393 - val_accuracy: 1.0000
# Epoch 122/1000
# 1/1 [==============================] - 0s 21ms/step - loss: 0.1417 - accuracy: 1.0000 - val_loss: 0.1450 - val_accuracy: 1.0000
# Epoch 123/1000
# 1/1 [==============================] - 0s 21ms/step - loss: 0.1390 - accuracy: 1.0000 - val_loss: 0.1451 - val_accuracy: 1.0000
# Epoch 124/1000
# 1/1 [==============================] - 0s 22ms/step - loss: 0.1366 - accuracy: 1.0000 - val_loss: 0.1427 - val_accuracy: 1.0000
# Epoch 125/1000
# 1/1 [==============================] - 0s 20ms/step - loss: 0.1343 - accuracy: 1.0000 - val_loss: 0.1403 - val_accuracy: 1.0000
# Epoch 126/1000
# 1/1 [==============================] - 0s 20ms/step - loss: 0.1324 - accuracy: 1.0000 - val_loss: 0.1435 - val_accuracy: 1.0000
# Epoch 127/1000
# 1/1 [==============================] - 0s 20ms/step - loss: 0.1299 - accuracy: 1.0000 - val_loss: 0.1539 - val_accuracy: 1.0000
# Epoch 128/1000
# 1/1 [==============================] - 0s 20ms/step - loss: 0.1266 - accuracy: 1.0000 - val_loss: 0.1627 - val_accuracy: 1.0000
# Epoch 129/1000
# 1/1 [==============================] - 0s 20ms/step - loss: 0.1255 - accuracy: 1.0000 - val_loss: 0.1648 - val_accuracy: 1.0000
# Epoch 130/1000
# 1/1 [==============================] - 0s 20ms/step - loss: 0.1227 - accuracy: 1.0000 - val_loss: 0.1614 - val_accuracy: 1.0000
# Epoch 131/1000
# 1/1 [==============================] - 0s 20ms/step - loss: 0.1210 - accuracy: 1.0000 - val_loss: 0.1633 - val_accuracy: 1.0000
# Epoch 132/1000
# 1/1 [==============================] - 0s 20ms/step - loss: 0.1187 - accuracy: 1.0000 - val_loss: 0.1699 - val_accuracy: 1.0000
# Epoch 133/1000
# 1/1 [==============================] - 0s 21ms/step - loss: 0.1172 - accuracy: 1.0000 - val_loss: 0.1766 - val_accuracy: 1.0000
# Epoch 134/1000
# 1/1 [==============================] - 0s 21ms/step - loss: 0.1139 - accuracy: 1.0000 - val_loss: 0.1855 - val_accuracy: 1.0000
# Epoch 135/1000
# 1/1 [==============================] - 0s 20ms/step - loss: 0.1118 - accuracy: 1.0000 - val_loss: 0.1919 - val_accuracy: 1.0000
# Epoch 136/1000
# 1/1 [==============================] - 0s 20ms/step - loss: 0.1103 - accuracy: 1.0000 - val_loss: 0.1922 - val_accuracy: 1.0000
# Epoch 137/1000
# 1/1 [==============================] - 0s 20ms/step - loss: 0.1078 - accuracy: 1.0000 - val_loss: 0.1873 - val_accuracy: 1.0000
# Epoch 138/1000
# 1/1 [==============================] - 0s 20ms/step - loss: 0.1043 - accuracy: 1.0000 - val_loss: 0.1832 - val_accuracy: 1.0000
# Epoch 139/1000
# 1/1 [==============================] - 0s 20ms/step - loss: 0.1030 - accuracy: 1.0000 - val_loss: 0.1828 - val_accuracy: 1.0000
# Epoch 140/1000
# 1/1 [==============================] - 0s 20ms/step - loss: 0.1012 - accuracy: 1.0000 - val_loss: 0.1821 - val_accuracy: 1.0000
# Epoch 141/1000
# 1/1 [==============================] - 0s 20ms/step - loss: 0.0987 - accuracy: 1.0000 - val_loss: 0.1843 - val_accuracy: 1.0000
# Epoch 142/1000
# 1/1 [==============================] - 0s 20ms/step - loss: 0.0956 - accuracy: 1.0000 - val_loss: 0.1899 - val_accuracy: 1.0000
# Epoch 143/1000
# 1/1 [==============================] - 0s 21ms/step - loss: 0.0930 - accuracy: 1.0000 - val_loss: 0.1928 - val_accuracy: 1.0000
# Epoch 144/1000
# 1/1 [==============================] - 0s 21ms/step - loss: 0.0907 - accuracy: 1.0000 - val_loss: 0.1955 - val_accuracy: 1.0000
# Epoch 145/1000
# 1/1 [==============================] - 0s 20ms/step - loss: 0.0892 - accuracy: 1.0000 - val_loss: 0.1955 - val_accuracy: 1.0000
# Epoch 146/1000
# 1/1 [==============================] - 0s 20ms/step - loss: 0.0866 - accuracy: 1.0000 - val_loss: 0.1963 - val_accuracy: 1.0000
# Epoch 147/1000
# 1/1 [==============================] - 0s 21ms/step - loss: 0.0846 - accuracy: 1.0000 - val_loss: 0.1951 - val_accuracy: 1.0000
# Epoch 148/1000
# 1/1 [==============================] - 0s 20ms/step - loss: 0.0829 - accuracy: 1.0000 - val_loss: 0.1910 - val_accuracy: 1.0000
# Epoch 149/1000
# 1/1 [==============================] - 0s 21ms/step - loss: 0.0794 - accuracy: 1.0000 - val_loss: 0.1876 - val_accuracy: 1.0000
# Epoch 150/1000
# 1/1 [==============================] - 0s 20ms/step - loss: 0.0778 - accuracy: 1.0000 - val_loss: 0.1894 - val_accuracy: 1.0000
# Epoch 151/1000
# 1/1 [==============================] - 0s 20ms/step - loss: 0.0752 - accuracy: 1.0000 - val_loss: 0.1948 - val_accuracy: 1.0000
# Epoch 152/1000
# 1/1 [==============================] - 0s 20ms/step - loss: 0.0730 - accuracy: 1.0000 - val_loss: 0.1974 - val_accuracy: 1.0000
# Epoch 153/1000
# 1/1 [==============================] - 0s 21ms/step - loss: 0.0715 - accuracy: 1.0000 - val_loss: 0.1988 - val_accuracy: 1.0000
# Epoch 154/1000
# 1/1 [==============================] - 0s 20ms/step - loss: 0.0693 - accuracy: 1.0000 - val_loss: 0.1973 - val_accuracy: 1.0000
# Epoch 155/1000
# 1/1 [==============================] - 0s 20ms/step - loss: 0.0670 - accuracy: 1.0000 - val_loss: 0.1956 - val_accuracy: 1.0000
# Epoch 156/1000
# 1/1 [==============================] - 0s 20ms/step - loss: 0.0652 - accuracy: 1.0000 - val_loss: 0.1958 - val_accuracy: 1.0000
# Epoch 157/1000
# 1/1 [==============================] - 0s 20ms/step - loss: 0.0632 - accuracy: 1.0000 - val_loss: 0.1954 - val_accuracy: 1.0000
# Epoch 158/1000
# 1/1 [==============================] - 0s 20ms/step - loss: 0.0612 - accuracy: 1.0000 - val_loss: 0.1932 - val_accuracy: 1.0000
# Epoch 159/1000
# 1/1 [==============================] - 0s 20ms/step - loss: 0.0608 - accuracy: 1.0000 - val_loss: 0.1890 - val_accuracy: 1.0000
# Epoch 160/1000
# 1/1 [==============================] - 0s 20ms/step - loss: 0.0592 - accuracy: 1.0000 - val_loss: 0.1840 - val_accuracy: 1.0000
# Epoch 161/1000
# 1/1 [==============================] - 0s 20ms/step - loss: 0.0566 - accuracy: 1.0000 - val_loss: 0.1809 - val_accuracy: 1.0000
# Epoch 162/1000
# 1/1 [==============================] - 0s 20ms/step - loss: 0.0552 - accuracy: 1.0000 - val_loss: 0.1800 - val_accuracy: 1.0000
# Epoch 163/1000
# 1/1 [==============================] - 0s 20ms/step - loss: 0.0536 - accuracy: 1.0000 - val_loss: 0.1798 - val_accuracy: 1.0000
# Epoch 164/1000
# 1/1 [==============================] - 0s 20ms/step - loss: 0.0519 - accuracy: 1.0000 - val_loss: 0.1795 - val_accuracy: 1.0000
# Epoch 165/1000
# 1/1 [==============================] - 0s 20ms/step - loss: 0.0499 - accuracy: 1.0000 - val_loss: 0.1770 - val_accuracy: 1.0000
# Epoch 166/1000
# 1/1 [==============================] - 0s 21ms/step - loss: 0.0485 - accuracy: 1.0000 - val_loss: 0.1730 - val_accuracy: 1.0000
# Epoch 167/1000
# 1/1 [==============================] - 0s 20ms/step - loss: 0.0472 - accuracy: 1.0000 - val_loss: 0.1686 - val_accuracy: 1.0000
# Epoch 168/1000
# 1/1 [==============================] - 0s 20ms/step - loss: 0.0456 - accuracy: 1.0000 - val_loss: 0.1686 - val_accuracy: 1.0000
# Epoch 169/1000
# 1/1 [==============================] - 0s 20ms/step - loss: 0.0447 - accuracy: 1.0000 - val_loss: 0.1655 - val_accuracy: 1.0000
# Epoch 170/1000
# 1/1 [==============================] - 0s 21ms/step - loss: 0.0426 - accuracy: 1.0000 - val_loss: 0.1648 - val_accuracy: 1.0000
# Epoch 171/1000
# 1/1 [==============================] - 0s 20ms/step - loss: 0.0420 - accuracy: 1.0000 - val_loss: 0.1629 - val_accuracy: 1.0000
# Epoch 172/1000
# 1/1 [==============================] - 0s 20ms/step - loss: 0.0408 - accuracy: 1.0000 - val_loss: 0.1610 - val_accuracy: 1.0000
# Epoch 173/1000
# 1/1 [==============================] - 0s 21ms/step - loss: 0.0394 - accuracy: 1.0000 - val_loss: 0.1583 - val_accuracy: 1.0000
# Epoch 174/1000
# 1/1 [==============================] - 0s 21ms/step - loss: 0.0379 - accuracy: 1.0000 - val_loss: 0.1492 - val_accuracy: 1.0000
# Epoch 175/1000
# 1/1 [==============================] - 0s 20ms/step - loss: 0.0363 - accuracy: 1.0000 - val_loss: 0.1466 - val_accuracy: 1.0000
# Epoch 176/1000
# 1/1 [==============================] - 0s 20ms/step - loss: 0.0348 - accuracy: 1.0000 - val_loss: 0.1496 - val_accuracy: 1.0000
# Epoch 177/1000
# 1/1 [==============================] - 0s 21ms/step - loss: 0.0339 - accuracy: 1.0000 - val_loss: 0.1469 - val_accuracy: 1.0000
# Epoch 178/1000
# 1/1 [==============================] - 0s 22ms/step - loss: 0.0325 - accuracy: 1.0000 - val_loss: 0.1408 - val_accuracy: 1.0000
# Epoch 179/1000
# 1/1 [==============================] - 0s 21ms/step - loss: 0.0311 - accuracy: 1.0000 - val_loss: 0.1395 - val_accuracy: 1.0000
# Epoch 180/1000
# 1/1 [==============================] - 0s 21ms/step - loss: 0.0300 - accuracy: 1.0000 - val_loss: 0.1365 - val_accuracy: 1.0000
# Epoch 181/1000
# 1/1 [==============================] - 0s 20ms/step - loss: 0.0292 - accuracy: 1.0000 - val_loss: 0.1305 - val_accuracy: 1.0000
# Epoch 182/1000
# 1/1 [==============================] - 0s 20ms/step - loss: 0.0280 - accuracy: 1.0000 - val_loss: 0.1317 - val_accuracy: 1.0000
# Epoch 183/1000
# 1/1 [==============================] - 0s 21ms/step - loss: 0.0270 - accuracy: 1.0000 - val_loss: 0.1349 - val_accuracy: 1.0000
# Epoch 184/1000
# 1/1 [==============================] - 0s 20ms/step - loss: 0.0256 - accuracy: 1.0000 - val_loss: 0.1295 - val_accuracy: 1.0000
# Epoch 185/1000
# 1/1 [==============================] - 0s 21ms/step - loss: 0.0257 - accuracy: 1.0000 - val_loss: 0.1202 - val_accuracy: 1.0000
# Epoch 186/1000
# 1/1 [==============================] - 0s 20ms/step - loss: 0.0255 - accuracy: 1.0000 - val_loss: 0.1121 - val_accuracy: 1.0000
# Epoch 187/1000
# 1/1 [==============================] - 0s 20ms/step - loss: 0.0243 - accuracy: 1.0000 - val_loss: 0.1130 - val_accuracy: 1.0000
# Epoch 188/1000
# 1/1 [==============================] - 0s 20ms/step - loss: 0.0230 - accuracy: 1.0000 - val_loss: 0.1146 - val_accuracy: 1.0000
# Epoch 189/1000
# 1/1 [==============================] - 0s 22ms/step - loss: 0.0231 - accuracy: 1.0000 - val_loss: 0.1123 - val_accuracy: 1.0000
# Epoch 190/1000
# 1/1 [==============================] - 0s 20ms/step - loss: 0.0224 - accuracy: 1.0000 - val_loss: 0.1105 - val_accuracy: 1.0000
# Epoch 191/1000
# 1/1 [==============================] - 0s 20ms/step - loss: 0.0225 - accuracy: 1.0000 - val_loss: 0.1019 - val_accuracy: 1.0000
# Epoch 192/1000
# 1/1 [==============================] - 0s 21ms/step - loss: 0.0215 - accuracy: 1.0000 - val_loss: 0.0937 - val_accuracy: 1.0000
# Epoch 193/1000
# 1/1 [==============================] - 0s 20ms/step - loss: 0.0215 - accuracy: 1.0000 - val_loss: 0.0926 - val_accuracy: 1.0000
# Epoch 194/1000
# 1/1 [==============================] - 0s 20ms/step - loss: 0.0213 - accuracy: 1.0000 - val_loss: 0.1007 - val_accuracy: 1.0000
# Epoch 195/1000
# 1/1 [==============================] - 0s 20ms/step - loss: 0.0192 - accuracy: 1.0000 - val_loss: 0.1151 - val_accuracy: 1.0000
# Epoch 196/1000
# 1/1 [==============================] - 0s 21ms/step - loss: 0.0209 - accuracy: 1.0000 - val_loss: 0.1158 - val_accuracy: 1.0000
# Epoch 197/1000
# 1/1 [==============================] - 0s 22ms/step - loss: 0.0201 - accuracy: 1.0000 - val_loss: 0.1042 - val_accuracy: 1.0000
# Epoch 198/1000
# 1/1 [==============================] - 0s 23ms/step - loss: 0.0185 - accuracy: 1.0000 - val_loss: 0.0947 - val_accuracy: 1.0000
# Epoch 199/1000
# 1/1 [==============================] - 0s 21ms/step - loss: 0.0189 - accuracy: 1.0000 - val_loss: 0.0986 - val_accuracy: 1.0000
# Epoch 200/1000
# 1/1 [==============================] - 0s 22ms/step - loss: 0.0184 - accuracy: 1.0000 - val_loss: 0.1006 - val_accuracy: 1.0000
# Epoch 201/1000
# 1/1 [==============================] - 0s 22ms/step - loss: 0.0177 - accuracy: 1.0000 - val_loss: 0.1014 - val_accuracy: 1.0000
# Epoch 202/1000
# 1/1 [==============================] - 0s 21ms/step - loss: 0.0159 - accuracy: 1.0000 - val_loss: 0.1008 - val_accuracy: 1.0000
# Epoch 203/1000
# 1/1 [==============================] - 0s 23ms/step - loss: 0.0152 - accuracy: 1.0000 - val_loss: 0.0972 - val_accuracy: 1.0000
# Epoch 204/1000
# 1/1 [==============================] - 0s 21ms/step - loss: 0.0150 - accuracy: 1.0000 - val_loss: 0.0912 - val_accuracy: 1.0000
# Epoch 205/1000
# 1/1 [==============================] - 0s 21ms/step - loss: 0.0142 - accuracy: 1.0000 - val_loss: 0.0889 - val_accuracy: 1.0000
# Epoch 206/1000
# 1/1 [==============================] - 0s 22ms/step - loss: 0.0141 - accuracy: 1.0000 - val_loss: 0.0848 - val_accuracy: 1.0000
# Epoch 207/1000
# 1/1 [==============================] - 0s 22ms/step - loss: 0.0144 - accuracy: 1.0000 - val_loss: 0.0831 - val_accuracy: 1.0000
# Epoch 208/1000
# 1/1 [==============================] - 0s 22ms/step - loss: 0.0132 - accuracy: 1.0000 - val_loss: 0.0814 - val_accuracy: 1.0000
# Epoch 209/1000
# 1/1 [==============================] - 0s 22ms/step - loss: 0.0129 - accuracy: 1.0000 - val_loss: 0.0843 - val_accuracy: 1.0000
# Epoch 210/1000
# 1/1 [==============================] - 0s 21ms/step - loss: 0.0125 - accuracy: 1.0000 - val_loss: 0.0835 - val_accuracy: 1.0000
# Epoch 211/1000
# 1/1 [==============================] - 0s 20ms/step - loss: 0.0114 - accuracy: 1.0000 - val_loss: 0.0880 - val_accuracy: 1.0000
# Epoch 212/1000
# 1/1 [==============================] - 0s 20ms/step - loss: 0.0119 - accuracy: 1.0000 - val_loss: 0.0858 - val_accuracy: 1.0000
# Epoch 213/1000
# 1/1 [==============================] - 0s 20ms/step - loss: 0.0139 - accuracy: 1.0000 - val_loss: 0.0868 - val_accuracy: 1.0000
# Epoch 214/1000
# 1/1 [==============================] - 0s 20ms/step - loss: 0.0131 - accuracy: 1.0000 - val_loss: 0.0875 - val_accuracy: 1.0000
# Epoch 215/1000
# 1/1 [==============================] - 0s 20ms/step - loss: 0.0124 - accuracy: 1.0000 - val_loss: 0.0881 - val_accuracy: 1.0000
# Epoch 216/1000
# 1/1 [==============================] - 0s 20ms/step - loss: 0.0117 - accuracy: 1.0000 - val_loss: 0.0865 - val_accuracy: 1.0000
# Epoch 217/1000
# 1/1 [==============================] - 0s 20ms/step - loss: 0.0118 - accuracy: 1.0000 - val_loss: 0.0830 - val_accuracy: 1.0000
# Epoch 218/1000
# 1/1 [==============================] - 0s 20ms/step - loss: 0.0121 - accuracy: 1.0000 - val_loss: 0.0782 - val_accuracy: 1.0000
# Epoch 219/1000
# 1/1 [==============================] - 0s 20ms/step - loss: 0.0129 - accuracy: 1.0000 - val_loss: 0.0798 - val_accuracy: 1.0000
# Epoch 220/1000
# 1/1 [==============================] - 0s 20ms/step - loss: 0.0127 - accuracy: 1.0000 - val_loss: 0.0853 - val_accuracy: 1.0000
# Epoch 221/1000
# 1/1 [==============================] - 0s 20ms/step - loss: 0.0104 - accuracy: 1.0000 - val_loss: 0.0830 - val_accuracy: 1.0000
# Epoch 222/1000
# 1/1 [==============================] - 0s 20ms/step - loss: 0.0118 - accuracy: 1.0000 - val_loss: 0.0799 - val_accuracy: 1.0000
# Epoch 223/1000
# 1/1 [==============================] - 0s 20ms/step - loss: 0.0120 - accuracy: 1.0000 - val_loss: 0.0786 - val_accuracy: 1.0000
# Epoch 224/1000
# 1/1 [==============================] - 0s 21ms/step - loss: 0.0122 - accuracy: 1.0000 - val_loss: 0.0810 - val_accuracy: 1.0000
# Epoch 225/1000
# 1/1 [==============================] - 0s 20ms/step - loss: 0.0101 - accuracy: 1.0000 - val_loss: 0.0859 - val_accuracy: 1.0000
# Epoch 226/1000
# 1/1 [==============================] - 0s 20ms/step - loss: 0.0113 - accuracy: 1.0000 - val_loss: 0.0837 - val_accuracy: 1.0000
# Epoch 227/1000
# 1/1 [==============================] - 0s 20ms/step - loss: 0.0107 - accuracy: 1.0000 - val_loss: 0.0755 - val_accuracy: 1.0000
# Epoch 228/1000
# 1/1 [==============================] - 0s 20ms/step - loss: 0.0114 - accuracy: 1.0000 - val_loss: 0.0769 - val_accuracy: 1.0000
# Epoch 229/1000
# 1/1 [==============================] - 0s 20ms/step - loss: 0.0105 - accuracy: 1.0000 - val_loss: 0.0813 - val_accuracy: 1.0000
# Epoch 230/1000
# 1/1 [==============================] - 0s 20ms/step - loss: 0.0112 - accuracy: 1.0000 - val_loss: 0.0777 - val_accuracy: 1.0000
# Epoch 231/1000
# 1/1 [==============================] - 0s 20ms/step - loss: 0.0108 - accuracy: 1.0000 - val_loss: 0.0757 - val_accuracy: 1.0000
# Epoch 232/1000
# 1/1 [==============================] - 0s 19ms/step - loss: 0.0114 - accuracy: 1.0000 - val_loss: 0.0828 - val_accuracy: 1.0000
# Epoch 233/1000
# 1/1 [==============================] - 0s 20ms/step - loss: 0.0113 - accuracy: 1.0000 - val_loss: 0.0908 - val_accuracy: 1.0000
# Epoch 234/1000
# 1/1 [==============================] - 0s 19ms/step - loss: 0.0108 - accuracy: 1.0000 - val_loss: 0.0914 - val_accuracy: 1.0000
# Epoch 235/1000
# 1/1 [==============================] - 0s 20ms/step - loss: 0.0118 - accuracy: 1.0000 - val_loss: 0.0898 - val_accuracy: 1.0000
# Epoch 236/1000
# 1/1 [==============================] - 0s 21ms/step - loss: 0.0101 - accuracy: 1.0000 - val_loss: 0.0837 - val_accuracy: 1.0000
# Epoch 237/1000
# 1/1 [==============================] - 0s 21ms/step - loss: 0.0111 - accuracy: 1.0000 - val_loss: 0.0832 - val_accuracy: 1.0000
# Epoch 238/1000
# 1/1 [==============================] - 0s 19ms/step - loss: 0.0100 - accuracy: 1.0000 - val_loss: 0.0933 - val_accuracy: 1.0000
# Epoch 239/1000
# 1/1 [==============================] - 0s 20ms/step - loss: 0.0101 - accuracy: 1.0000 - val_loss: 0.0996 - val_accuracy: 1.0000
# Epoch 240/1000
# 1/1 [==============================] - 0s 20ms/step - loss: 0.0103 - accuracy: 1.0000 - val_loss: 0.0961 - val_accuracy: 1.0000
# Epoch 241/1000
# 1/1 [==============================] - 0s 20ms/step - loss: 0.0103 - accuracy: 1.0000 - val_loss: 0.0850 - val_accuracy: 1.0000
# Epoch 242/1000
# 1/1 [==============================] - 0s 20ms/step - loss: 0.0101 - accuracy: 1.0000 - val_loss: 0.0853 - val_accuracy: 1.0000
# Epoch 243/1000
# 1/1 [==============================] - 0s 20ms/step - loss: 0.0088 - accuracy: 1.0000 - val_loss: 0.0944 - val_accuracy: 1.0000
# Epoch 244/1000
# 1/1 [==============================] - 0s 20ms/step - loss: 0.0083 - accuracy: 1.0000 - val_loss: 0.0956 - val_accuracy: 1.0000
# Epoch 245/1000
# 1/1 [==============================] - 0s 20ms/step - loss: 0.0087 - accuracy: 1.0000 - val_loss: 0.0861 - val_accuracy: 1.0000
# Epoch 246/1000
# 1/1 [==============================] - 0s 20ms/step - loss: 0.0079 - accuracy: 1.0000 - val_loss: 0.0813 - val_accuracy: 1.0000
# Epoch 247/1000
# 1/1 [==============================] - 0s 20ms/step - loss: 0.0087 - accuracy: 1.0000 - val_loss: 0.0826 - val_accuracy: 1.0000
# Epoch 248/1000
# 1/1 [==============================] - 0s 19ms/step - loss: 0.0086 - accuracy: 1.0000 - val_loss: 0.0938 - val_accuracy: 1.0000
# Epoch 249/1000
# 1/1 [==============================] - 0s 20ms/step - loss: 0.0094 - accuracy: 1.0000 - val_loss: 0.0985 - val_accuracy: 1.0000
# Epoch 250/1000
# 1/1 [==============================] - 0s 21ms/step - loss: 0.0090 - accuracy: 1.0000 - val_loss: 0.0953 - val_accuracy: 1.0000
# Epoch 251/1000
# 1/1 [==============================] - 0s 21ms/step - loss: 0.0093 - accuracy: 1.0000 - val_loss: 0.0862 - val_accuracy: 1.0000
# Epoch 252/1000
# 1/1 [==============================] - 0s 20ms/step - loss: 0.0092 - accuracy: 1.0000 - val_loss: 0.0871 - val_accuracy: 1.0000
# Epoch 253/1000
# 1/1 [==============================] - 0s 20ms/step - loss: 0.0087 - accuracy: 1.0000 - val_loss: 0.0922 - val_accuracy: 1.0000
# Epoch 254/1000
# 1/1 [==============================] - 0s 21ms/step - loss: 0.0094 - accuracy: 1.0000 - val_loss: 0.0917 - val_accuracy: 1.0000
# Epoch 255/1000
# 1/1 [==============================] - 0s 20ms/step - loss: 0.0080 - accuracy: 1.0000 - val_loss: 0.0907 - val_accuracy: 1.0000
# Epoch 256/1000
# 1/1 [==============================] - 0s 20ms/step - loss: 0.0096 - accuracy: 1.0000 - val_loss: 0.0936 - val_accuracy: 1.0000
# Epoch 257/1000
# 1/1 [==============================] - 0s 20ms/step - loss: 0.0081 - accuracy: 1.0000 - val_loss: 0.0943 - val_accuracy: 1.0000
# Epoch 258/1000
# 1/1 [==============================] - 0s 20ms/step - loss: 0.0097 - accuracy: 1.0000 - val_loss: 0.0888 - val_accuracy: 1.0000
# Epoch 259/1000
# 1/1 [==============================] - 0s 20ms/step - loss: 0.0086 - accuracy: 1.0000 - val_loss: 0.0810 - val_accuracy: 1.0000
# Epoch 260/1000
# 1/1 [==============================] - 0s 20ms/step - loss: 0.0108 - accuracy: 1.0000 - val_loss: 0.0850 - val_accuracy: 1.0000
# Epoch 261/1000
# 1/1 [==============================] - 0s 21ms/step - loss: 0.0094 - accuracy: 1.0000 - val_loss: 0.0925 - val_accuracy: 1.0000
# Epoch 262/1000
# 1/1 [==============================] - 0s 21ms/step - loss: 0.0108 - accuracy: 1.0000 - val_loss: 0.0952 - val_accuracy: 1.0000
# Epoch 263/1000
# 1/1 [==============================] - 0s 20ms/step - loss: 0.0080 - accuracy: 1.0000 - val_loss: 0.0921 - val_accuracy: 1.0000
# Epoch 264/1000
# 1/1 [==============================] - 0s 20ms/step - loss: 0.0080 - accuracy: 1.0000 - val_loss: 0.0929 - val_accuracy: 1.0000
# Epoch 265/1000
# 1/1 [==============================] - 0s 20ms/step - loss: 0.0093 - accuracy: 1.0000 - val_loss: 0.0876 - val_accuracy: 1.0000
# Epoch 266/1000
# 1/1 [==============================] - 0s 20ms/step - loss: 0.0075 - accuracy: 1.0000 - val_loss: 0.0817 - val_accuracy: 1.0000
# Epoch 267/1000
# 1/1 [==============================] - 0s 19ms/step - loss: 0.0112 - accuracy: 1.0000 - val_loss: 0.0853 - val_accuracy: 1.0000
# Epoch 268/1000
# 1/1 [==============================] - 0s 20ms/step - loss: 0.0090 - accuracy: 1.0000 - val_loss: 0.0868 - val_accuracy: 1.0000
# Epoch 269/1000
# 1/1 [==============================] - 0s 20ms/step - loss: 0.0093 - accuracy: 1.0000 - val_loss: 0.0828 - val_accuracy: 1.0000
# Epoch 270/1000
# 1/1 [==============================] - 0s 21ms/step - loss: 0.0088 - accuracy: 1.0000 - val_loss: 0.0856 - val_accuracy: 1.0000
# Epoch 271/1000
# 1/1 [==============================] - 0s 20ms/step - loss: 0.0113 - accuracy: 1.0000 - val_loss: 0.0904 - val_accuracy: 1.0000
# Epoch 272/1000
# 1/1 [==============================] - 0s 22ms/step - loss: 0.0092 - accuracy: 1.0000 - val_loss: 0.0981 - val_accuracy: 1.0000
# Epoch 273/1000
# 1/1 [==============================] - 0s 20ms/step - loss: 0.0111 - accuracy: 1.0000 - val_loss: 0.0943 - val_accuracy: 1.0000
# Epoch 274/1000
# 1/1 [==============================] - 0s 21ms/step - loss: 0.0099 - accuracy: 1.0000 - val_loss: 0.0816 - val_accuracy: 1.0000
# Epoch 275/1000
# 1/1 [==============================] - 0s 21ms/step - loss: 0.0101 - accuracy: 1.0000 - val_loss: 0.0736 - val_accuracy: 1.0000
# Epoch 276/1000
# 1/1 [==============================] - 0s 21ms/step - loss: 0.0119 - accuracy: 1.0000 - val_loss: 0.0772 - val_accuracy: 1.0000
# Epoch 277/1000
# 1/1 [==============================] - 0s 22ms/step - loss: 0.0106 - accuracy: 1.0000 - val_loss: 0.0904 - val_accuracy: 1.0000
# Epoch 278/1000
# 1/1 [==============================] - 0s 20ms/step - loss: 0.0091 - accuracy: 1.0000 - val_loss: 0.0945 - val_accuracy: 1.0000
# Epoch 279/1000
# 1/1 [==============================] - 0s 21ms/step - loss: 0.0063 - accuracy: 1.0000 - val_loss: 0.0881 - val_accuracy: 1.0000
# Epoch 280/1000
# 1/1 [==============================] - 0s 22ms/step - loss: 0.0110 - accuracy: 1.0000 - val_loss: 0.0879 - val_accuracy: 1.0000
# Epoch 281/1000
# 1/1 [==============================] - 0s 21ms/step - loss: 0.0103 - accuracy: 1.0000 - val_loss: 0.0908 - val_accuracy: 1.0000
# Epoch 282/1000
# 1/1 [==============================] - 0s 21ms/step - loss: 0.0070 - accuracy: 1.0000 - val_loss: 0.0892 - val_accuracy: 1.0000
# Epoch 283/1000
# 1/1 [==============================] - 0s 21ms/step - loss: 0.0099 - accuracy: 1.0000 - val_loss: 0.0850 - val_accuracy: 1.0000
# Epoch 284/1000
# 1/1 [==============================] - 0s 20ms/step - loss: 0.0063 - accuracy: 1.0000 - val_loss: 0.0900 - val_accuracy: 1.0000
# Epoch 285/1000
# 1/1 [==============================] - 0s 21ms/step - loss: 0.0096 - accuracy: 1.0000 - val_loss: 0.0989 - val_accuracy: 1.0000
# Epoch 286/1000
# 1/1 [==============================] - 0s 20ms/step - loss: 0.0087 - accuracy: 1.0000 - val_loss: 0.1038 - val_accuracy: 1.0000
# Epoch 287/1000
# 1/1 [==============================] - 0s 20ms/step - loss: 0.0129 - accuracy: 1.0000 - val_loss: 0.0994 - val_accuracy: 1.0000
# Epoch 288/1000
# 1/1 [==============================] - 0s 20ms/step - loss: 0.0115 - accuracy: 1.0000 - val_loss: 0.0855 - val_accuracy: 1.0000
# Epoch 289/1000
# 1/1 [==============================] - 0s 20ms/step - loss: 0.0072 - accuracy: 1.0000 - val_loss: 0.0777 - val_accuracy: 1.0000
# Epoch 290/1000
# 1/1 [==============================] - 0s 20ms/step - loss: 0.0107 - accuracy: 1.0000 - val_loss: 0.0806 - val_accuracy: 1.0000
# Epoch 291/1000
# 1/1 [==============================] - 0s 21ms/step - loss: 0.0094 - accuracy: 1.0000 - val_loss: 0.0821 - val_accuracy: 1.0000
# Epoch 292/1000
# 1/1 [==============================] - 0s 20ms/step - loss: 0.0107 - accuracy: 1.0000 - val_loss: 0.0870 - val_accuracy: 1.0000
# Epoch 293/1000
# 1/1 [==============================] - 0s 20ms/step - loss: 0.0055 - accuracy: 1.0000 - val_loss: 0.0930 - val_accuracy: 1.0000
# Epoch 294/1000
# 1/1 [==============================] - 0s 20ms/step - loss: 0.0087 - accuracy: 1.0000 - val_loss: 0.1007 - val_accuracy: 1.0000
# Epoch 295/1000
# 1/1 [==============================] - 0s 19ms/step - loss: 0.0090 - accuracy: 1.0000 - val_loss: 0.1014 - val_accuracy: 1.0000
# Epoch 296/1000
# 1/1 [==============================] - 0s 20ms/step - loss: 0.0084 - accuracy: 1.0000 - val_loss: 0.0927 - val_accuracy: 1.0000
# Epoch 297/1000
# 1/1 [==============================] - 0s 21ms/step - loss: 0.0067 - accuracy: 1.0000 - val_loss: 0.0789 - val_accuracy: 1.0000
# Epoch 298/1000
# 1/1 [==============================] - 0s 20ms/step - loss: 0.0093 - accuracy: 1.0000 - val_loss: 0.0742 - val_accuracy: 1.0000
# Epoch 299/1000
# 1/1 [==============================] - 0s 19ms/step - loss: 0.0096 - accuracy: 1.0000 - val_loss: 0.0780 - val_accuracy: 1.0000
# Epoch 300/1000
# 1/1 [==============================] - 0s 20ms/step - loss: 0.0077 - accuracy: 1.0000 - val_loss: 0.0907 - val_accuracy: 1.0000
# Epoch 301/1000
# 1/1 [==============================] - 0s 20ms/step - loss: 0.0087 - accuracy: 1.0000 - val_loss: 0.0953 - val_accuracy: 1.0000
# Epoch 302/1000
# 1/1 [==============================] - 0s 20ms/step - loss: 0.0067 - accuracy: 1.0000 - val_loss: 0.0928 - val_accuracy: 1.0000
# Epoch 303/1000
# 1/1 [==============================] - 0s 20ms/step - loss: 0.0087 - accuracy: 1.0000 - val_loss: 0.0882 - val_accuracy: 1.0000
# Epoch 304/1000
# 1/1 [==============================] - 0s 19ms/step - loss: 0.0082 - accuracy: 1.0000 - val_loss: 0.0915 - val_accuracy: 1.0000
# Epoch 305/1000
# 1/1 [==============================] - 0s 19ms/step - loss: 0.0060 - accuracy: 1.0000 - val_loss: 0.0874 - val_accuracy: 1.0000
# Epoch 306/1000
# 1/1 [==============================] - 0s 20ms/step - loss: 0.0075 - accuracy: 1.0000 - val_loss: 0.0833 - val_accuracy: 1.0000
# Epoch 307/1000
# 1/1 [==============================] - 0s 21ms/step - loss: 0.0052 - accuracy: 1.0000 - val_loss: 0.0817 - val_accuracy: 1.0000
# Epoch 308/1000
# 1/1 [==============================] - 0s 20ms/step - loss: 0.0093 - accuracy: 1.0000 - val_loss: 0.0835 - val_accuracy: 1.0000
# Epoch 309/1000
# 1/1 [==============================] - 0s 20ms/step - loss: 0.0074 - accuracy: 1.0000 - val_loss: 0.0876 - val_accuracy: 1.0000
# Epoch 310/1000
# 1/1 [==============================] - 0s 20ms/step - loss: 0.0069 - accuracy: 1.0000 - val_loss: 0.0898 - val_accuracy: 1.0000
# Epoch 311/1000
# 1/1 [==============================] - 0s 21ms/step - loss: 0.0068 - accuracy: 1.0000 - val_loss: 0.0896 - val_accuracy: 1.0000
# Epoch 312/1000
# 1/1 [==============================] - 0s 21ms/step - loss: 0.0065 - accuracy: 1.0000 - val_loss: 0.0901 - val_accuracy: 1.0000
# Epoch 313/1000
# 1/1 [==============================] - 0s 21ms/step - loss: 0.0067 - accuracy: 1.0000 - val_loss: 0.0945 - val_accuracy: 1.0000
# Epoch 314/1000
# 1/1 [==============================] - 0s 20ms/step - loss: 0.0067 - accuracy: 1.0000 - val_loss: 0.0922 - val_accuracy: 1.0000
# Epoch 315/1000
# 1/1 [==============================] - 0s 20ms/step - loss: 0.0076 - accuracy: 1.0000 - val_loss: 0.0923 - val_accuracy: 1.0000
# Epoch 316/1000
# 1/1 [==============================] - 0s 21ms/step - loss: 0.0063 - accuracy: 1.0000 - val_loss: 0.0948 - val_accuracy: 1.0000
# Epoch 317/1000
# 1/1 [==============================] - 0s 20ms/step - loss: 0.0070 - accuracy: 1.0000 - val_loss: 0.0962 - val_accuracy: 1.0000
# Epoch 318/1000
# 1/1 [==============================] - 0s 20ms/step - loss: 0.0059 - accuracy: 1.0000 - val_loss: 0.0949 - val_accuracy: 1.0000
# Epoch 319/1000
# 1/1 [==============================] - 0s 20ms/step - loss: 0.0079 - accuracy: 1.0000 - val_loss: 0.0917 - val_accuracy: 1.0000
# Epoch 320/1000
# 1/1 [==============================] - 0s 19ms/step - loss: 0.0053 - accuracy: 1.0000 - val_loss: 0.0891 - val_accuracy: 1.0000
# Epoch 321/1000
# 1/1 [==============================] - 0s 20ms/step - loss: 0.0072 - accuracy: 1.0000 - val_loss: 0.0920 - val_accuracy: 1.0000
# Epoch 322/1000
# 1/1 [==============================] - 0s 20ms/step - loss: 0.0055 - accuracy: 1.0000 - val_loss: 0.0966 - val_accuracy: 1.0000
# Epoch 323/1000
# 1/1 [==============================] - 0s 21ms/step - loss: 0.0075 - accuracy: 1.0000 - val_loss: 0.0921 - val_accuracy: 1.0000
# Epoch 324/1000
# 1/1 [==============================] - 0s 20ms/step - loss: 0.0058 - accuracy: 1.0000 - val_loss: 0.0865 - val_accuracy: 1.0000
# Epoch 325/1000
# 1/1 [==============================] - 0s 20ms/step - loss: 0.0086 - accuracy: 1.0000 - val_loss: 0.0884 - val_accuracy: 1.0000
# Epoch 326/1000
# 1/1 [==============================] - 0s 20ms/step - loss: 0.0084 - accuracy: 1.0000 - val_loss: 0.0912 - val_accuracy: 1.0000
# Epoch 327/1000
# 1/1 [==============================] - 0s 20ms/step - loss: 0.0055 - accuracy: 1.0000 - val_loss: 0.0934 - val_accuracy: 1.0000
# Epoch 328/1000
# 1/1 [==============================] - 0s 20ms/step - loss: 0.0061 - accuracy: 1.0000 - val_loss: 0.0896 - val_accuracy: 1.0000
# Epoch 329/1000
# 1/1 [==============================] - 0s 19ms/step - loss: 0.0057 - accuracy: 1.0000 - val_loss: 0.0895 - val_accuracy: 1.0000
# Epoch 330/1000
# 1/1 [==============================] - 0s 20ms/step - loss: 0.0065 - accuracy: 1.0000 - val_loss: 0.0901 - val_accuracy: 1.0000
# Epoch 331/1000
# 1/1 [==============================] - 0s 20ms/step - loss: 0.0064 - accuracy: 1.0000 - val_loss: 0.0917 - val_accuracy: 1.0000
# Epoch 332/1000
# 1/1 [==============================] - 0s 20ms/step - loss: 0.0041 - accuracy: 1.0000 - val_loss: 0.0943 - val_accuracy: 1.0000
# Epoch 333/1000
# 1/1 [==============================] - 0s 20ms/step - loss: 0.0058 - accuracy: 1.0000 - val_loss: 0.0954 - val_accuracy: 1.0000
# Epoch 334/1000
# 1/1 [==============================] - 0s 20ms/step - loss: 0.0055 - accuracy: 1.0000 - val_loss: 0.0950 - val_accuracy: 1.0000
# Epoch 335/1000
# 1/1 [==============================] - 0s 20ms/step - loss: 0.0063 - accuracy: 1.0000 - val_loss: 0.0937 - val_accuracy: 1.0000
# Epoch 336/1000
# 1/1 [==============================] - 0s 20ms/step - loss: 0.0052 - accuracy: 1.0000 - val_loss: 0.0910 - val_accuracy: 1.0000
# Epoch 337/1000
# ...
# Epoch 890/1000
# 1/1 [==============================] - 0s 20ms/step - loss: 0.0056 - accuracy: 1.0000 - val_loss: 0.0994 - val_accuracy: 1.0000
# Epoch 891/1000
# 1/1 [==============================] - 0s 20ms/step - loss: 0.0054 - accuracy: 1.0000 - val_loss: 0.1055 - val_accuracy: 1.0000
# Epoch 892/1000
# 1/1 [==============================] - 0s 23ms/step - loss: 0.0055 - accuracy: 1.0000 - val_loss: 0.1031 - val_accuracy: 1.0000
# Epoch 893/1000
# 1/1 [==============================] - 0s 20ms/step - loss: 0.0063 - accuracy: 1.0000 - val_loss: 0.0964 - val_accuracy: 1.0000
# Epoch 894/1000
# 1/1 [==============================] - 0s 20ms/step - loss: 0.0026 - accuracy: 1.0000 - val_loss: 0.0930 - val_accuracy: 1.0000
# Epoch 895/1000
# 1/1 [==============================] - 0s 20ms/step - loss: 0.0057 - accuracy: 1.0000 - val_loss: 0.0975 - val_accuracy: 1.0000
# Epoch 896/1000
# 1/1 [==============================] - 0s 20ms/step - loss: 0.0042 - accuracy: 1.0000 - val_loss: 0.1051 - val_accuracy: 1.0000
# Epoch 897/1000
# 1/1 [==============================] - 0s 20ms/step - loss: 0.0050 - accuracy: 1.0000 - val_loss: 0.1045 - val_accuracy: 1.0000
# Epoch 898/1000
# 1/1 [==============================] - 0s 20ms/step - loss: 0.0034 - accuracy: 1.0000 - val_loss: 0.0975 - val_accuracy: 1.0000
# Epoch 899/1000
# 1/1 [==============================] - 0s 19ms/step - loss: 0.0038 - accuracy: 1.0000 - val_loss: 0.0928 - val_accuracy: 1.0000
# Epoch 900/1000
# 1/1 [==============================] - 0s 20ms/step - loss: 0.0053 - accuracy: 1.0000 - val_loss: 0.0950 - val_accuracy: 1.0000
# Epoch 901/1000
# 1/1 [==============================] - 0s 21ms/step - loss: 0.0047 - accuracy: 1.0000 - val_loss: 0.1009 - val_accuracy: 1.0000
# Epoch 902/1000
# 1/1 [==============================] - 0s 20ms/step - loss: 0.0037 - accuracy: 1.0000 - val_loss: 0.1061 - val_accuracy: 1.0000
# Epoch 903/1000
# 1/1 [==============================] - 0s 20ms/step - loss: 0.0047 - accuracy: 1.0000 - val_loss: 0.1077 - val_accuracy: 1.0000
# Epoch 904/1000
# 1/1 [==============================] - 0s 20ms/step - loss: 0.0052 - accuracy: 1.0000 - val_loss: 0.1062 - val_accuracy: 1.0000
# Epoch 905/1000
# 1/1 [==============================] - 0s 20ms/step - loss: 0.0032 - accuracy: 1.0000 - val_loss: 0.0977 - val_accuracy: 1.0000
# Epoch 906/1000
# 1/1 [==============================] - 0s 20ms/step - loss: 0.0044 - accuracy: 1.0000 - val_loss: 0.0927 - val_accuracy: 1.0000
# Epoch 907/1000
# 1/1 [==============================] - 0s 20ms/step - loss: 0.0038 - accuracy: 1.0000 - val_loss: 0.0958 - val_accuracy: 1.0000
# Epoch 908/1000
# 1/1 [==============================] - 0s 21ms/step - loss: 0.0028 - accuracy: 1.0000 - val_loss: 0.1042 - val_accuracy: 1.0000
# Epoch 909/1000
# 1/1 [==============================] - 0s 20ms/step - loss: 0.0038 - accuracy: 1.0000 - val_loss: 0.1083 - val_accuracy: 1.0000
# Epoch 910/1000
# 1/1 [==============================] - 0s 21ms/step - loss: 0.0049 - accuracy: 1.0000 - val_loss: 0.1058 - val_accuracy: 1.0000
# Epoch 911/1000
# 1/1 [==============================] - 0s 21ms/step - loss: 0.0029 - accuracy: 1.0000 - val_loss: 0.0964 - val_accuracy: 1.0000
# Epoch 912/1000
# 1/1 [==============================] - 0s 20ms/step - loss: 0.0044 - accuracy: 1.0000 - val_loss: 0.0944 - val_accuracy: 1.0000
# Epoch 913/1000
# 1/1 [==============================] - 0s 20ms/step - loss: 0.0059 - accuracy: 1.0000 - val_loss: 0.0969 - val_accuracy: 1.0000
# Epoch 914/1000
# 1/1 [==============================] - 0s 20ms/step - loss: 0.0045 - accuracy: 1.0000 - val_loss: 0.1019 - val_accuracy: 1.0000
# Epoch 915/1000
# 1/1 [==============================] - 0s 29ms/step - loss: 0.0026 - accuracy: 1.0000 - val_loss: 0.1039 - val_accuracy: 1.0000
# Epoch 916/1000
# 1/1 [==============================] - 0s 28ms/step - loss: 0.0034 - accuracy: 1.0000 - val_loss: 0.1020 - val_accuracy: 1.0000
# Epoch 917/1000
# 1/1 [==============================] - 0s 22ms/step - loss: 0.0027 - accuracy: 1.0000 - val_loss: 0.0980 - val_accuracy: 1.0000
# Epoch 918/1000
# 1/1 [==============================] - 0s 23ms/step - loss: 0.0038 - accuracy: 1.0000 - val_loss: 0.0959 - val_accuracy: 1.0000
# Epoch 919/1000
# 1/1 [==============================] - 0s 22ms/step - loss: 0.0038 - accuracy: 1.0000 - val_loss: 0.0986 - val_accuracy: 1.0000
# Epoch 920/1000
# 1/1 [==============================] - 0s 21ms/step - loss: 0.0034 - accuracy: 1.0000 - val_loss: 0.1034 - val_accuracy: 1.0000
# Epoch 921/1000
# 1/1 [==============================] - 0s 21ms/step - loss: 0.0043 - accuracy: 1.0000 - val_loss: 0.1034 - val_accuracy: 1.0000
# Epoch 922/1000
# 1/1 [==============================] - 0s 20ms/step - loss: 0.0033 - accuracy: 1.0000 - val_loss: 0.0990 - val_accuracy: 1.0000
# Epoch 923/1000
# 1/1 [==============================] - 0s 21ms/step - loss: 0.0027 - accuracy: 1.0000 - val_loss: 0.0952 - val_accuracy: 1.0000
# Epoch 924/1000
# 1/1 [==============================] - 0s 21ms/step - loss: 0.0037 - accuracy: 1.0000 - val_loss: 0.0988 - val_accuracy: 1.0000
# Epoch 925/1000
# 1/1 [==============================] - 0s 20ms/step - loss: 0.0038 - accuracy: 1.0000 - val_loss: 0.1017 - val_accuracy: 1.0000
# Epoch 926/1000
# 1/1 [==============================] - 0s 20ms/step - loss: 0.0034 - accuracy: 1.0000 - val_loss: 0.1040 - val_accuracy: 1.0000
# Epoch 927/1000
# 1/1 [==============================] - 0s 20ms/step - loss: 0.0026 - accuracy: 1.0000 - val_loss: 0.1021 - val_accuracy: 1.0000
# Epoch 928/1000
# 1/1 [==============================] - 0s 19ms/step - loss: 0.0041 - accuracy: 1.0000 - val_loss: 0.1014 - val_accuracy: 1.0000
# Epoch 929/1000
# 1/1 [==============================] - 0s 20ms/step - loss: 0.0040 - accuracy: 1.0000 - val_loss: 0.1000 - val_accuracy: 1.0000
# Epoch 930/1000
# 1/1 [==============================] - 0s 20ms/step - loss: 0.0033 - accuracy: 1.0000 - val_loss: 0.1010 - val_accuracy: 1.0000
# Epoch 931/1000
# 1/1 [==============================] - 0s 19ms/step - loss: 0.0040 - accuracy: 1.0000 - val_loss: 0.1027 - val_accuracy: 1.0000
# Epoch 932/1000
# 1/1 [==============================] - 0s 21ms/step - loss: 0.0023 - accuracy: 1.0000 - val_loss: 0.1065 - val_accuracy: 1.0000
# Epoch 933/1000
# 1/1 [==============================] - 0s 20ms/step - loss: 0.0049 - accuracy: 1.0000 - val_loss: 0.1084 - val_accuracy: 1.0000
# Epoch 934/1000
# 1/1 [==============================] - 0s 20ms/step - loss: 0.0055 - accuracy: 1.0000 - val_loss: 0.1029 - val_accuracy: 1.0000
# Epoch 935/1000
# 1/1 [==============================] - 0s 19ms/step - loss: 0.0027 - accuracy: 1.0000 - val_loss: 0.0973 - val_accuracy: 1.0000
# Epoch 936/1000
# 1/1 [==============================] - 0s 20ms/step - loss: 0.0055 - accuracy: 1.0000 - val_loss: 0.0968 - val_accuracy: 1.0000
# Epoch 937/1000
# 1/1 [==============================] - 0s 20ms/step - loss: 0.0049 - accuracy: 1.0000 - val_loss: 0.0999 - val_accuracy: 1.0000
# Epoch 938/1000
# 1/1 [==============================] - 0s 20ms/step - loss: 0.0041 - accuracy: 1.0000 - val_loss: 0.1022 - val_accuracy: 1.0000
# Epoch 939/1000
# 1/1 [==============================] - 0s 21ms/step - loss: 0.0035 - accuracy: 1.0000 - val_loss: 0.1031 - val_accuracy: 1.0000
# Epoch 940/1000
# 1/1 [==============================] - 0s 20ms/step - loss: 0.0027 - accuracy: 1.0000 - val_loss: 0.1036 - val_accuracy: 1.0000
# Epoch 941/1000
# 1/1 [==============================] - 0s 20ms/step - loss: 0.0025 - accuracy: 1.0000 - val_loss: 0.0988 - val_accuracy: 1.0000
# Epoch 942/1000
# 1/1 [==============================] - 0s 20ms/step - loss: 0.0030 - accuracy: 1.0000 - val_loss: 0.0963 - val_accuracy: 1.0000
# Epoch 943/1000
# 1/1 [==============================] - 0s 21ms/step - loss: 0.0028 - accuracy: 1.0000 - val_loss: 0.1006 - val_accuracy: 1.0000
# Epoch 944/1000
# 1/1 [==============================] - 0s 20ms/step - loss: 0.0026 - accuracy: 1.0000 - val_loss: 0.1027 - val_accuracy: 1.0000
# Epoch 945/1000
# 1/1 [==============================] - 0s 20ms/step - loss: 0.0032 - accuracy: 1.0000 - val_loss: 0.0988 - val_accuracy: 1.0000
# Epoch 946/1000
# 1/1 [==============================] - 0s 20ms/step - loss: 0.0022 - accuracy: 1.0000 - val_loss: 0.0993 - val_accuracy: 1.0000
# Epoch 947/1000
# 1/1 [==============================] - 0s 20ms/step - loss: 0.0030 - accuracy: 1.0000 - val_loss: 0.1053 - val_accuracy: 1.0000
# Epoch 948/1000
# 1/1 [==============================] - 0s 19ms/step - loss: 0.0040 - accuracy: 1.0000 - val_loss: 0.1049 - val_accuracy: 1.0000
# Epoch 949/1000
# 1/1 [==============================] - 0s 20ms/step - loss: 0.0029 - accuracy: 1.0000 - val_loss: 0.1026 - val_accuracy: 1.0000
# Epoch 950/1000
# 1/1 [==============================] - 0s 20ms/step - loss: 0.0022 - accuracy: 1.0000 - val_loss: 0.1007 - val_accuracy: 1.0000
# Epoch 951/1000
# 1/1 [==============================] - 0s 20ms/step - loss: 0.0024 - accuracy: 1.0000 - val_loss: 0.1007 - val_accuracy: 1.0000
# Epoch 952/1000
# 1/1 [==============================] - 0s 20ms/step - loss: 0.0027 - accuracy: 1.0000 - val_loss: 0.1003 - val_accuracy: 1.0000
# Epoch 953/1000
# 1/1 [==============================] - 0s 20ms/step - loss: 0.0053 - accuracy: 1.0000 - val_loss: 0.1024 - val_accuracy: 1.0000
# Epoch 954/1000
# 1/1 [==============================] - 0s 21ms/step - loss: 0.0033 - accuracy: 1.0000 - val_loss: 0.1048 - val_accuracy: 1.0000
# Epoch 955/1000
# 1/1 [==============================] - 0s 20ms/step - loss: 0.0039 - accuracy: 1.0000 - val_loss: 0.1028 - val_accuracy: 1.0000
# Epoch 956/1000
# 1/1 [==============================] - 0s 20ms/step - loss: 0.0027 - accuracy: 1.0000 - val_loss: 0.0980 - val_accuracy: 1.0000
# Epoch 957/1000
# 1/1 [==============================] - 0s 20ms/step - loss: 0.0026 - accuracy: 1.0000 - val_loss: 0.0984 - val_accuracy: 1.0000
# Epoch 958/1000
# 1/1 [==============================] - 0s 20ms/step - loss: 0.0036 - accuracy: 1.0000 - val_loss: 0.1012 - val_accuracy: 1.0000
# Epoch 959/1000
# 1/1 [==============================] - 0s 20ms/step - loss: 0.0035 - accuracy: 1.0000 - val_loss: 0.1022 - val_accuracy: 1.0000
# Epoch 960/1000
# 1/1 [==============================] - 0s 20ms/step - loss: 0.0024 - accuracy: 1.0000 - val_loss: 0.1022 - val_accuracy: 1.0000
# Epoch 961/1000
# 1/1 [==============================] - 0s 21ms/step - loss: 0.0021 - accuracy: 1.0000 - val_loss: 0.1049 - val_accuracy: 1.0000
# Epoch 962/1000
# 1/1 [==============================] - 0s 21ms/step - loss: 0.0022 - accuracy: 1.0000 - val_loss: 0.1045 - val_accuracy: 1.0000
# Epoch 963/1000
# 1/1 [==============================] - 0s 21ms/step - loss: 0.0019 - accuracy: 1.0000 - val_loss: 0.1041 - val_accuracy: 1.0000
# Epoch 964/1000
# 1/1 [==============================] - 0s 21ms/step - loss: 0.0030 - accuracy: 1.0000 - val_loss: 0.1032 - val_accuracy: 1.0000
# Epoch 965/1000
# 1/1 [==============================] - 0s 20ms/step - loss: 0.0032 - accuracy: 1.0000 - val_loss: 0.1030 - val_accuracy: 1.0000
# Epoch 966/1000
# 1/1 [==============================] - 0s 22ms/step - loss: 0.0033 - accuracy: 1.0000 - val_loss: 0.1036 - val_accuracy: 1.0000
# Epoch 967/1000
# 1/1 [==============================] - 0s 21ms/step - loss: 0.0030 - accuracy: 1.0000 - val_loss: 0.1050 - val_accuracy: 1.0000
# Epoch 968/1000
# 1/1 [==============================] - 0s 20ms/step - loss: 0.0025 - accuracy: 1.0000 - val_loss: 0.1093 - val_accuracy: 1.0000
# Epoch 969/1000
# 1/1 [==============================] - 0s 21ms/step - loss: 0.0029 - accuracy: 1.0000 - val_loss: 0.1064 - val_accuracy: 1.0000
# Epoch 970/1000
# 1/1 [==============================] - 0s 21ms/step - loss: 0.0030 - accuracy: 1.0000 - val_loss: 0.1028 - val_accuracy: 1.0000
# Epoch 971/1000
# 1/1 [==============================] - 0s 20ms/step - loss: 0.0016 - accuracy: 1.0000 - val_loss: 0.1006 - val_accuracy: 1.0000
# Epoch 972/1000
# 1/1 [==============================] - 0s 21ms/step - loss: 0.0024 - accuracy: 1.0000 - val_loss: 0.0979 - val_accuracy: 1.0000
# Epoch 973/1000
# 1/1 [==============================] - 0s 21ms/step - loss: 0.0032 - accuracy: 1.0000 - val_loss: 0.1029 - val_accuracy: 1.0000
# Epoch 974/1000
# 1/1 [==============================] - 0s 21ms/step - loss: 0.0032 - accuracy: 1.0000 - val_loss: 0.1057 - val_accuracy: 1.0000
# Epoch 975/1000
# 1/1 [==============================] - 0s 21ms/step - loss: 0.0034 - accuracy: 1.0000 - val_loss: 0.1002 - val_accuracy: 1.0000
# Epoch 976/1000
# 1/1 [==============================] - 0s 20ms/step - loss: 0.0018 - accuracy: 1.0000 - val_loss: 0.0980 - val_accuracy: 1.0000
# Epoch 977/1000
# 1/1 [==============================] - 0s 21ms/step - loss: 0.0032 - accuracy: 1.0000 - val_loss: 0.1035 - val_accuracy: 1.0000
# Epoch 978/1000
# 1/1 [==============================] - 0s 21ms/step - loss: 0.0025 - accuracy: 1.0000 - val_loss: 0.1055 - val_accuracy: 1.0000
# Epoch 979/1000
# 1/1 [==============================] - 0s 20ms/step - loss: 0.0021 - accuracy: 1.0000 - val_loss: 0.1003 - val_accuracy: 1.0000
# Epoch 980/1000
# 1/1 [==============================] - 0s 20ms/step - loss: 0.0027 - accuracy: 1.0000 - val_loss: 0.0979 - val_accuracy: 1.0000
# Epoch 981/1000
# 1/1 [==============================] - 0s 20ms/step - loss: 0.0033 - accuracy: 1.0000 - val_loss: 0.0997 - val_accuracy: 1.0000
# Epoch 982/1000
# 1/1 [==============================] - 0s 20ms/step - loss: 0.0024 - accuracy: 1.0000 - val_loss: 0.1053 - val_accuracy: 1.0000
# Epoch 983/1000
# 1/1 [==============================] - 0s 20ms/step - loss: 0.0030 - accuracy: 1.0000 - val_loss: 0.1072 - val_accuracy: 1.0000
# Epoch 984/1000
# 1/1 [==============================] - 0s 20ms/step - loss: 0.0028 - accuracy: 1.0000 - val_loss: 0.1017 - val_accuracy: 1.0000
# Epoch 985/1000
# 1/1 [==============================] - 0s 21ms/step - loss: 0.0028 - accuracy: 1.0000 - val_loss: 0.0985 - val_accuracy: 1.0000
# Epoch 986/1000
# 1/1 [==============================] - 0s 19ms/step - loss: 0.0030 - accuracy: 1.0000 - val_loss: 0.1022 - val_accuracy: 1.0000
# Epoch 987/1000
# 1/1 [==============================] - 0s 19ms/step - loss: 0.0023 - accuracy: 1.0000 - val_loss: 0.1033 - val_accuracy: 1.0000
# Epoch 988/1000
# 1/1 [==============================] - 0s 20ms/step - loss: 0.0041 - accuracy: 1.0000 - val_loss: 0.1051 - val_accuracy: 1.0000
# Epoch 989/1000
# 1/1 [==============================] - 0s 20ms/step - loss: 0.0030 - accuracy: 1.0000 - val_loss: 0.1034 - val_accuracy: 1.0000
# Epoch 990/1000
# 1/1 [==============================] - 0s 20ms/step - loss: 0.0044 - accuracy: 1.0000 - val_loss: 0.0952 - val_accuracy: 1.0000
# Epoch 991/1000
# 1/1 [==============================] - 0s 20ms/step - loss: 0.0038 - accuracy: 1.0000 - val_loss: 0.0932 - val_accuracy: 1.0000
# Epoch 992/1000
# 1/1 [==============================] - 0s 22ms/step - loss: 0.0051 - accuracy: 1.0000 - val_loss: 0.0987 - val_accuracy: 1.0000
# Epoch 993/1000
# 1/1 [==============================] - 0s 20ms/step - loss: 0.0038 - accuracy: 1.0000 - val_loss: 0.1036 - val_accuracy: 1.0000
# Epoch 994/1000
# 1/1 [==============================] - 0s 21ms/step - loss: 0.0040 - accuracy: 1.0000 - val_loss: 0.1060 - val_accuracy: 1.0000
# Epoch 995/1000
# 1/1 [==============================] - 0s 21ms/step - loss: 0.0044 - accuracy: 1.0000 - val_loss: 0.1037 - val_accuracy: 1.0000
# Epoch 996/1000
# 1/1 [==============================] - 0s 21ms/step - loss: 0.0039 - accuracy: 1.0000 - val_loss: 0.0971 - val_accuracy: 1.0000
# Epoch 997/1000
# 1/1 [==============================] - 0s 20ms/step - loss: 0.0035 - accuracy: 1.0000 - val_loss: 0.0969 - val_accuracy: 1.0000
# Epoch 998/1000
# 1/1 [==============================] - 0s 21ms/step - loss: 0.0045 - accuracy: 1.0000 - val_loss: 0.1024 - val_accuracy: 1.0000
# Epoch 999/1000
# 1/1 [==============================] - 0s 20ms/step - loss: 0.0034 - accuracy: 1.0000 - val_loss: 0.1082 - val_accuracy: 1.0000
# Epoch 1000/1000
# 1/1 [==============================] - 0s 21ms/step - loss: 0.0033 - accuracy: 1.0000 - val_loss: 0.1084 - val_accuracy: 1.0000

# %%
model_score = seq_model.evaluate(test_features, test_labels, verbose = 0)
print(model_score)
# Out:
# [0.042140230536460876, 1.0]

# %%
test_predictions = seq_model.predict(test_features)
# Out:
# 3/3 [==============================] - 0s 994us/step

# %%
# Анализ Depth
x_predict = range(test_predictions.shape[0])
y_predict = test_predictions[:,:1]
y_test = test_labels[:,:1]
test_results_depth['Neural Network'] = mae(y_test, y_predict)
plt_model(x_predict, y_test, y_predict, f'Depth: NN Model MAE: {mae(y_test, y_predict):0.3}')

# %%
# Анализ Width
x_predict = range(test_predictions.shape[0])
y_predict = test_predictions[:,1:2]
y_test = test_labels[:,1:2]
test_results_width['Neural Network'] = mae(y_test, y_predict)
plt_model(x_predict, y_test, y_predict, f'Width: Neural Network Model MAE: {mae(y_test, y_predict):0.3}')

# %%
test_predictions = seq_model.predict(test_features[:1], verbose = 0)
print(f'Параметры: {test_features[:1]}')
print(f'Прогноз: {test_predictions}')
print(f'Истинное значение: {test_labels[:1]}')
# Out:
# Параметры: [[ 47.  139.    4.5  80. ]]
# Прогноз: [[1.5   2.509]]
# Истинное значение: [[1.6  2.54]]

# %%
print("WIDTH")
test_results_width
# Out:
# WIDTH
# {'LinearRegression': 0.05442429651267374,
#  'PolynomialFeatures': 0.030625000000000013,
#  'SupportVectorRegression': 0.03158711796658591,
#  'Neural Network': 0.03760538472069636}

# %%
print("DEPTH")
test_results_depth
# Out:
# DEPTH
# {'LinearRegression': 0.0745975747744926,
#  'PolynomialFeatures': 0.04277777777777795,
#  'SupportVectorRegression': 0.044957939923193,
#  'Neural Network': 0.046675081650416055}

# %% [markdown]
# #### Сохранение модели

# %%
seq_model.save('model\welding-model')
# Сохранение в формате ONNX
tf2onnx.convert.from_keras(seq_model, output_path = 'model\welding-model.onnx')
# Out:
# INFO:tensorflow:Assets written to: model\welding-model\assets
# (ir_version: 7
#  producer_name: "tf2onnx"
#  producer_version: "1.13.0 2c1db5"
#  graph {
#    node {
#      input: "normalization_input"
#      input: "sequential/normalization/sub/y:0"
#      output: "sequential/normalization/sub:0"
#      name: "sequential/normalization/sub"
#      op_type: "Sub"
#    }
#    node {
#      input: "sequential/normalization/sub:0"
#      input: "ConstantFolding/sequential/normalization/truediv_recip:0"
#      output: "sequential/normalization/truediv:0"
#      name: "sequential/normalization/truediv"
#      op_type: "Mul"
#    }
#    node {
#      input: "sequential/normalization/truediv:0"
#      input: "sequential/dense/MatMul/ReadVariableOp:0"
#      output: "sequential/dense/MatMul:0"
#      name: "sequential/dense/MatMul"
#      op_type: "MatMul"
#    }
#    node {
#      input: "sequential/dense/MatMul:0"
#      input: "sequential/dense/BiasAdd/ReadVariableOp:0"
#      output: "sequential/dense/BiasAdd:0"
#      name: "sequential/dense/BiasAdd"
#      op_type: "Add"
#    }
#    node {
#      input: "sequential/dense/BiasAdd:0"
#      output: "sequential/dense/Relu:0"
#      name: "sequential/dense/Relu"
#      op_type: "Relu"
#    }
#    node {
#      input: "sequential/dense/Relu:0"
#      input: "sequential/dense_1/MatMul/ReadVariableOp:0"
#      output: "sequential/dense_1/MatMul:0"
#      name: "sequential/dense_1/MatMul"
#      op_type: "MatMul"
#    }
#    node {
#      input: "sequential/dense_1/MatMul:0"
#      input: "sequential/dense_1/BiasAdd/ReadVariableOp:0"
#      output: "sequential/dense_1/BiasAdd:0"
#      name: "sequential/dense_1/BiasAdd"
#      op_type: "Add"
#    }
#    node {
#      input: "sequential/dense_1/BiasAdd:0"
#      output: "sequential/dense_1/Relu:0"
#      name: "sequential/dense_1/Relu"
#      op_type: "Relu"
#    }
#    node {
#      input: "sequential/dense_1/Relu:0"
#      input: "sequential/dense_2/MatMul/ReadVariableOp:0"
#      output: "sequential/dense_2/MatMul:0"
#      name: "sequential/dense_2/MatMul"
#      op_type: "MatMul"
#    }
#    node {
#      input: "sequential/dense_2/MatMul:0"
#      input: "sequential/dense_2/BiasAdd/ReadVariableOp:0"
#      output: "dense_2"
#      name: "sequential/dense_2/BiasAdd"
#      op_type: "Add"
#    }
#    name: "tf2onnx"
#    initializer {
#      dims: 1
#      dims: 4
#      data_type: 1
#      name: "sequential/normalization/sub/y:0"
#      raw_data: "337B\336\335\014C\336\335\rAUU\241B"
#    }
#    initializer {
#      dims: 32
#      dims: 2
#      data_type: 1
#      name: "sequential/dense_2/MatMul/ReadVariableOp:0"
#      raw_data: "\307\230\217\275\273\326\270>j)\212\276\202\230\022=E\374\262=\260O:=s\034\301\276\037\266]>\024}\007=S\'\t>\275\234\265\276\025\n\366=\027\304\256=\374F.>\214\370\350>\324\203\210>\220sp\276:\020\357>\343T\252\275\330\353\224\276\360U\230\276\270I\207=~\326\340>\240r\220>\031\026\230\276\330\352\302>\030\037W>Ca\236>\212\'#\276\3242\354\274\204\300\013\276Q\217\003={^\315\275\026Gd\276L\340\325\274\036\372\334>\325)\207>b\237\t>\337\371\233\275\373\334\301\274\251\372m>A\363\213\276\354\240:>\271\240G>\216=\352>\322\244\273=(0\240\273@\276\310>D:\302\276\241\366\r\2768b\251>\222\324\320\276\255\204\005?\324\321\002>+\240\251>\206\361\220\276\035\304~;q\312\215=\003]\327=\030D\210><\017#\276%\254\322=(\310{=\357o<\276"
#    }
#    initializer {
#      dims: 2
#      data_type: 1
#      name: "sequential/dense_2/BiasAdd/ReadVariableOp:0"
#      raw_data: "y\216\246=,`\254="
#    }
#    initializer {
#      dims: 64
#      dims: 32
#      data_type: 1
#      name: "sequential/dense_1/MatMul/ReadVariableOp:0"
#      raw_data: "P\316\265\275\371\\;=z\251W<F\345\334\275Z\017->\252\204\226<\242H\017;\342\352Y\276\222\245o>\251\202\330=`\315\372=}1\r>\267)X>\304\320=>\277\203\356\275x\254\223\274\025\276\'\275\327/4\276r8(>%u\323=\255j|\273.\376\r\276\206B[<\340\031\250=\224\214\232\275\250\311h\2762\375}\276\270\014V\276\200}8=\305Wj>\215R\206\275)X(\276\204g\016\275\301\n\371\274\200\315\r\276\354\230\263\275\253C\227>2\214\033=\376\231\221>\210\331\252\275\261Wq>Q\\?=\264\252l\276SP\317<o\037\216>\323\276%>\232h\261;\n=\037\276\001\247_\275$\177/>\225\013P\276A\327\347=4\026]\275\201A\375=\273\247V\276\355\272\216\274\215\213B>\305:\"\275F(\204\275\3604F>\254\031\222\275<\266\334=?\026\213\276c\302\216\276XG[>\372\014\t\275zU\206>\226>(\276\330mW>\346!\236\275\001\246\364=N\224\202>\274\231\270=p\351]\276\000d\356=\257Y\214\275\'\235\360=\272\253\n>\246\213p=k!X>`\351#>\r{\224<1r]\275&c\226\275\357=i>G_\233\2754\347\251=f\273t\275\227\320\013\275E\307T\276\023%^\275L\3758\276\033\251%>\250j\327\275\360\326\177\276\321Z\001>Ew\273=\205\rf\275\022\272\205\275\335\214f=\177\252\375\275\306\321d\275Z\262\022\276\000\210B\275\261g\213>t\364\202\276\0345p\276S\215\032>\375\211u\2763\353\313=:?e\275B+;\276V\310\211\273D\235\231=\271!9\274\036\305\"=B\365\201=\243\332\021\2755\301\005\275\247\236\200\275_\201\034>\276\376\013>\277\253\357;\370r\240\275\244\334\177>\347g5\276\260\307v\276\222\220\016\274\310Z\265>\001\r\353=\004\311\306\275]\265\026\2763|\265>\357\327D\275\215=\375=\244\340;>\024+\367\273\323\3123>\364\017\003\276\243\033\202>g\211;=\263\007\031>\256:|\274\272\314\310=\256ab\2766\365?> J\035>~\255\274;\213\036Q=i\021\327\275\202\242\242<\352\365L>qU?\276j\021i\275\021\033\021>\260\212}\276(\212\007>Z\316\212>\031\327\205\2762\371\214\276\t\336\250<8\3048>v\207\215>\225\033U\276\347T\376<\254\270\037>\360\326!\276\310\247\225\275\365\365b>c.\004>\360\345\241\275sIR>\326]6\275\3545N>\210\366\311\275G\271\354\275\357\017\240=K\035\026>2\230\227>\275\3030>\007+\231\276\370\016\223<D\323\016\275\333\035d>\227\355F>1\204(\274Oyn>0\246\020=\r9\215:Nz\226>\334\304\034>,4\365\275\0026\252\275p\305\205\276\261\307L>\363\276A\276\2606\351\275\342\231\203<\332\357H>\035_w\274\346\004K\275\335\221\201\276\030/t\276\207B:\275\272\334Z\276\355\214y>!~+>@\005\265=]\251x=\327\200\202<G\020\374\274\342\206c\276>\265M>P\3748>\027\303H\276\325y\032=\240\220\277=\0160b\276\364z\035>\260\341>\276\"9G>\030\225\373<\375\014\363\275(&\235\275*\346\371=z\322\206<\027D\314=\332h\254\275\362\270\312\275\306\276\003>Be\026\276\311\357R=7\270>>\020\340\027\276@\260h<\2305k=\344v\017>w\264y=\204\247\271<`k\354=u{\255=\002:\306\275Op\363\274\206\315\336<$\021T>\327\367~>\275\014=>0S >\252`\357\275\241^\005>\265\210\004=\200V\356=\205a\311=/{\357\275\240\021\203=r\373\022>B\234y>X\216y\276\320\241\242=\330\333\035=\271\300\035\275\0045\025\275\376[I\273\265j=>\033@e>F\010f>Pr`\276o\346\214=\316,\221\275o\323/\276\253\3749=\r\000\371=/\377\325=\265\323\252=\370\305?=\3014\203\276`\337\316<\366\366\344\275B\377i\276;\001\337=\027m\222=-\2265\276g|\340\274@k8<\026cE\275?<6>q\206\034\276*PK>\242H\203\276\225\275\201\273\"<\020>6 |\276\254rX=\255\010\007\276D\215\200>:\376\273=\375\302\202\275a\373\234=\2206h\275(\375\235\275\225\210\242\275E0o=\2578\023>\200V\006=\026\201\211\275\322\025\004\276\006i\207=1\273D\276#v!\275\241+\257\275\3563\010>{\357\300=\304\\.>{\016\254\275>\276\336\275Hv\377=\035\0356>_\270\020=\375\322\210\276\204~d=\316T8\276\232E|=?\260\315\2759\245\n\275K\223v>\35236\275\355\205\301:\257\372^\276\205\243X>z\014\346\275\030\r\377=}\363R>\343\366\002\276*B\017\276\301\253g\276\260\214/=\226-\232\275\004\360\322\274\312:f>\236\255\306\274\230\222\014>|nj>\230x\330;?\\\331<\2020|\276\314\314\3539\212\010\327=\2103.\276\317\036\305=\017\240h>\265\364&=w\201\237=Q6\237\276A\353Q\275\014\275\032\275V\233q\276\216\326\267=\2525\034>\217_O<rP\304\275s\305\006=\363\323\231\275Xm\360\275)nA\275\220\354*>\344J\205\276n\320\201\276pF\230\275\037\314\311 ...
#    }
#    initializer {
#      dims: 32
#      data_type: 1
#      name: "sequential/dense_1/BiasAdd/ReadVariableOp:0"
#      raw_data: "\250q\013>\317\354\t\275\361\037\307=\225=\357\274\232|\345=\256n\335\274z\200\303=P^\254=\030\232\316=\270]\320\274\000\000\000\000sj\322=\\?\362\2730\214\320=\216D\025\275\340\332\202\275\314O\355\274\360u\010>o\026\365=\003|\"\275\206c\r\2758\202\357=\346@\352=\226\001\330=h\271L\275.u\206\274\200B$>\000\000\000\000\205k\351=GH\316=\267q\246\274%\205|\275"
#    }
#    initializer {
#      dims: 4
#      dims: 64
#      data_type: 1
#      name: "sequential/dense/MatMul/ReadVariableOp:0"
#      raw_data: "v\t\022\275\225\227\221>\006\023\231>\370\032\335=\\\262K\275\222U\254\276\214R~\2762\361*\276\225\353\310<\241PY\276&G \276P}`>\006LK>\324\305H\275\r\267\242=k0\323\275\374\211\354\274\355\231\243\276\227iD\276\304\256z>2m\020>*\215\261=\321G\354=\t\031]>~HA>\373\341\226\275AI\020=\004 w>\r\257\200>R\320\372=\252\244\300>\224\312\025\276\347#\r\276~\3023\273\361R0\276\374\326\205=\021\210\016\275\200\306\300\275Qp\303=\222#\370=\322\233\027\276\274\360\021\276\200\345\363\2752)C\276q\303\353\2737\225\032\276Y?i\276\3725\022>\362A\261\275?\321\177>\246\021U\275\201n\230\275G\025\014\276(\264i=\243,\022>i\235\212>\236D\231\275\373!\373\275\205\321r\276\007\022\315\275|\340\227>\002\330\256=\363\274\220\274\206\315\364;V\035\223>\276\334\n\276-8K>\006\010\214\274\240\t\314\275\020\226G\276U\000\211\274{Gr>\"V\352\275+\224W>2\233\251\272\217\210\345=\\\312\371\275\031h\211>\337\213\217\275h%\206>\332\030V>\316\022Z>;\034_\276\007S\200=%\271\013>\313\300{>|\\\325\274\002z\305=\254\220\000\276B\227R>d\025\326=\002\016\240\275\245K\037>*\242\005\276\031\241\014>\"\242\272=\256\374}\2762t_\276\333\036l\276F\027\200>\252~/\275\222\237T\2756N\016=\270\204\021>\255:&>\037\357\376=\016l}>\331\352\326=c}^>\023<w\276\264\037\006\276\365\261 >\246\224\244=\325\334k>B\333|\275\201^[>\262\222I>\227H\203=Ki3>\210\010\035>\0268B>\334W\374=\302B\256\276\304N\247=+\231\022>\262\271\355\275\014\222\002;\277\3536\276S$f>C\230\250\275\373\226\353<\036vQ\276yC\\=\"+\226;_\232m\276|\255\235\276\220G\361=s\215c\276\227!\211\275\201?\031>\214bo>\306\264]\276\372\353=>\367\034\205=;\361\031\275x\253\026\276k=\022=A\207\005>R\273\200>\234\310\261==\t}\275\361\376#\276\363[F\276\0304\223>m\350\025\276\013i!=\327Y\026>\314\340\244\276m\300\022>\276Pb\276\200cF>\363\374h<\2515\200>\232\211\017>\351\0132=:\341w>\010,;>T\353.\276a:\211>&\350|<\037t\364\275\225\331\243>\255J\203\276R\246\t>\207ft>K\004\001\276\036;\226\276M8\010\276\326\301\272\275%/\204>\266\222\003\276<\267V>E\342\302\275\355\216\246<-\006\271\275w\371\215>\306\207\332=\357\020W=\263\000\311\272\30292<\217\033\244\276\331\201\252\276\347\261I>0\202=\276U6(\2769$=\275\271}\330\2757y$>\343B\216\275\214\3238>\374\247\030>\2115\345=m\310X\276l4S\272V-\245\276\326\034\366=\2548N\276E\006\231=\232\315~\276\316])\276\355\314v>-\371o\275\352\377\r=\036\n\006\276\272D\230\275\276\2667<\005\230\250\276\014\177Y\274,\346\333\274\206\210\226>\370L\210\276\220J[\276\376^\371\275\303{]\276x\005\346=u6W\276\365\034\235>\2078@>\271\026b>\224\375\215>#\260\007>\310\026\006>\340w}\276\037\276\022\276\266d\211\275,\025\215\276S\313D\276\213\304O\276]{\001<V\254r>\227\320\371\275\002\224\201\275\367\361\276<\344l\322=(\257\231>J}\234\275\215z\035\274\240\270\224>\245N\023;\243iE>\274\334\310\275\'\036\024\276\002\314\210>\273kf\276\272\253p={$:\276"
#    }
#    initializer {
#      dims: 64
#      data_type: 1
#      name: "sequential/dense/BiasAdd/ReadVariableOp:0"
#      raw_data: "2\253\224=p\221\245\275{.#>\302i\352<\310\302\021>\314\233L>$\240\257=\037\277\264=\276\2030>\220VR=<\240\027>\320\257\357\275!&\033>\321Hr=\350H\201=\356R\375\274\315\022\320=|k|=\205\221\317=-Z\341\275\374\321\020>\342\332\227\275\226/g\275\216\000x\275o\362M>\237r\025\276y\351\215=S\237\201=\334\024\007=`^\003>q\274,>\300RN\275\262G\274=\022\\h\275\2431->Dl\345=\343w7>C\350\t>g\033\355\275\372\240\026\275\305\016\267=\247i\313=#\316\273=I9\357=\002\025\244=\3760/>\206\210\336\275\331.\023>\036\234\236=k\357\306\274\275\245\247\274\222\002\260=\307,\213\275\005K\345=\247\014\311\274\242\000\226=\355\025\221\275\013\024\307<\2025*>gW\024>\2349\025>UK1>\222]\264=\222\353\016>"
#    }
#    initializer {
#      dims: 1
#      dims: 4
#      data_type: 1
#      name: "ConstantFolding/sequential/normalization/truediv_recip:0"
#      raw_data: "\021D\030?\311\nB>\250\016\003?\351\3377="
#    }
#    doc_string: "converted from sequential"
#    input {
#      name: "normalization_input"
#      type {
#        tensor_type {
#          elem_type: 1
#          shape {
#            dim {
#              dim_param: "unk__6"
#            }
#            dim {
#              dim_param: "unk__7"
#            }
#          }
#        }
#      }
#    }
#    output {
#      name: "dense_2"
#      type {
#        tensor_type {
#          elem_type: 1
#          shape {
#            dim {
#              dim_param: "unk__8"
#            }
#            dim {
#              dim_value: 2
#            }
#          }
#        }
#      }
#    }
#  }
#  opset_import {
#    domain: ""
#    version: 13
#  }
#  opset_import {
#    domain: "ai.onnx.ml"
#    version: 2
#  },
#  None)

# %% [markdown]
# #### Загрузка сохраненной модели и тестовый запуск

# %%
# Создание переменной сессии для работы с моделью (загрузка модели)
session = rt.InferenceSession('model\welding-model.onnx')
# Создание вектора для параметров
X = np.array([[47.0, 139.0, 4.5, 80.0]], dtype = np.float32)
inputDetails = session.get_inputs()
# Получение прогозна
y = session.run(None, {inputDetails[0].name: X})
print(y)
# Out:
# [array([[1.5  , 2.509]], dtype=float32)]
